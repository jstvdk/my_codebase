# %%
from matplotlib.colors import SymLogNorm
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from astropy.coordinates.sky_coordinate import SkyCoord
import astropy.units as u
#from astropy.cosmology import Planck15 as cosmo
from astropy.cosmology import FlatLambdaCDM
cosmo = FlatLambdaCDM(H0 = 67.8,  Om0 = 0.308,  Ob0 = 0.0484,  Tcmb0 = 2.7255,  Neff = 3.13)
from astropy.wcs import WCS
from minot import model, model_plots
from astropy import constants as const
import scipy

# Modify plotting parameters
dict_base = {'font.size':        16,
             'legend.fontsize':  16,
             'xtick.labelsize':  16,
             'ytick.labelsize':  16,
             'axes.labelsize':   16,
             'axes.titlesize':   16,
             'figure.titlesize': 16,    
             'figure.figsize':[8.0, 6.0],
             'figure.subplot.right':0.97,
             'figure.subplot.left':0.15,
             'font.family':'serif',
             'figure.facecolor': 'white',
             'legend.frameon': True}
plt.rcParams.update(dict_base)

# %%
clust_Coma_Remi = model.Cluster(name='Coma', 
                      redshift=0.023, M500=6.13e14*u.Msun, 
                      cosmology=cosmo, silent=False, 
                      output_dir='/Users/vdk/Desktop/ComaTEST_1')

clust_Coma_Remi_2 = model.Cluster(name='Coma', 
                      redshift=0.023, M500=6.13e14*u.Msun, 
                      cosmology=cosmo, silent=False, 
                      output_dir='/Users/vdk/Desktop/ComaTEST_1')

clust_Coma_Our = model.Cluster(name='Coma', 
                      redshift=0.023, M500=6.13e14*u.Msun, 
                      cosmology=cosmo, silent=False, 
                      output_dir='/Users/vdk/Desktop/ComaTEST_1')

clust_Coma_Our_2 = model.Cluster(name='Coma', 
                      redshift=0.023, M500=6.13e14*u.Msun, 
                      cosmology=cosmo, silent=False, 
                      output_dir='/Users/vdk/Desktop/ComaTEST_1')

clust_Coma_index2 = model.Cluster(name='Coma', 
                      redshift=0.023, M500=6.13e14*u.Msun, 
                      cosmology=cosmo, silent=False, 
                      output_dir='/Users/vdk/Desktop/ComaTEST_1')

clust_Coma_index23 = model.Cluster(name='Coma', 
                      redshift=0.023, M500=6.13e14*u.Msun, 
                      cosmology=cosmo, silent=False, 
                      output_dir='/Users/vdk/Desktop/ComaTEST_1')

clust_Coma_index27 = model.Cluster(name='Coma', 
                      redshift=0.023, M500=6.13e14*u.Msun, 
                      cosmology=cosmo, silent=False, 
                      output_dir='/Users/vdk/Desktop/ComaTEST_1')

clust_Coma_index2_2 = model.Cluster(name='Coma', 
                      redshift=0.023, M500=6.13e14*u.Msun, 
                      cosmology=cosmo, silent=False, 
                      output_dir='/Users/vdk/Desktop/ComaTEST_1')

clust_Coma_index23_2 = model.Cluster(name='Coma', 
                      redshift=0.023, M500=6.13e14*u.Msun, 
                      cosmology=cosmo, silent=False, 
                      output_dir='/Users/vdk/Desktop/ComaTEST_1')

clust_Coma_index27_2 = model.Cluster(name='Coma', 
                      redshift=0.023, M500=6.13e14*u.Msun, 
                      cosmology=cosmo, silent=False, 
                      output_dir='/Users/vdk/Desktop/ComaTEST_1')


clust_Coma_index2.coord = SkyCoord("194.91d  27.95d", frame="icrs", unit="deg")
clust_Coma_index2.pressure_gas_model = {'name':'GNFW', 'P_0':0.022*u.keV/u.cm**3, 'r_p':466.8*u.kpc, 'a':1.8, 'b':3.1, 'c':0.}
clust_Coma_index2.density_gas_model = {'name':'beta', 'n_0':3.36e-3*u.cm**-3, 'beta':0.75, 'r_c':310.*u.kpc}
clust_Coma_index2.abundance = 0.3
clust_Coma_index2.set_magfield_isodens_scal_param(4.7*u.uG, scal=0.5)
clust_Coma_index2.X_crp_E = {'X':0.02, 'R_norm':clust_Coma_Remi.R500} 
clust_Coma_index2.X_cre1_E = {'X':0.00002, 'R_norm':clust_Coma_Remi.R500} 
clust_Coma_index2.spectrum_crp_model = {'name':'ExponentialCutoffPowerLaw', 'Index':2., 'CutoffEnergy':30*u.TeV}
clust_Coma_index2.spectrum_cre1_model = {'name':'PowerLaw', 'Index':3.}
clust_Coma_index2.set_density_crp_isodens_scal_param(scal=1)
clust_Coma_index2.Epmax = 1e6*u.TeV
clust_Coma_index2.Eemax = 1e-2*u.TeV

clust_Coma_index23.coord = SkyCoord("194.91d  27.95d", frame="icrs", unit="deg")
clust_Coma_index23.pressure_gas_model = {'name':'GNFW', 'P_0':0.022*u.keV/u.cm**3, 'r_p':466.8*u.kpc, 'a':1.8, 'b':3.1, 'c':0.}
clust_Coma_index23.density_gas_model = {'name':'beta', 'n_0':3.36e-3*u.cm**-3, 'beta':0.75, 'r_c':310.*u.kpc}
clust_Coma_index23.abundance = 0.3
clust_Coma_index23.set_magfield_isodens_scal_param(4.7*u.uG, scal=0.5)
clust_Coma_index23.X_crp_E = {'X':0.02, 'R_norm':clust_Coma_Remi.R500} 
clust_Coma_index23.X_cre1_E = {'X':0.00002, 'R_norm':clust_Coma_Remi.R500} 
clust_Coma_index23.spectrum_crp_model = {'name':'ExponentialCutoffPowerLaw', 'Index':2.3, 'CutoffEnergy':30*u.TeV}
clust_Coma_index23.spectrum_cre1_model = {'name':'PowerLaw', 'Index':3.}
clust_Coma_index23.set_density_crp_isodens_scal_param(scal=1)
clust_Coma_index23.Epmax = 1e6*u.TeV
clust_Coma_index23.Eemax = 1e-2*u.TeV

clust_Coma_index27.coord = SkyCoord("194.91d  27.95d", frame="icrs", unit="deg")
clust_Coma_index27.pressure_gas_model = {'name':'GNFW', 'P_0':0.022*u.keV/u.cm**3, 'r_p':466.8*u.kpc, 'a':1.8, 'b':3.1, 'c':0.}
clust_Coma_index27.density_gas_model = {'name':'beta', 'n_0':3.36e-3*u.cm**-3, 'beta':0.75, 'r_c':310.*u.kpc}
clust_Coma_index27.abundance = 0.3
clust_Coma_index27.set_magfield_isodens_scal_param(4.7*u.uG, scal=0.5)
clust_Coma_index27.X_crp_E = {'X':0.02, 'R_norm':clust_Coma_Remi.R500} 
clust_Coma_index27.X_cre1_E = {'X':0.00002, 'R_norm':clust_Coma_Remi.R500} 
clust_Coma_index27.spectrum_crp_model = {'name':'ExponentialCutoffPowerLaw', 'Index':2.7, 'CutoffEnergy':30*u.TeV}
clust_Coma_index27.spectrum_cre1_model = {'name':'PowerLaw', 'Index':3.}
clust_Coma_index27.set_density_crp_isodens_scal_param(scal=1)
clust_Coma_index27.Epmax = 1e6*u.TeV
clust_Coma_index27.Eemax = 1e-2*u.TeV


clust_Coma_index2_2.coord = SkyCoord("194.91d  27.95d", frame="icrs", unit="deg")
clust_Coma_index2_2.pressure_gas_model = {'name':'GNFW', 'P_0':0.022*u.keV/u.cm**3, 'r_p':466.8*u.kpc, 'a':1.8, 'b':3.1, 'c':0.}
clust_Coma_index2_2.density_gas_model = {'name':'beta', 'n_0':3.36e-3*u.cm**-3, 'beta':0.75, 'r_c':310.*u.kpc}
clust_Coma_index2_2.abundance = 0.3
clust_Coma_index2_2.set_magfield_isodens_scal_param(4.7*u.uG, scal=0.5)
clust_Coma_index2_2.X_crp_E = {'X':0.02, 'R_norm':clust_Coma_Remi.R500} 
clust_Coma_index2_2.X_cre1_E = {'X':0.00002, 'R_norm':clust_Coma_Remi.R500} 
clust_Coma_index2_2.spectrum_crp_model = {'name':'ExponentialCutoffPowerLaw', 'Index':2., 'CutoffEnergy':30*u.TeV}
clust_Coma_index2_2.spectrum_cre1_model = {'name':'PowerLaw', 'Index':3.}
clust_Coma_index2_2.set_density_crp_isodens_scal_param(scal=2)
clust_Coma_index2_2.Epmax = 1e6*u.TeV
clust_Coma_index2_2.Eemax = 1e-2*u.TeV

clust_Coma_index23_2.coord = SkyCoord("194.91d  27.95d", frame="icrs", unit="deg")
clust_Coma_index23_2.pressure_gas_model = {'name':'GNFW', 'P_0':0.022*u.keV/u.cm**3, 'r_p':466.8*u.kpc, 'a':1.8, 'b':3.1, 'c':0.}
clust_Coma_index23_2.density_gas_model = {'name':'beta', 'n_0':3.36e-3*u.cm**-3, 'beta':0.75, 'r_c':310.*u.kpc}
clust_Coma_index23_2.abundance = 0.3
clust_Coma_index23_2.set_magfield_isodens_scal_param(4.7*u.uG, scal=0.5)
clust_Coma_index23_2.X_crp_E = {'X':0.02, 'R_norm':clust_Coma_Remi.R500} 
clust_Coma_index23_2.X_cre1_E = {'X':0.00002, 'R_norm':clust_Coma_Remi.R500} 
clust_Coma_index23_2.spectrum_crp_model = {'name':'ExponentialCutoffPowerLaw', 'Index':2.3, 'CutoffEnergy':30*u.TeV}
clust_Coma_index23_2.spectrum_cre1_model = {'name':'PowerLaw', 'Index':3.}
clust_Coma_index23_2.set_density_crp_isodens_scal_param(scal=2)
clust_Coma_index23_2.Epmax = 1e6*u.TeV
clust_Coma_index23_2.Eemax = 1e-2*u.TeV

clust_Coma_index27_2.coord = SkyCoord("194.91d  27.95d", frame="icrs", unit="deg")
clust_Coma_index27_2.pressure_gas_model = {'name':'GNFW', 'P_0':0.022*u.keV/u.cm**3, 'r_p':466.8*u.kpc, 'a':1.8, 'b':3.1, 'c':0.}
clust_Coma_index27_2.density_gas_model = {'name':'beta', 'n_0':3.36e-3*u.cm**-3, 'beta':0.75, 'r_c':310.*u.kpc}
clust_Coma_index27_2.abundance = 0.3
clust_Coma_index27_2.set_magfield_isodens_scal_param(4.7*u.uG, scal=0.5)
clust_Coma_index27_2.X_crp_E = {'X':0.02, 'R_norm':clust_Coma_Remi.R500} 
clust_Coma_index27_2.X_cre1_E = {'X':0.00002, 'R_norm':clust_Coma_Remi.R500} 
clust_Coma_index27_2.spectrum_crp_model = {'name':'ExponentialCutoffPowerLaw', 'Index':2.7, 'CutoffEnergy':30*u.TeV}
clust_Coma_index27_2.spectrum_cre1_model = {'name':'PowerLaw', 'Index':3.}
clust_Coma_index27_2.set_density_crp_isodens_scal_param(scal=2)
clust_Coma_index27_2.Epmax = 1e6*u.TeV
clust_Coma_index27_2.Eemax = 1e-2*u.TeV


clust_Coma_Remi.coord = SkyCoord("194.91d  27.95d", frame="icrs", unit="deg")
clust_Coma_Remi.pressure_gas_model = {'name':'GNFW', 'P_0':0.022*u.keV/u.cm**3, 'r_p':466.8*u.kpc, 'a':1.8, 'b':3.1, 'c':0.}
clust_Coma_Remi.density_gas_model = {'name':'beta', 'n_0':3.36e-3*u.cm**-3, 'beta':0.75, 'r_c':310.*u.kpc}
clust_Coma_Remi.abundance = 0.3
clust_Coma_Remi.set_magfield_isodens_scal_param(4.7*u.uG, scal=0.5)
clust_Coma_Remi.X_crp_E = {'X':0.01, 'R_norm':clust_Coma_Remi.R500} 
clust_Coma_Remi.X_cre1_E = {'X':0.01, 'R_norm':clust_Coma_Remi.R500} 
clust_Coma_Remi.spectrum_crp_model = {'name':'PowerLaw', 'Index':2.3}
clust_Coma_Remi.spectrum_cre1_model = {'name':'PowerLaw', 'Index':2.3}
clust_Coma_Remi.set_density_crp_isodens_scal_param(scal=1)

clust_Coma_Remi_2.coord = SkyCoord("194.91d  27.95d", frame="icrs", unit="deg")
clust_Coma_Remi_2.pressure_gas_model = {'name':'GNFW', 'P_0':0.022*u.keV/u.cm**3, 'r_p':466.8*u.kpc, 'a':1.8, 'b':3.1, 'c':0.}
clust_Coma_Remi_2.density_gas_model = {'name':'beta', 'n_0':3.36e-3*u.cm**-3, 'beta':0.75, 'r_c':310.*u.kpc}
clust_Coma_Remi_2.abundance = 0.3
clust_Coma_Remi_2.set_magfield_isodens_scal_param(4.7*u.uG, scal=0.5)
clust_Coma_Remi_2.X_crp_E = {'X':0.02, 'R_norm':clust_Coma_Remi.R500} 
clust_Coma_Remi_2.X_cre1_E = {'X':0.01, 'R_norm':clust_Coma_Remi.R500} 
clust_Coma_Remi_2.spectrum_crp_model = {'name':'PowerLaw', 'Index':2.3}
clust_Coma_Remi_2.spectrum_cre1_model = {'name':'PowerLaw', 'Index':2.3}
clust_Coma_Remi_2.set_density_crp_isodens_scal_param(scal=1)


clust_Coma_Our.coord = SkyCoord("194.91d  27.95d", frame="icrs", unit="deg")
clust_Coma_Our.pressure_gas_model = {'name':'GNFW', 'P_0':0.022*u.keV/u.cm**3, 'r_p':466.8*u.kpc, 'a':1.8, 'b':3.1, 'c':0.}
clust_Coma_Our.density_gas_model = {'name':'beta', 'n_0':3.36e-3*u.cm**-3, 'beta':0.75, 'r_c':310.*u.kpc}
clust_Coma_Our.abundance = 0.3
clust_Coma_Our.set_magfield_isodens_scal_param(4.7*u.uG, scal=0.5)
clust_Coma_Our.X_crp_E = {'X':0.05, 'R_norm':clust_Coma_Our.R500} 
clust_Coma_Our.X_cre1_E = {'X':0.01, 'R_norm':clust_Coma_Our.R500} 
clust_Coma_Our.spectrum_crp_model = {'name':'PowerLaw', 'Index':1.5}
clust_Coma_Our.spectrum_cre1_model = {'name':'PowerLaw', 'Index':2.3}
clust_Coma_Our.set_density_crp_isodens_scal_param(scal=1)

clust_Coma_Our_2.coord = SkyCoord("194.91d  27.95d", frame="icrs", unit="deg")
clust_Coma_Our_2.pressure_gas_model = {'name':'GNFW', 'P_0':0.022*u.keV/u.cm**3, 'r_p':466.8*u.kpc, 'a':1.8, 'b':3.1, 'c':0.}
clust_Coma_Our_2.density_gas_model = {'name':'beta', 'n_0':3.36e-3*u.cm**-3, 'beta':0.75, 'r_c':310.*u.kpc}
clust_Coma_Our_2.abundance = 0.3
clust_Coma_Our_2.set_magfield_isodens_scal_param(4.7*u.uG, scal=0.5)
clust_Coma_Our_2.X_crp_E = {'X':0.1, 'R_norm':clust_Coma_Our.R500} 
clust_Coma_Our_2.X_cre1_E = {'X':0.01, 'R_norm':clust_Coma_Our.R500} 
clust_Coma_Our_2.spectrum_crp_model = {'name':'PowerLaw', 'Index':1.5}
clust_Coma_Our_2.spectrum_cre1_model = {'name':'PowerLaw', 'Index':2.3}
clust_Coma_Our_2.set_density_crp_isodens_scal_param(scal=1)

# %%
energy = np.logspace(-1,5,100)*u.GeV
e_1, s_1 = clust_Coma_Remi.get_gamma_spectrum(energy,Rmax=clust_Coma_Remi.R500, type_integral='spherical')
e_2, s_2 = clust_Coma_Remi_2.get_gamma_spectrum(energy,Rmax=clust_Coma_Remi_2.R500, type_integral='spherical')


# разом з СТА чутливістю
plt.figure(0,figsize=(10,8))
bins_lo = [0.02, 0.0316, 0.0501, 0.0794, 0.126, 0.2, 0.316, 0.501, 0.794, 1.26, 2, 3.16, 5.01, 7.94, 12.6, 20, 31.6, 50.1, 79.4, 126] # E_min (TeV)
bins_hi = [0.0316, 0.0501, 0.0794, 0.126, 0.2, 0.316, 0.501, 0.794, 1.26, 2, 3.16, 5.01, 7.94, 12.6, 20, 31.6, 50.1, 79.4, 126, 200] # E_max (TeV)
data = [2.37e-11, 8.35e-12, 2.02e-12, 9.41e-13, 5.37e-13, 3.58e-13, 2.43e-13, 1.76e-13, 1.35e-13, 1.24e-13, 1.1e-13,
        1.21e-13, 1.44e-13, 2.06e-13, 3.2e-13, 5.1e-13, 7.97e-13, 1.2e-12, 1.93e-12, 3.92e-12] # S (erg / cm^2 / s)
data_GeV = [i * 624.15064799632 for i in data]
mid_point = [np.exp((np.log(i)+np.log(j))/2) * 1000 for i, j in zip(bins_lo, bins_hi)]
plt.loglog(mid_point, data_GeV, color='k', ls='-.', lw='2', alpha=1, label = 'CTA North sensivity 50h')

#LHAASO sensitivity
bins_lo = [0.3, 0.6, 1, 2, 2.5, 3, 5, 8, 10, 20, 50, 100, 170, 300] # E_min (TeV)
bins_hi = [0.6, 1, 2, 2.5, 3, 5, 8, 10, 20, 50, 100, 170, 300, 600] # E_max (TeV)
data = [3e-9, 8e-10, 4e-10, 1e-10, 8e-11, 7e-11, 8e-11, 9e-11, 6e-11, 4e-11, 1.5e-11, 2e-11, 5e-11, 7e-11 ] # S (GeV/ cm^2 / s)
mid_point = [np.exp((np.log(i)+np.log(j))/2) * 1000 for i, j in zip(bins_lo, bins_hi)]
plt.loglog(mid_point, data, color='gray', ls='-.', lw='2', alpha=1, label = 'LHAASO sensivity')

# Fermi sensitivity
bins_lo = [5e-5, 7e-5, 2e-4, 4e-4, 6e-4, 1.5e-3, 2e-3, 4e-3, 8e-3,5e-2, 0.1] #in TeV
bins_hi = [7e-5, 2e-4, 4e-4, 6e-4, 1.5e-3, 2e-3, 4e-3, 8e-3, 5e-2,0.1, 0.3] #in TeV
data = [6e-12, 3e-12, 1e-12, 8e-13, 6.5e-13, 3.75e-13, 3e-13, 3.5e-13, 5e-13, 2e-12, 4.25e-12] # S (erg / cm^2 / s)
data_GeV = [i * 624.15064799632 for i in data]
mid_point = [np.exp((np.log(i)+np.log(j))/2) * 1000 for i, j in zip(bins_lo, bins_hi)]
plt.loglog(mid_point, data_GeV, color='k', ls='--', lw='2', alpha=1, label = 'Fermi sensivity')


plt.gca().set_ylim(bottom= 1e-12)
plt.gca().set_xlim(left= 1e-1)

plt.loglog(e_1, (e_1**2*s_1).to('GeV cm-2 s-1'), label= r'$\alpha = 2.3, X_{CRp} = 0.01 $', c = 'g')
plt.loglog(e_2, (e_2**2*s_2).to('GeV cm-2 s-1'), label=r'$\alpha = 2.3, X_{CRp} = 0.02 $', c = 'r')

plt.xlabel('Energy (GeV)')
plt.ylabel('Flux ($GeV/cm^2/s$)')
plt.legend()

# %%
energy = np.logspace(-1,5,100)*u.GeV
e_1, s_1 = clust_Coma_Our.get_gamma_spectrum(energy,Rmax=clust_Coma_Our.R500, type_integral='spherical')
e_2, s_2 = clust_Coma_Our_2.get_gamma_spectrum(energy,Rmax=clust_Coma_Our_2.R500, type_integral='spherical')


# разом з СТА чутливістю
plt.figure(0,figsize=(10,8))
bins_lo = [0.02, 0.0316, 0.0501, 0.0794, 0.126, 0.2, 0.316, 0.501, 0.794, 1.26, 2, 3.16, 5.01, 7.94, 12.6, 20, 31.6, 50.1, 79.4, 126] # E_min (TeV)
bins_hi = [0.0316, 0.0501, 0.0794, 0.126, 0.2, 0.316, 0.501, 0.794, 1.26, 2, 3.16, 5.01, 7.94, 12.6, 20, 31.6, 50.1, 79.4, 126, 200] # E_max (TeV)
data = [2.37e-11, 8.35e-12, 2.02e-12, 9.41e-13, 5.37e-13, 3.58e-13, 2.43e-13, 1.76e-13, 1.35e-13, 1.24e-13, 1.1e-13,
        1.21e-13, 1.44e-13, 2.06e-13, 3.2e-13, 5.1e-13, 7.97e-13, 1.2e-12, 1.93e-12, 3.92e-12] # S (erg / cm^2 / s)
data_GeV = [i * 624.15064799632 for i in data]
mid_point = [np.exp((np.log(i)+np.log(j))/2) * 1000 for i, j in zip(bins_lo, bins_hi)]
plt.loglog(mid_point, data_GeV, color='k', ls='-.', lw='2', alpha=1, label = 'CTA North sensivity 50h')

#LHAASO sensitivity
bins_lo = [0.3, 0.6, 1, 2, 2.5, 3, 5, 8, 10, 20, 50, 100, 170, 300] # E_min (TeV)
bins_hi = [0.6, 1, 2, 2.5, 3, 5, 8, 10, 20, 50, 100, 170, 300, 600] # E_max (TeV)
data = [3e-9, 8e-10, 4e-10, 1e-10, 8e-11, 7e-11, 8e-11, 9e-11, 6e-11, 4e-11, 1.5e-11, 2e-11, 5e-11, 7e-11 ] # S (GeV/ cm^2 / s)
mid_point = [np.exp((np.log(i)+np.log(j))/2) * 1000 for i, j in zip(bins_lo, bins_hi)]
plt.loglog(mid_point, data, color='gray', ls='-.', lw='2', alpha=1, label = 'LHAASO sensivity')

# Fermi sensitivity
bins_lo = [5e-5, 7e-5, 2e-4, 4e-4, 6e-4, 1.5e-3, 2e-3, 4e-3, 8e-3,5e-2, 0.1] #in TeV
bins_hi = [7e-5, 2e-4, 4e-4, 6e-4, 1.5e-3, 2e-3, 4e-3, 8e-3, 5e-2,0.1, 0.3] #in TeV
data = [6e-12, 3e-12, 1e-12, 8e-13, 6.5e-13, 3.75e-13, 3e-13, 3.5e-13, 5e-13, 2e-12, 4.25e-12] # S (erg / cm^2 / s)
data_GeV = [i * 624.15064799632 for i in data]
mid_point = [np.exp((np.log(i)+np.log(j))/2) * 1000 for i, j in zip(bins_lo, bins_hi)]
plt.loglog(mid_point, data_GeV, color='k', ls='--', lw='2', alpha=1, label = 'Fermi sensivity')


plt.gca().set_ylim(bottom= 1e-12)
plt.gca().set_xlim(left= 1e-1)

plt.loglog(e_1, (e_1**2*s_1).to('GeV cm-2 s-1'), label= r'$\alpha = 2.3, X_{CRp} = 0.1 $', c = 'blue')
plt.loglog(e_2, (e_2**2*s_2).to('GeV cm-2 s-1'), label=r'$\alpha = 2.3, X_{CRp} = 0.05 $', c = 'orange')

plt.xlabel('Energy (GeV)')
plt.ylabel('Flux ($GeV/cm^2/s$)')
plt.legend()

# %%
energy = np.logspace(-1,6,100)*u.GeV
x = np.logspace(3,6,10)
y = [1e-9 for i in x]

e_15, n_15 = clust_Coma_Our.get_neutrino_spectrum(energy,Rmax=clust_Coma_Our.R500, type_integral='spherical')
e_20, n_20 = clust_Coma_Remi.get_neutrino_spectrum(energy,Rmax=clust_Coma_Remi.R500, type_integral='spherical')

plt.gca().set_ylim(top = 1e-7)
plt.gca().set_ylim(bottom= 1e-15)
plt.gca().set_xlim(left= 1e-1)
plt.gca().set_xlim(right= 1e6)



plt.loglog(e_15, (e_15**2*n_15).to('GeV cm-2 s-1'), '-', label=r'$\alpha = 1.5, X_{CRp} = 0.05 $', c = 'r')
plt.loglog(e_20, (e_20**2*n_20).to('GeV cm-2 s-1'), '-', label=r'$\alpha = 2.3, X_{CRp} = 0.01 $', c = 'g')
plt.plot(x,y, label = 'Ice Cube discovery potential', c = 'k', ls = '--')

plt.xlabel('Energy (GeV)')
plt.ylabel('Neutrino Flux ($GeV/cm^2/s$)')
plt.legend()

# %%
energy = np.logspace(-1,5,100)*u.GeV
e_1, s_1 = clust_Coma_Remi.get_gamma_spectrum(energy,Rmax=clust_Coma_Remi.R500, type_integral='spherical')
e_2, s_2 = clust_Coma_Our.get_gamma_spectrum(energy,Rmax=clust_Coma_Our.R500, type_integral='spherical')


# разом з СТА чутливістю
plt.figure(0,figsize=(10,8))
bins_lo = [0.02, 0.0316, 0.0501, 0.0794, 0.126, 0.2, 0.316, 0.501, 0.794, 1.26, 2, 3.16, 5.01, 7.94, 12.6, 20, 31.6, 50.1, 79.4, 126] # E_min (TeV)
bins_hi = [0.0316, 0.0501, 0.0794, 0.126, 0.2, 0.316, 0.501, 0.794, 1.26, 2, 3.16, 5.01, 7.94, 12.6, 20, 31.6, 50.1, 79.4, 126, 200] # E_max (TeV)
data = [2.37e-11, 8.35e-12, 2.02e-12, 9.41e-13, 5.37e-13, 3.58e-13, 2.43e-13, 1.76e-13, 1.35e-13, 1.24e-13, 1.1e-13,
        1.21e-13, 1.44e-13, 2.06e-13, 3.2e-13, 5.1e-13, 7.97e-13, 1.2e-12, 1.93e-12, 3.92e-12] # S (erg / cm^2 / s)
data_GeV = [i * 624.15064799632 for i in data]
mid_point = [np.exp((np.log(i)+np.log(j))/2) * 1000 for i, j in zip(bins_lo, bins_hi)]
plt.loglog(mid_point, data_GeV, color='k', ls='-.', lw='2', alpha=1, label = 'CTA North sensivity 50h')

#LHAASO sensitivity
bins_lo = [0.3, 0.6, 1, 2, 2.5, 3, 5, 8, 10, 20, 50, 100, 170, 300] # E_min (TeV)
bins_hi = [0.6, 1, 2, 2.5, 3, 5, 8, 10, 20, 50, 100, 170, 300, 600] # E_max (TeV)
data = [3e-9, 8e-10, 4e-10, 1e-10, 8e-11, 7e-11, 8e-11, 9e-11, 6e-11, 4e-11, 1.5e-11, 2e-11, 5e-11, 7e-11 ] # S (GeV/ cm^2 / s)
mid_point = [np.exp((np.log(i)+np.log(j))/2) * 1000 for i, j in zip(bins_lo, bins_hi)]
plt.loglog(mid_point, data, color='gray', ls='-.', lw='2', alpha=1, label = 'LHAASO sensivity')

# Fermi sensitivity
bins_lo = [5e-5, 7e-5, 2e-4, 4e-4, 6e-4, 1.5e-3, 2e-3, 4e-3, 8e-3,5e-2, 0.1] #in TeV
bins_hi = [7e-5, 2e-4, 4e-4, 6e-4, 1.5e-3, 2e-3, 4e-3, 8e-3, 5e-2,0.1, 0.3] #in TeV
data = [6e-12, 3e-12, 1e-12, 8e-13, 6.5e-13, 3.75e-13, 3e-13, 3.5e-13, 5e-13, 2e-12, 4.25e-12] # S (erg / cm^2 / s)
data_GeV = [i * 624.15064799632 for i in data]
mid_point = [np.exp((np.log(i)+np.log(j))/2) * 1000 for i, j in zip(bins_lo, bins_hi)]
plt.loglog(mid_point, data_GeV, color='k', ls='--', lw='2', alpha=1, label = 'Fermi sensivity')


plt.gca().set_ylim(bottom= 1e-12)
plt.gca().set_xlim(left= 1e-1)

plt.loglog(e_1, (e_1**2*s_1).to('GeV cm-2 s-1'), label= r'$\alpha = 2.3, X_{CRp} = 0.01 $', c = 'g')
plt.loglog(e_2, (e_2**2*s_2).to('GeV cm-2 s-1'), label=r'$\alpha = 1.5, X_{CRp} = 0.05 $', c = 'r')

plt.xlabel('Energy (GeV)')
plt.ylabel('Flux ($GeV/cm^2/s$)')
plt.legend()

# %%
energy = np.logspace(-1,5,100)*u.GeV
e_1, s_1 = clust_Coma_Remi_2.get_gamma_spectrum(energy,Rmax=clust_Coma_Remi_2.R500, type_integral='spherical')
e_2, s_2 = clust_Coma_Our_2.get_gamma_spectrum(energy,Rmax=clust_Coma_Our_2.R500, type_integral='spherical')


# разом з СТА чутливістю
plt.figure(0,figsize=(10,8))
bins_lo = [0.02, 0.0316, 0.0501, 0.0794, 0.126, 0.2, 0.316, 0.501, 0.794, 1.26, 2, 3.16, 5.01, 7.94, 12.6, 20, 31.6, 50.1, 79.4, 126] # E_min (TeV)
bins_hi = [0.0316, 0.0501, 0.0794, 0.126, 0.2, 0.316, 0.501, 0.794, 1.26, 2, 3.16, 5.01, 7.94, 12.6, 20, 31.6, 50.1, 79.4, 126, 200] # E_max (TeV)
data = [2.37e-11, 8.35e-12, 2.02e-12, 9.41e-13, 5.37e-13, 3.58e-13, 2.43e-13, 1.76e-13, 1.35e-13, 1.24e-13, 1.1e-13,
        1.21e-13, 1.44e-13, 2.06e-13, 3.2e-13, 5.1e-13, 7.97e-13, 1.2e-12, 1.93e-12, 3.92e-12] # S (erg / cm^2 / s)
data_GeV = [i * 624.15064799632 for i in data]
mid_point = [np.exp((np.log(i)+np.log(j))/2) * 1000 for i, j in zip(bins_lo, bins_hi)]
plt.loglog(mid_point, data_GeV, color='k', ls='-.', lw='2', alpha=1, label = 'CTA North sensivity 50h')

#LHAASO sensitivity
bins_lo = [0.3, 0.6, 1, 2, 2.5, 3, 5, 8, 10, 20, 50, 100, 170, 300] # E_min (TeV)
bins_hi = [0.6, 1, 2, 2.5, 3, 5, 8, 10, 20, 50, 100, 170, 300, 600] # E_max (TeV)
data = [3e-9, 8e-10, 4e-10, 1e-10, 8e-11, 7e-11, 8e-11, 9e-11, 6e-11, 4e-11, 1.5e-11, 2e-11, 5e-11, 7e-11 ] # S (GeV/ cm^2 / s)
mid_point = [np.exp((np.log(i)+np.log(j))/2) * 1000 for i, j in zip(bins_lo, bins_hi)]
plt.loglog(mid_point, data, color='gray', ls='-.', lw='2', alpha=1, label = 'LHAASO sensivity')

# Fermi sensitivity
bins_lo = [5e-5, 7e-5, 2e-4, 4e-4, 6e-4, 1.5e-3, 2e-3, 4e-3, 8e-3,5e-2, 0.1] #in TeV
bins_hi = [7e-5, 2e-4, 4e-4, 6e-4, 1.5e-3, 2e-3, 4e-3, 8e-3, 5e-2,0.1, 0.3] #in TeV
data = [6e-12, 3e-12, 1e-12, 8e-13, 6.5e-13, 3.75e-13, 3e-13, 3.5e-13, 5e-13, 2e-12, 4.25e-12] # S (erg / cm^2 / s)
data_GeV = [i * 624.15064799632 for i in data]
mid_point = [np.exp((np.log(i)+np.log(j))/2) * 1000 for i, j in zip(bins_lo, bins_hi)]
plt.loglog(mid_point, data_GeV, color='k', ls='--', lw='2', alpha=1, label = 'Fermi sensivity')


plt.gca().set_ylim(bottom= 1e-12)
plt.gca().set_xlim(left= 1e-1)

plt.loglog(e_1, (e_1**2*s_1).to('GeV cm-2 s-1'), label= r'$\alpha = 2.3, X_{CRp} = 0.02 $', c = 'g')
plt.loglog(e_2, (e_2**2*s_2).to('GeV cm-2 s-1'), label=r'$\alpha = 1.5, X_{CRp} = 0.1 $', c = 'r')

plt.xlabel('Energy (GeV)')
plt.ylabel('Flux ($GeV/cm^2/s$)')
plt.legend()

# %%
energy = np.logspace(-1,6,100)*u.GeV
x = np.logspace(3,6,10)
y = [1e-9 for i in x]

e_15, n_15 = clust_Coma_Our_2.get_neutrino_spectrum(energy,Rmax=clust_Coma_Our_2.R500, type_integral='spherical')
e_20, n_20 = clust_Coma_Remi_2.get_neutrino_spectrum(energy,Rmax=clust_Coma_Remi_2.R500, type_integral='spherical')

plt.gca().set_ylim(top = 1e-7)
plt.gca().set_ylim(bottom= 1e-15)
plt.gca().set_xlim(left= 1e-1)
plt.gca().set_xlim(right= 1e6)



plt.loglog(e_15, (e_15**2*n_15).to('GeV cm-2 s-1'), '-', label=r'$\alpha = 1.5, X_{CRp} = 0.1 $', c = 'r')
plt.loglog(e_20, (e_20**2*n_20).to('GeV cm-2 s-1'), '-', label=r'$\alpha = 2.3, X_{CRp} = 0.02 $', c = 'g')
plt.plot(x,y, label = 'Ice Cube discovery potential', c = 'k', ls = '--')

plt.xlabel('Energy (GeV)')
plt.ylabel('Neutrino Flux ($GeV/cm^2/s$)')

plt.legend()

# %%
# потік при розподілі КР пропорційному n

def plot_fermi_coma():
    # батерфляйка
    energy = np.logspace(-1, 1, 100)*u.GeV
    F23_fermi = 5.2e-9
    gamma23 = 2.3
    F20_fermi = 3.2e-9 #ph cm-2 s-1
    gamma20 = 2.0
    N20_fermi = F20_fermi / scipy.integrate.quad(lambda e: e ** (-gamma20), 0.1, 100)[0]
    N23_fermi = F23_fermi / scipy.integrate.quad(lambda e: e ** (-gamma23), 0.1, 100)[0]
    dNdE_20 = N20_fermi * energy.value ** (-gamma20) * u.Unit('GeV-1 cm-2 s-1')
    dNdE_23 = N23_fermi * energy.value ** (-gamma23) * u.Unit('GeV-1 cm-2 s-1')
    plt.fill_between(energy, dNdE_20 * energy**2, dNdE_23 * energy**2, color = 'grey', alpha = 0.5, label = 'Fermi data')

energy = np.logspace(-1,5,100)*u.GeV
e_20, s_20 = clust_Coma_index2.get_gamma_spectrum(energy,Rmax=clust_Coma_index2.R_truncation, type_integral='spherical')
e_23, s_23 = clust_Coma_index23.get_gamma_spectrum(energy,Rmax=clust_Coma_index23.R_truncation, type_integral='spherical')
e_27, s_27 = clust_Coma_index27.get_gamma_spectrum(energy,Rmax=clust_Coma_index27.R_truncation, type_integral='spherical')

plt.figure(figsize=(10, 8))

# разом з СТА чутливістю
bins_lo = [0.02, 0.0316, 0.0501, 0.0794, 0.126, 0.2, 0.316, 0.501, 0.794, 1.26, 2, 3.16, 5.01, 7.94, 12.6, 20, 31.6, 50.1, 79.4, 126] # E_min (TeV)
bins_hi = [0.0316, 0.0501, 0.0794, 0.126, 0.2, 0.316, 0.501, 0.794, 1.26, 2, 3.16, 5.01, 7.94, 12.6, 20, 31.6, 50.1, 79.4, 126, 200] # E_max (TeV)
data = [2.37e-11, 8.35e-12, 2.02e-12, 9.41e-13, 5.37e-13, 3.58e-13, 2.43e-13, 1.76e-13, 1.35e-13, 1.24e-13, 1.1e-13,
        1.21e-13, 1.44e-13, 2.06e-13, 3.2e-13, 5.1e-13, 7.97e-13, 1.2e-12, 1.93e-12, 3.92e-12] # S (erg / cm^2 / s)
data_GeV = [i * 624.15064799632 for i in data]
mid_point = [np.exp((np.log(i)+np.log(j))/2) * 1000 for i, j in zip(bins_lo, bins_hi)]
plt.loglog(mid_point, data_GeV, color='k', ls='-.', lw='2', alpha=1, label = 'CTA North sensivity 50h')

#LHAASO sensitivity
bins_lo = [0.3, 0.6, 1, 2, 2.5, 3, 5, 8, 10, 20, 50, 100, 170, 300] # E_min (TeV)
bins_hi = [0.6, 1, 2, 2.5, 3, 5, 8, 10, 20, 50, 100, 170, 300, 600] # E_max (TeV)
data = [3e-9, 8e-10, 4e-10, 1e-10, 8e-11, 7e-11, 8e-11, 9e-11, 6e-11, 4e-11, 1.5e-11, 2e-11, 5e-11, 7e-11 ] # S (GeV/ cm^2 / s)
mid_point = [np.exp((np.log(i)+np.log(j))/2) * 1000 for i, j in zip(bins_lo, bins_hi)]
plt.loglog(mid_point, data, color='gray', ls='-.', lw='2', alpha=1, label = 'LHAASO sensitivity')


plt.ylim(1e-12, 1e-8)
plt.xlim(1e-1, 1e6)

plt.loglog(e_20, (e_20**2*s_20).to('GeV cm-2 s-1'), '-', label='Index = 2', c = 'k')
plt.loglog(e_23, (e_23**2*s_23).to('GeV cm-2 s-1'), '--', label='Index = 2.3', c = 'k')
plt.loglog(e_27, (e_27**2*s_27).to('GeV cm-2 s-1'), ':', label='Index = 2.7', c = 'k')
    
plot_fermi_coma()

plt.xlabel('Energy (GeV)')
plt.ylabel('Flux ($GeV/cm^2/s$)')
plt.legend()

# %%
clust_Coma_index2.print_param()

# %%
energy = np.logspace(-1,7,100)*u.GeV
x = np.logspace(3,6,10)
y = [1e-9 for i in x]

e_20, n_20 = clust_Coma_index2.get_neutrino_spectrum(energy,Rmax=clust_Coma_index2.R_truncation, type_integral='spherical')
e_23, n_23 = clust_Coma_index23.get_neutrino_spectrum(energy,Rmax=clust_Coma_index23.R_truncation, type_integral='spherical')
e_27, n_27 = clust_Coma_index27.get_neutrino_spectrum(energy,Rmax=clust_Coma_index27.R_truncation, type_integral='spherical')

plt.figure(figsize=(10, 8))
plt.gca().set_ylim(top = 1e-7)
plt.gca().set_ylim(bottom= 1e-15)
plt.gca().set_xlim(left= 1e-1)
plt.gca().set_xlim(right= 1e7)

plt.ylim(1e-12, 1e-8)
plt.xlim(1e-1, 1e6)

plt.loglog(e_20, (e_20**2*n_20).to('GeV cm-2 s-1'), '-', label='Index = 2', c = 'k')
plt.loglog(e_23, (e_23**2*n_23).to('GeV cm-2 s-1'), '-.', label='Index = 2.3', c = 'k')
plt.loglog(e_27, (e_27**2*n_27).to('GeV cm-2 s-1'), ':', label='Index = 2.7', c = 'k')
plt.plot(x,y, label = 'Ice Cube discovery potential', c = 'k', ls = '--', linewidth = 5)

plt.xlabel('Energy (GeV)')
plt.ylabel('Flux ($GeV/cm^2/s$)')
plt.legend()

# %%
# потік при розподілі КР пропорційному n^2

def plot_fermi_coma():
    # батерфляйка
    energy = np.logspace(-1, 1, 100)*u.GeV
    F23_fermi = 5.2e-9
    gamma23 = 2.3
    F20_fermi = 3.2e-9 #ph cm-2 s-1
    gamma20 = 2.0
    N20_fermi = F20_fermi / scipy.integrate.quad(lambda e: e ** (-gamma20), 0.1, 100)[0]
    N23_fermi = F23_fermi / scipy.integrate.quad(lambda e: e ** (-gamma23), 0.1, 100)[0]
    dNdE_20 = N20_fermi * energy.value ** (-gamma20) * u.Unit('GeV-1 cm-2 s-1')
    dNdE_23 = N23_fermi * energy.value ** (-gamma23) * u.Unit('GeV-1 cm-2 s-1')
    plt.fill_between(energy, dNdE_20 * energy**2, dNdE_23 * energy**2, color = 'grey', alpha = 0.5, label = 'Fermi data')

energy = np.logspace(-1,5,100)*u.GeV
e_20, s_20 = clust_Coma_index2_2.get_gamma_spectrum(energy,Rmax=clust_Coma_index2_2.R_truncation, type_integral='spherical')
e_23, s_23 = clust_Coma_index23_2.get_gamma_spectrum(energy,Rmax=clust_Coma_index23_2.R_truncation, type_integral='spherical')
e_27, s_27 = clust_Coma_index27_2.get_gamma_spectrum(energy,Rmax=clust_Coma_index27_2.R_truncation, type_integral='spherical')

plt.figure(figsize=(10, 8))

# разом з СТА чутливістю
bins_lo = [0.02, 0.0316, 0.0501, 0.0794, 0.126, 0.2, 0.316, 0.501, 0.794, 1.26, 2, 3.16, 5.01, 7.94, 12.6, 20, 31.6, 50.1, 79.4, 126] # E_min (TeV)
bins_hi = [0.0316, 0.0501, 0.0794, 0.126, 0.2, 0.316, 0.501, 0.794, 1.26, 2, 3.16, 5.01, 7.94, 12.6, 20, 31.6, 50.1, 79.4, 126, 200] # E_max (TeV)
data = [2.37e-11, 8.35e-12, 2.02e-12, 9.41e-13, 5.37e-13, 3.58e-13, 2.43e-13, 1.76e-13, 1.35e-13, 1.24e-13, 1.1e-13,
        1.21e-13, 1.44e-13, 2.06e-13, 3.2e-13, 5.1e-13, 7.97e-13, 1.2e-12, 1.93e-12, 3.92e-12] # S (erg / cm^2 / s)
data_GeV = [i * 624.15064799632 for i in data]
mid_point = [np.exp((np.log(i)+np.log(j))/2) * 1000 for i, j in zip(bins_lo, bins_hi)]
plt.loglog(mid_point, data_GeV, color='k', ls='-.', lw='2', alpha=1, label = 'CTA North sensivity 50h')

#LHAASO sensitivity
bins_lo = [0.3, 0.6, 1, 2, 2.5, 3, 5, 8, 10, 20, 50, 100, 170, 300] # E_min (TeV)
bins_hi = [0.6, 1, 2, 2.5, 3, 5, 8, 10, 20, 50, 100, 170, 300, 600] # E_max (TeV)
data = [3e-9, 8e-10, 4e-10, 1e-10, 8e-11, 7e-11, 8e-11, 9e-11, 6e-11, 4e-11, 1.5e-11, 2e-11, 5e-11, 7e-11 ] # S (GeV/ cm^2 / s)
mid_point = [np.exp((np.log(i)+np.log(j))/2) * 1000 for i, j in zip(bins_lo, bins_hi)]
plt.loglog(mid_point, data, color='gray', ls='-.', lw='2', alpha=1, label = 'LHAASO sensitivity')

plt.ylim(1e-12, 1e-8)
plt.xlim(1e-1, 1e6)

plt.loglog(e_20, (e_20**2*s_20).to('GeV cm-2 s-1'), '-', label='Index = 2', c = 'k')
plt.loglog(e_23, (e_23**2*s_23).to('GeV cm-2 s-1'), '--', label='Index = 2.3', c = 'k')
plt.loglog(e_27, (e_27**2*s_27).to('GeV cm-2 s-1'), ':', label='Index = 2.7', c = 'k')
    
plot_fermi_coma()

plt.xlabel('Energy (GeV)')
plt.ylabel('Flux ($GeV/cm^2/s$)')
plt.legend()
