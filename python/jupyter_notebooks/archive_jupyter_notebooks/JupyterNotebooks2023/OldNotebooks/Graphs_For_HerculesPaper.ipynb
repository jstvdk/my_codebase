# %%
from matplotlib.colors import SymLogNorm
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from astropy.coordinates.sky_coordinate import SkyCoord
import astropy.units as u
#from astropy.cosmology import Planck15 as cosmo
from astropy.cosmology import FlatLambdaCDM
cosmo = FlatLambdaCDM(H0=70, Om0=0.3, Tcmb0=2.725, Ob0 = 0.0486, m_nu = [0, 0, 0.06] * u.eV)
from astropy.wcs import WCS
from minot import model, model_plots
from astropy import constants as const

# Modify plotting parameters
dict_base = {'font.size':        16,
             'legend.fontsize':  16,
             'xtick.labelsize':  16,
             'ytick.labelsize':  16,
             'axes.labelsize':   16,
             'axes.titlesize':   16,
             'figure.titlesize': 16,    
             'figure.figsize':[8.0, 6.0],
             'figure.subplot.right':0.97,
             'figure.subplot.left':0.15,
             'font.family':'serif',
             'figure.facecolor': 'white',
             'legend.frameon': True}
plt.rcParams.update(dict_base)

# %%
clust_midM_index15_test_smallrc = model.Cluster(name='A2151CB', 
                      redshift=0.0368, M500=9.08e13*u.Msun, 
                      cosmology=cosmo, silent=False, 
                      output_dir='/Users/vdk/Desktop/A2151CB_CRPprop1_TEST')

clust_midM_index15_2_test_smallrc = model.Cluster(name='A2151CB', 
                      redshift=0.0368, M500=9.08e13*u.Msun, 
                      cosmology=cosmo, silent=False, 
                      output_dir='/Users/vdk/Desktop/A2151CB_CRPprop2_TEST')

clust_midM_index15_test_bigrc = model.Cluster(name='A2151CB', 
                      redshift=0.0368, M500=9.08e13*u.Msun, 
                      cosmology=cosmo, silent=False, 
                      output_dir='/Users/vdk/Desktop/A2151CB_CRPprop1_TEST')

clust_midM_index15_2_test_bigrc = model.Cluster(name='A2151CB', 
                      redshift=0.0368, M500=9.08e13*u.Msun, 
                      cosmology=cosmo, silent=False, 
                      output_dir='/Users/vdk/Desktop/A2151CB_CRPprop2_TEST')


clust_lowM = model.Cluster(name='A2151CB', 
                      redshift=0.0368, M500=3.84e13*u.Msun, 
                      cosmology=cosmo, silent=False, 
                      output_dir='/Users/vdk/Desktop/A2151CB_Test')

clust_midM = model.Cluster(name='A2151CB', 
                      redshift=0.0368, M500=9.08e13*u.Msun, 
                      cosmology=cosmo, silent=False, 
                      output_dir='/Users/vdk/Desktop/A2151CB_Test')

clust_highM = model.Cluster(name='A2151CB', 
                      redshift=0.0368, M500=14.32e13*u.Msun, 
                      cosmology=cosmo, silent=False, 
                      output_dir='/Users/vdk/Desktop/A2151CB_Test')


clust_midM_index15 = model.Cluster(name='A2151CB', 
                      redshift=0.0368, M500=9.08e13*u.Msun, 
                      cosmology=cosmo, silent=False, 
                      output_dir='/Users/vdk/Desktop/A2151CB_CRPprop1')

clust_midM_index15_2 = model.Cluster(name='A2151CB', 
                      redshift=0.0368, M500=9.08e13*u.Msun, 
                      cosmology=cosmo, silent=False, 
                      output_dir='/Users/vdk/Desktop/A2151CB_CRPprop2')

clust_midM_index20 = model.Cluster(name='A2151CB', 
                      redshift=0.0368, M500=9.08e13*u.Msun, 
                      cosmology=cosmo, silent=False, 
                      output_dir='/Users/vdk/Desktop/A2151CB_Test')

clust_midM_index20_2 = model.Cluster(name='A2151CB', 
                      redshift=0.0368, M500=9.08e13*u.Msun, 
                      cosmology=cosmo, silent=False, 
                      output_dir='/Users/vdk/Desktop/A2151CB_Prop2')

clust_midM_index23 = model.Cluster(name='A2151CB', 
                      redshift=0.0368, M500=9.08e13*u.Msun, 
                      cosmology=cosmo, silent=False, 
                      output_dir='/Users/vdk/Desktop/A2151CB_Test')

clust_midM_index23_2 = model.Cluster(name='A2151CB', 
                      redshift=0.0368, M500=9.08e13*u.Msun, 
                      cosmology=cosmo, silent=False, 
                      output_dir='/Users/vdk/Desktop/A2151CB_Prop2')



clust_two_index15 = model.Cluster(name='A2151CB', 
                      redshift=0.0368, M500=3.01e13*u.Msun, 
                      cosmology=cosmo, silent=False, 
                      output_dir='/Users/vdk/Desktop/A2151CF_Test')

clust_two_index20 = model.Cluster(name='A2151CB', 
                      redshift=0.0368, M500=3.01e13*u.Msun, 
                      cosmology=cosmo, silent=False, 
                      output_dir='/Users/vdk/Desktop/A2151CF_Test')

clust_two_index23 = model.Cluster(name='A2151CB', 
                      redshift=0.0368, M500=3.01e13*u.Msun, 
                      cosmology=cosmo, silent=False, 
                      output_dir='/Users/vdk/Desktop/A2151CF_Test')


#___________________________________________________________________________________________________________

#A2151CB
clust_lowM.coord = SkyCoord("241.14d  17.72d", frame="icrs", unit="deg")
clust_lowM.density_gas_model = {'name':'beta', 'n_0':0.00875*u.cm**-3, 'beta':0.38, 'r_c':19.35*u.kpc}
clust_lowM.pressure_gas_model = {'name':'GNFW', 'P_0':0.009*u.keV/u.cm**3, 'c500':1.81, 'a':1.33, 'b':4.13, 'c':0.31}
clust_lowM.set_density_crp_isodens_scal_param()
clust_lowM.set_density_cre1_isodens_scal_param()
clust_lowM.spectrum_crp_model = {'name':'ExponentialCutoffPowerLaw', 'Index':1.5, 'CutoffEnergy':30*u.TeV}
clust_lowM.spectrum_cre1_model = {'name':'PowerLaw', 'Index':2.3}
clust_lowM.X_crp_E = {'X':0.1, 'R_norm':clust_lowM.R500} 
clust_lowM.X_cre1_E = {'X':0.01, 'R_norm':clust_lowM.R500} 
clust_lowM.set_magfield_isodens_scal_param(5*u.uG, scal=2/3)
clust_lowM.Epmax = 10e5*u.TeV
clust_lowM.Eemax = 10e5*u.TeV
clust_lowM.abundance = 0.43

clust_midM.coord = SkyCoord("241.14d  17.72d", frame="icrs", unit="deg")
clust_midM.density_gas_model = {'name':'beta', 'n_0':0.00875*u.cm**-3, 'beta':0.38, 'r_c':19.35*u.kpc}
clust_midM.pressure_gas_model = {'name':'GNFW', 'P_0':0.009*u.keV/u.cm**3, 'c500':1.81, 'a':1.33, 'b':4.13, 'c':0.31}
clust_midM.set_density_crp_isodens_scal_param()
clust_midM.set_density_cre1_isodens_scal_param()
clust_midM.spectrum_crp_model = {'name':'ExponentialCutoffPowerLaw', 'Index':1.5, 'CutoffEnergy':30*u.TeV}
clust_midM.spectrum_cre1_model = {'name':'PowerLaw', 'Index':2.3}
clust_midM.X_crp_E = {'X':0.1, 'R_norm':clust_midM.R500} 
clust_midM.X_cre1_E = {'X':0.01, 'R_norm':clust_midM.R500} 
clust_midM.set_magfield_isodens_scal_param(5*u.uG, scal=2/3)
clust_midM.Epmax = 10e5*u.TeV
clust_midM.Eemax = 10e5*u.TeV
clust_midM.abundance = 0.43

clust_highM.coord = SkyCoord("241.14d  17.72d", frame="icrs", unit="deg")
clust_highM.density_gas_model = {'name':'beta', 'n_0':0.00875*u.cm**-3, 'beta':0.38, 'r_c':19.35*u.kpc}
clust_highM.pressure_gas_model = {'name':'GNFW', 'P_0':0.009*u.keV/u.cm**3, 'c500':1.81, 'a':1.33, 'b':4.13, 'c':0.31}
clust_highM.set_density_crp_isodens_scal_param()
clust_highM.set_density_cre1_isodens_scal_param()
clust_highM.spectrum_crp_model = {'name':'ExponentialCutoffPowerLaw', 'Index':1.5, 'CutoffEnergy':30*u.TeV}
clust_highM.spectrum_cre1_model = {'name':'PowerLaw', 'Index':2.3}
clust_highM.X_crp_E = {'X':0.1, 'R_norm':clust_highM.R500} 
clust_highM.X_cre1_E = {'X':0.01, 'R_norm':clust_highM.R500} 
clust_highM.set_magfield_isodens_scal_param(5*u.uG, scal=2/3)
clust_highM.Epmax = 10e5*u.TeV
clust_highM.Eemax = 10e5*u.TeV
clust_highM.abundance = 0.43

#___________________________________________________________________________________________________________

# A2151CB different index

clust_midM_index15.coord = SkyCoord("241.14d  17.72d", frame="icrs", unit="deg")
clust_midM_index15.density_gas_model = {'name':'beta', 'n_0':0.00875*u.cm**-3, 'beta':0.38, 'r_c':19.35*u.kpc}
clust_midM_index15.pressure_gas_model = {'name':'GNFW', 'P_0':0.009*u.keV/u.cm**3, 'c500':1.81, 'a':1.33, 'b':4.13, 'c':0.31}
clust_midM_index15.set_density_crp_isodens_scal_param(scal=1)
clust_midM_index15.set_density_cre1_isodens_scal_param()
clust_midM_index15.spectrum_crp_model = {'name':'ExponentialCutoffPowerLaw', 'Index':1.5, 'CutoffEnergy':1000*u.TeV}
clust_midM_index15.spectrum_cre1_model = {'name':'PowerLaw', 'Index':2.3}
clust_midM_index15.X_crp_E = {'X':0.1, 'R_norm':clust_midM_index15.R500} 
clust_midM_index15.X_cre1_E = {'X':0.01, 'R_norm':clust_midM_index15.R500} 
clust_midM_index15.set_magfield_isodens_scal_param(5*u.uG, scal=2/3)
clust_midM_index15.Epmax = 10e5*u.TeV
clust_midM_index15.Eemax = 10e5*u.TeV
clust_midM_index15.abundance = 0.43

clust_midM_index15_2.coord = SkyCoord("241.14d  17.72d", frame="icrs", unit="deg")
clust_midM_index15_2.density_gas_model = {'name':'beta', 'n_0':0.00875*u.cm**-3, 'beta':0.38, 'r_c':19.35*u.kpc}
clust_midM_index15_2.pressure_gas_model = {'name':'GNFW', 'P_0':0.009*u.keV/u.cm**3, 'c500':1.81, 'a':1.33, 'b':4.13, 'c':0.31}
clust_midM_index15_2.set_density_crp_isodens_scal_param(scal=2)
clust_midM_index15_2.set_density_cre1_isodens_scal_param()
clust_midM_index15_2.spectrum_crp_model = {'name':'ExponentialCutoffPowerLaw', 'Index':1.5, 'CutoffEnergy':30*u.TeV}
clust_midM_index15_2.spectrum_cre1_model = {'name':'PowerLaw', 'Index':2.3}
clust_midM_index15_2.X_crp_E = {'X':0.1, 'R_norm':clust_midM_index15.R500} 
clust_midM_index15_2.X_cre1_E = {'X':0.01, 'R_norm':clust_midM_index15.R500} 
clust_midM_index15_2.set_magfield_isodens_scal_param(5*u.uG, scal=2/3)
clust_midM_index15_2.Epmax = 10e5*u.TeV
clust_midM_index15_2.Eemax = 10e5*u.TeV
clust_midM_index15_2.abundance = 0.43

clust_midM_index20.coord = SkyCoord("241.14d  17.72d", frame="icrs", unit="deg")
clust_midM_index20.density_gas_model = {'name':'beta', 'n_0':0.00875*u.cm**-3, 'beta':0.38, 'r_c':19.35*u.kpc}
clust_midM_index20.pressure_gas_model = {'name':'GNFW', 'P_0':0.009*u.keV/u.cm**3, 'c500':1.81, 'a':1.33, 'b':4.13, 'c':0.31}
clust_midM_index20.set_density_crp_isodens_scal_param(scal=1)
clust_midM_index20.set_density_cre1_isodens_scal_param()
clust_midM_index20.spectrum_crp_model = {'name':'ExponentialCutoffPowerLaw', 'Index':2.0, 'CutoffEnergy':1000*u.TeV}
clust_midM_index20.spectrum_cre1_model = {'name':'PowerLaw', 'Index':2.3}
clust_midM_index20.X_crp_E = {'X':0.1, 'R_norm':clust_midM_index20.R500} 
clust_midM_index20.X_cre1_E = {'X':0.01, 'R_norm':clust_midM_index20.R500} 
clust_midM_index20.set_magfield_isodens_scal_param(5*u.uG, scal=2/3)
clust_midM_index20.Epmax = 10e5*u.TeV
clust_midM_index20.Eemax = 10e5*u.TeV
clust_midM_index20.abundance = 0.43

clust_midM_index20_2.coord = SkyCoord("241.14d  17.72d", frame="icrs", unit="deg")
clust_midM_index20_2.density_gas_model = {'name':'beta', 'n_0':0.00875*u.cm**-3, 'beta':0.38, 'r_c':19.35*u.kpc}
clust_midM_index20_2.pressure_gas_model = {'name':'GNFW', 'P_0':0.009*u.keV/u.cm**3, 'c500':1.81, 'a':1.33, 'b':4.13, 'c':0.31}
clust_midM_index20_2.set_density_crp_isodens_scal_param(scal=2)
clust_midM_index20_2.set_density_cre1_isodens_scal_param()
clust_midM_index20_2.spectrum_crp_model = {'name':'ExponentialCutoffPowerLaw', 'Index':2.0, 'CutoffEnergy':30*u.TeV}
clust_midM_index20_2.spectrum_cre1_model = {'name':'PowerLaw', 'Index':2.3}
clust_midM_index20_2.X_crp_E = {'X':0.1, 'R_norm':clust_midM_index20.R500} 
clust_midM_index20_2.X_cre1_E = {'X':0.01, 'R_norm':clust_midM_index20.R500} 
clust_midM_index20_2.set_magfield_isodens_scal_param(5*u.uG, scal=2/3)
clust_midM_index20_2.Epmax = 10e5*u.TeV
clust_midM_index20_2.Eemax = 10e5*u.TeV
clust_midM_index20_2.abundance = 0.43

clust_midM_index23.coord = SkyCoord("241.14d  17.72d", frame="icrs", unit="deg")
clust_midM_index23.density_gas_model = {'name':'beta', 'n_0':0.00875*u.cm**-3, 'beta':0.38, 'r_c':19.35*u.kpc}
clust_midM_index23.pressure_gas_model = {'name':'GNFW', 'P_0':0.009*u.keV/u.cm**3, 'c500':1.81, 'a':1.33, 'b':4.13, 'c':0.31}
clust_midM_index23.set_density_crp_isodens_scal_param(scal=1)
clust_midM_index23.set_density_cre1_isodens_scal_param()
clust_midM_index23.spectrum_crp_model = {'name':'ExponentialCutoffPowerLaw', 'Index':2.3, 'CutoffEnergy':1000*u.TeV}
clust_midM_index23.spectrum_cre1_model = {'name':'PowerLaw', 'Index':2.3}
clust_midM_index23.X_crp_E = {'X':0.1, 'R_norm':clust_midM_index23.R500} 
clust_midM_index23.X_cre1_E = {'X':0.01, 'R_norm':clust_midM_index23.R500} 
clust_midM_index23.set_magfield_isodens_scal_param(5*u.uG, scal=2/3)
clust_midM_index23.Epmax = 10e5*u.TeV
clust_midM_index23.Eemax = 10e5*u.TeV
clust_midM_index23.abundance = 0.43

clust_midM_index23_2.coord = SkyCoord("241.14d  17.72d", frame="icrs", unit="deg")
clust_midM_index23_2.density_gas_model = {'name':'beta', 'n_0':0.00875*u.cm**-3, 'beta':0.38, 'r_c':19.35*u.kpc}
clust_midM_index23_2.pressure_gas_model = {'name':'GNFW', 'P_0':0.009*u.keV/u.cm**3, 'c500':1.81, 'a':1.33, 'b':4.13, 'c':0.31}
clust_midM_index23_2.set_density_crp_isodens_scal_param(scal=1)
clust_midM_index23_2.set_density_cre1_isodens_scal_param()
clust_midM_index23_2.spectrum_crp_model = {'name':'ExponentialCutoffPowerLaw', 'Index':2.3, 'CutoffEnergy':30*u.TeV}
clust_midM_index23_2.spectrum_cre1_model = {'name':'PowerLaw', 'Index':2.3}
clust_midM_index23_2.X_crp_E = {'X':0.1, 'R_norm':clust_midM_index23.R500} 
clust_midM_index23_2.X_cre1_E = {'X':0.01, 'R_norm':clust_midM_index23.R500} 
clust_midM_index23_2.set_magfield_isodens_scal_param(5*u.uG, scal=2/3)
clust_midM_index23_2.Epmax = 10e5*u.TeV
clust_midM_index23_2.Eemax = 10e5*u.TeV
clust_midM_index23_2.abundance = 0.43

#___________________________________________________________________________________________________________

# A2151CF
clust_two_index15.coord = SkyCoord("241.28d  17.72d", frame="icrs", unit="deg")
clust_two_index15.density_gas_model = {'name':'beta', 'n_0':0.0049*u.cm**-3, 'beta':0.38, 'r_c':10.43*u.kpc}
clust_two_index15.pressure_gas_model = {'name':'GNFW', 'P_0':0.0077*u.keV/u.cm**3, 'c500':1.81, 'a':1.33, 'b':4.13, 'c':0.31}
clust_two_index15.set_density_crp_isodens_scal_param()
clust_two_index15.set_density_cre1_isodens_scal_param()
clust_two_index15.spectrum_crp_model = {'name':'ExponentialCutoffPowerLaw', 'Index':1.5, 'CutoffEnergy':30*u.TeV}
clust_two_index15.spectrum_cre1_model = {'name':'PowerLaw', 'Index':2.3}
clust_two_index15.X_crp_E = {'X':0.1, 'R_norm':clust_two_index15.R500} 
clust_two_index15.X_cre1_E = {'X':0.01, 'R_norm':clust_two_index15.R500} 
clust_two_index15.set_magfield_isodens_scal_param(5*u.uG, scal=2/3)
clust_two_index15.Epmax = 10e5*u.TeV
clust_two_index15.Eemax = 10e5*u.TeV
clust_two_index15.abundance = 0.13

clust_two_index20.coord = SkyCoord("241.28d  17.72d", frame="icrs", unit="deg")
clust_two_index20.density_gas_model = {'name':'beta', 'n_0':0.0049*u.cm**-3, 'beta':0.38, 'r_c':10.43*u.kpc}
clust_two_index20.pressure_gas_model = {'name':'GNFW', 'P_0':0.0077*u.keV/u.cm**3, 'c500':1.81, 'a':1.33, 'b':4.13, 'c':0.31}
clust_two_index20.set_density_crp_isodens_scal_param()
clust_two_index20.set_density_cre1_isodens_scal_param()
clust_two_index20.spectrum_crp_model = {'name':'ExponentialCutoffPowerLaw', 'Index':2.0, 'CutoffEnergy':30*u.TeV}
clust_two_index20.spectrum_cre1_model = {'name':'PowerLaw', 'Index':2.3}
clust_two_index20.X_crp_E = {'X':0.1, 'R_norm':clust_two_index20.R500} 
clust_two_index20.X_cre1_E = {'X':0.01, 'R_norm':clust_two_index20.R500} 
clust_two_index20.set_magfield_isodens_scal_param(5*u.uG, scal=2/3)
clust_two_index20.Epmax = 10e5*u.TeV
clust_two_index20.Eemax = 10e5*u.TeV
clust_two_index20.abundance = 0.13

clust_two_index23.coord = SkyCoord("241.28d  17.72d", frame="icrs", unit="deg")
clust_two_index23.density_gas_model = {'name':'beta', 'n_0':0.0049*u.cm**-3, 'beta':0.38, 'r_c':10.43*u.kpc}
clust_two_index23.pressure_gas_model = {'name':'GNFW', 'P_0':0.0077*u.keV/u.cm**3, 'c500':1.81, 'a':1.33, 'b':4.13, 'c':0.31}
clust_two_index23.set_density_crp_isodens_scal_param()
clust_two_index23.set_density_cre1_isodens_scal_param()
clust_two_index23.spectrum_crp_model = {'name':'ExponentialCutoffPowerLaw', 'Index':2.3, 'CutoffEnergy':30*u.TeV}
clust_two_index23.spectrum_cre1_model = {'name':'PowerLaw', 'Index':2.3}
clust_two_index23.X_crp_E = {'X':0.1, 'R_norm':clust_two_index23.R500} 
clust_two_index23.X_cre1_E = {'X':0.01, 'R_norm':clust_two_index23.R500} 
clust_two_index23.set_magfield_isodens_scal_param(5*u.uG, scal=2/3)
clust_two_index23.Epmax = 10e5*u.TeV
clust_two_index23.Eemax = 10e5*u.TeV
clust_two_index23.abundance = 0.13


# TEST

clust_midM_index15_test_smallrc.coord = SkyCoord("241.14d  17.72d", frame="icrs", unit="deg")
clust_midM_index15_test_smallrc.density_gas_model = {'name':'beta', 'n_0':0.00875*u.cm**-3, 'beta':0.38, 'r_c':1.935*u.kpc}
clust_midM_index15_test_smallrc.pressure_gas_model = {'name':'GNFW', 'P_0':0.009*u.keV/u.cm**3, 'c500':1.81, 'a':1.33, 'b':4.13, 'c':0.31}
clust_midM_index15_test_smallrc.set_density_crp_isodens_scal_param(scal=1)
clust_midM_index15_test_smallrc.set_density_cre1_isodens_scal_param()
clust_midM_index15_test_smallrc.spectrum_crp_model = {'name':'ExponentialCutoffPowerLaw', 'Index':1.5, 'CutoffEnergy':30*u.TeV}
clust_midM_index15_test_smallrc.spectrum_cre1_model = {'name':'PowerLaw', 'Index':2.3}
clust_midM_index15_test_smallrc.X_crp_E = {'X':0.1, 'R_norm':clust_midM_index15_test_smallrc.R500} 
clust_midM_index15_test_smallrc.X_cre1_E = {'X':0.01, 'R_norm':clust_midM_index15_test_smallrc.R500} 
clust_midM_index15_test_smallrc.set_magfield_isodens_scal_param(5*u.uG, scal=2/3)
clust_midM_index15_test_smallrc.Epmax = 10e5*u.TeV
clust_midM_index15_test_smallrc.Eemax = 10e5*u.TeV
clust_midM_index15_test_smallrc.abundance = 0.43

clust_midM_index15_2_test_smallrc.coord = SkyCoord("241.14d  17.72d", frame="icrs", unit="deg")
clust_midM_index15_2_test_smallrc.density_gas_model = {'name':'beta', 'n_0':0.00875*u.cm**-3, 'beta':0.38, 'r_c':1.935*u.kpc}
clust_midM_index15_2_test_smallrc.pressure_gas_model = {'name':'GNFW', 'P_0':0.009*u.keV/u.cm**3, 'c500':1.81, 'a':1.33, 'b':4.13, 'c':0.31}
clust_midM_index15_2_test_smallrc.set_density_crp_isodens_scal_param(scal=2)
clust_midM_index15_2_test_smallrc.set_density_cre1_isodens_scal_param()
clust_midM_index15_2_test_smallrc.spectrum_crp_model = {'name':'ExponentialCutoffPowerLaw', 'Index':1.5, 'CutoffEnergy':30*u.TeV}
clust_midM_index15_2_test_smallrc.spectrum_cre1_model = {'name':'PowerLaw', 'Index':2.3}
clust_midM_index15_2_test_smallrc.X_crp_E = {'X':0.1, 'R_norm':clust_midM_index15_test_smallrc.R500} 
clust_midM_index15_2_test_smallrc.X_cre1_E = {'X':0.01, 'R_norm':clust_midM_index15_test_smallrc.R500} 
clust_midM_index15_2_test_smallrc.set_magfield_isodens_scal_param(5*u.uG, scal=2/3)
clust_midM_index15_2_test_smallrc.Epmax = 10e5*u.TeV
clust_midM_index15_2_test_smallrc.Eemax = 10e5*u.TeV
clust_midM_index15_2_test_smallrc.abundance = 0.43

clust_midM_index15_test_bigrc.coord = SkyCoord("241.14d  17.72d", frame="icrs", unit="deg")
clust_midM_index15_test_bigrc.density_gas_model = {'name':'beta', 'n_0':0.00875*u.cm**-3, 'beta':0.38, 'r_c':193.5*u.kpc}
clust_midM_index15_test_bigrc.pressure_gas_model = {'name':'GNFW', 'P_0':0.009*u.keV/u.cm**3, 'c500':1.81, 'a':1.33, 'b':4.13, 'c':0.31}
clust_midM_index15_test_bigrc.set_density_crp_isodens_scal_param(scal=1)
clust_midM_index15_test_bigrc.set_density_cre1_isodens_scal_param()
clust_midM_index15_test_bigrc.spectrum_crp_model = {'name':'ExponentialCutoffPowerLaw', 'Index':1.5, 'CutoffEnergy':30*u.TeV}
clust_midM_index15_test_bigrc.spectrum_cre1_model = {'name':'PowerLaw', 'Index':2.3}
clust_midM_index15_test_bigrc.X_crp_E = {'X':0.1, 'R_norm':clust_midM_index15_test_bigrc.R500} 
clust_midM_index15_test_bigrc.X_cre1_E = {'X':0.01, 'R_norm':clust_midM_index15_test_bigrc.R500} 
clust_midM_index15_test_bigrc.set_magfield_isodens_scal_param(5*u.uG, scal=2/3)
clust_midM_index15_test_bigrc.Epmax = 10e5*u.TeV
clust_midM_index15_test_bigrc.Eemax = 10e5*u.TeV
clust_midM_index15_test_bigrc.abundance = 0.43

clust_midM_index15_2_test_bigrc.coord = SkyCoord("241.14d  17.72d", frame="icrs", unit="deg")
clust_midM_index15_2_test_bigrc.density_gas_model = {'name':'beta', 'n_0':0.00875*u.cm**-3, 'beta':0.38, 'r_c':193.5*u.kpc}
clust_midM_index15_2_test_bigrc.pressure_gas_model = {'name':'GNFW', 'P_0':0.009*u.keV/u.cm**3, 'c500':1.81, 'a':1.33, 'b':4.13, 'c':0.31}
clust_midM_index15_2_test_bigrc.set_density_crp_isodens_scal_param(scal=2)
clust_midM_index15_2_test_bigrc.set_density_cre1_isodens_scal_param()
clust_midM_index15_2_test_bigrc.spectrum_crp_model = {'name':'ExponentialCutoffPowerLaw', 'Index':1.5, 'CutoffEnergy':30*u.TeV}
clust_midM_index15_2_test_bigrc.spectrum_cre1_model = {'name':'PowerLaw', 'Index':2.3}
clust_midM_index15_2_test_bigrc.X_crp_E = {'X':0.1, 'R_norm':clust_midM_index15_2_test_bigrc.R500} 
clust_midM_index15_2_test_bigrc.X_cre1_E = {'X':0.01, 'R_norm':clust_midM_index15_2_test_bigrc.R500} 
clust_midM_index15_2_test_bigrc.set_magfield_isodens_scal_param(5*u.uG, scal=2/3)
clust_midM_index15_2_test_bigrc.Epmax = 10e5*u.TeV
clust_midM_index15_2_test_bigrc.Eemax = 10e5*u.TeV
clust_midM_index15_2_test_bigrc.abundance = 0.43

# %%
energy = np.logspace(-1,5,100)*u.GeV
e1, s1 = clust_lowM.get_gamma_spectrum(energy,Rmax=clust_lowM.R_truncation, type_integral='spherical')
e2, s2 = clust_midM.get_gamma_spectrum(energy,Rmax=clust_midM.R_truncation, type_integral='spherical')
e3, s3 = clust_highM.get_gamma_spectrum(energy,Rmax=clust_highM.R_truncation, type_integral='spherical')

# разом з СТА чутливістю
plt.figure(0,figsize=(10,8))
bins_lo = [0.02, 0.0316, 0.0501, 0.0794, 0.126, 0.2, 0.316, 0.501, 0.794, 1.26, 2, 3.16, 5.01, 7.94, 12.6, 20, 31.6, 50.1, 79.4, 126] # E_min (TeV)
bins_hi = [0.0316, 0.0501, 0.0794, 0.126, 0.2, 0.316, 0.501, 0.794, 1.26, 2, 3.16, 5.01, 7.94, 12.6, 20, 31.6, 50.1, 79.4, 126, 200] # E_max (TeV)
data = [2.37e-11, 8.35e-12, 2.02e-12, 9.41e-13, 5.37e-13, 3.58e-13, 2.43e-13, 1.76e-13, 1.35e-13, 1.24e-13, 1.1e-13,
        1.21e-13, 1.44e-13, 2.06e-13, 3.2e-13, 5.1e-13, 7.97e-13, 1.2e-12, 1.93e-12, 3.92e-12] # S (erg / cm^2 / s)
data_GeV = [i * 624.15064799632 for i in data]
mid_point = [np.exp((np.log(i)+np.log(j))/2) * 1000 for i, j in zip(bins_lo, bins_hi)]
plt.loglog(mid_point, data_GeV, color='k', ls='-.', lw='2', alpha=1, label = 'CTA North sensivity 50h')

#LHAASO sensitivity
bins_lo = [0.3, 0.6, 1, 2, 2.5, 3, 5, 8, 10, 20, 50, 100, 170, 300] # E_min (TeV)
bins_hi = [0.6, 1, 2, 2.5, 3, 5, 8, 10, 20, 50, 100, 170, 300, 600] # E_max (TeV)
data = [3e-9, 8e-10, 4e-10, 1e-10, 8e-11, 7e-11, 8e-11, 9e-11, 6e-11, 4e-11, 1.5e-11, 2e-11, 5e-11, 7e-11 ] # S (GeV/ cm^2 / s)
mid_point = [np.exp((np.log(i)+np.log(j))/2) * 1000 for i, j in zip(bins_lo, bins_hi)]
plt.loglog(mid_point, data, color='grey', ls='-.', lw='2', alpha=1, label = 'LHAASO sensivity')

# Fermi sensitivity
bins_lo = [5e-5, 7e-5, 2e-4, 4e-4, 6e-4, 1.5e-3, 2e-3, 4e-3, 8e-3,5e-2, 0.1] #in TeV
bins_hi = [7e-5, 2e-4, 4e-4, 6e-4, 1.5e-3, 2e-3, 4e-3, 8e-3, 5e-2,0.1, 0.3] #in TeV
data = [6e-12, 3e-12, 1e-12, 8e-13, 6.5e-13, 3.75e-13, 3e-13, 3.5e-13, 5e-13, 2e-12, 4.25e-12] # S (erg / cm^2 / s)
data_GeV = [i * 624.15064799632 for i in data]
mid_point = [np.exp((np.log(i)+np.log(j))/2) * 1000 for i, j in zip(bins_lo, bins_hi)]
plt.loglog(mid_point, data_GeV, color='grey', ls='-.', lw='2', alpha=0.5, label = 'Fermi sensivity')

sum = s1 + s2
plt.gca().set_ylim(bottom= 1e-12)
plt.gca().set_xlim(left= 1e-1)

plt.loglog(e1, (e1**2*s1).to('GeV cm-2 s-1'), ':', label='$M_{500} - \Delta M$', c = 'k')
plt.loglog(e2, (e2**2*s2).to('GeV cm-2 s-1'), '--', label='$M_{500}$', c = 'k')
plt.loglog(e3, (e3**2*s3).to('GeV cm-2 s-1'), '-', label='$M_{500} + \Delta M$', c = 'k')
plt.xlabel('Energy (GeV)')
plt.ylabel('Flux ($GeV/cm^2/s$)')
plt.legend()

# %%
energy = np.logspace(-1,5,100)*u.GeV
e_15, s_15 = clust_midM_index15.get_gamma_spectrum(energy,Rmax=clust_midM_index15.R_truncation, type_integral='spherical')
e_20, s_20 = clust_midM_index20.get_gamma_spectrum(energy,Rmax=clust_midM_index20.R_truncation, type_integral='spherical')
e_23, s_23 = clust_midM_index23.get_gamma_spectrum(energy,Rmax=clust_midM_index23.R_truncation, type_integral='spherical')


# разом з СТА чутливістю
plt.figure(0,figsize=(10,8))
bins_lo = [0.02, 0.0316, 0.0501, 0.0794, 0.126, 0.2, 0.316, 0.501, 0.794, 1.26, 2, 3.16, 5.01, 7.94, 12.6, 20, 31.6, 50.1, 79.4, 126] # E_min (TeV)
bins_hi = [0.0316, 0.0501, 0.0794, 0.126, 0.2, 0.316, 0.501, 0.794, 1.26, 2, 3.16, 5.01, 7.94, 12.6, 20, 31.6, 50.1, 79.4, 126, 200] # E_max (TeV)
data = [2.37e-11, 8.35e-12, 2.02e-12, 9.41e-13, 5.37e-13, 3.58e-13, 2.43e-13, 1.76e-13, 1.35e-13, 1.24e-13, 1.1e-13,
        1.21e-13, 1.44e-13, 2.06e-13, 3.2e-13, 5.1e-13, 7.97e-13, 1.2e-12, 1.93e-12, 3.92e-12] # S (erg / cm^2 / s)
data_GeV = [i * 624.15064799632 for i in data]
mid_point = [np.exp((np.log(i)+np.log(j))/2) * 1000 for i, j in zip(bins_lo, bins_hi)]
plt.loglog(mid_point, data_GeV, color='k', ls='-.', lw='2', alpha=1, label = 'CTA North sensivity 50h')

#LHAASO sensitivity
bins_lo = [0.3, 0.6, 1, 2, 2.5, 3, 5, 8, 10, 20, 50, 100, 170, 300] # E_min (TeV)
bins_hi = [0.6, 1, 2, 2.5, 3, 5, 8, 10, 20, 50, 100, 170, 300, 600] # E_max (TeV)
data = [3e-9, 8e-10, 4e-10, 1e-10, 8e-11, 7e-11, 8e-11, 9e-11, 6e-11, 4e-11, 1.5e-11, 2e-11, 5e-11, 7e-11 ] # S (GeV/ cm^2 / s)
mid_point = [np.exp((np.log(i)+np.log(j))/2) * 1000 for i, j in zip(bins_lo, bins_hi)]
plt.loglog(mid_point, data, color='gray', ls='-.', lw='2', alpha=1, label = 'LHAASO sensivity')

# Fermi sensitivity
bins_lo = [5e-5, 7e-5, 2e-4, 4e-4, 6e-4, 1.5e-3, 2e-3, 4e-3, 8e-3,5e-2, 0.1] #in TeV
bins_hi = [7e-5, 2e-4, 4e-4, 6e-4, 1.5e-3, 2e-3, 4e-3, 8e-3, 5e-2,0.1, 0.3] #in TeV
data = [6e-12, 3e-12, 1e-12, 8e-13, 6.5e-13, 3.75e-13, 3e-13, 3.5e-13, 5e-13, 2e-12, 4.25e-12] # S (erg / cm^2 / s)
data_GeV = [i * 624.15064799632 for i in data]
mid_point = [np.exp((np.log(i)+np.log(j))/2) * 1000 for i, j in zip(bins_lo, bins_hi)]
plt.loglog(mid_point, data_GeV, color='grey', ls='-.', lw='2', alpha=0.5, label = 'Fermi sensivity')



sum = s1 + s2
plt.gca().set_ylim(bottom= 1e-12)
plt.gca().set_xlim(left= 1e-1)

plt.loglog(e_15, (e_15**2*s_15).to('GeV cm-2 s-1'), '-', label='Index = 1.5', c = 'k')
plt.loglog(e_20, (e_20**2*s_20).to('GeV cm-2 s-1'), '--', label='Index = 2', c = 'k')
plt.loglog(e_23, (e_23**2*s_23).to('GeV cm-2 s-1'), ':', label='Index = 2.3', c = 'k')
plt.xlabel('Energy (GeV)')
plt.ylabel('Flux ($GeV/cm^2/s$)')
plt.legend()

# %%
energy = np.logspace(-1,5,100)*u.GeV
e1, s1 = clust_two_index15.get_gamma_spectrum(energy,Rmax=clust_two_index15.R_truncation, type_integral='spherical')
e2, s2 = clust_two_index20.get_gamma_spectrum(energy,Rmax=clust_two_index20.R_truncation, type_integral='spherical')
e3, s3 = clust_two_index23.get_gamma_spectrum(energy,Rmax=clust_two_index23.R_truncation, type_integral='spherical')

# разом з СТА чутливістю
plt.figure(0,figsize=(10,8))
bins_lo = [0.02, 0.0316, 0.0501, 0.0794, 0.126, 0.2, 0.316, 0.501, 0.794, 1.26, 2, 3.16, 5.01, 7.94, 12.6, 20, 31.6, 50.1, 79.4, 126] # E_min (TeV)
bins_hi = [0.0316, 0.0501, 0.0794, 0.126, 0.2, 0.316, 0.501, 0.794, 1.26, 2, 3.16, 5.01, 7.94, 12.6, 20, 31.6, 50.1, 79.4, 126, 200] # E_max (TeV)
data = [2.37e-11, 8.35e-12, 2.02e-12, 9.41e-13, 5.37e-13, 3.58e-13, 2.43e-13, 1.76e-13, 1.35e-13, 1.24e-13, 1.1e-13,
        1.21e-13, 1.44e-13, 2.06e-13, 3.2e-13, 5.1e-13, 7.97e-13, 1.2e-12, 1.93e-12, 3.92e-12] # S (erg / cm^2 / s)
data_GeV = [i * 624.15064799632 for i in data]
mid_point = [np.exp((np.log(i)+np.log(j))/2) * 1000 for i, j in zip(bins_lo, bins_hi)]
plt.loglog(mid_point, data_GeV, color='k', ls='-.', lw='2', alpha=1, label = 'CTA North sensivity 50h')

#LHAASO sensitivity
bins_lo = [0.3, 0.6, 1, 2, 2.5, 3, 5, 8, 10, 20, 50, 100, 170, 300] # E_min (TeV)
bins_hi = [0.6, 1, 2, 2.5, 3, 5, 8, 10, 20, 50, 100, 170, 300, 600] # E_max (TeV)
data = [3e-9, 8e-10, 4e-10, 1e-10, 8e-11, 7e-11, 8e-11, 9e-11, 6e-11, 4e-11, 1.5e-11, 2e-11, 5e-11, 7e-11 ] # S (GeV/ cm^2 / s)
mid_point = [np.exp((np.log(i)+np.log(j))/2) * 1000 for i, j in zip(bins_lo, bins_hi)]
plt.loglog(mid_point, data, color='gray', ls='-.', lw='2', alpha=1, label = 'LHAASO sensivity')

# Fermi sensitivity
bins_lo = [5e-5, 7e-5, 2e-4, 4e-4, 6e-4, 1.5e-3, 2e-3, 4e-3, 8e-3,5e-2, 0.1] #in TeV
bins_hi = [7e-5, 2e-4, 4e-4, 6e-4, 1.5e-3, 2e-3, 4e-3, 8e-3, 5e-2,0.1, 0.3] #in TeV
data = [6e-12, 3e-12, 1e-12, 8e-13, 6.5e-13, 3.75e-13, 3e-13, 3.5e-13, 5e-13, 2e-12, 4.25e-12] # S (erg / cm^2 / s)
data_GeV = [i * 624.15064799632 for i in data]
mid_point = [np.exp((np.log(i)+np.log(j))/2) * 1000 for i, j in zip(bins_lo, bins_hi)]
plt.loglog(mid_point, data_GeV, color='grey', ls='-.', lw='2', alpha=0.5, label = 'Fermi sensivity')



sum = s1 + s2
plt.gca().set_ylim(bottom= 1e-12)
plt.gca().set_xlim(left= 1e-1)

plt.loglog(e1, (e1**2*s1).to('GeV cm-2 s-1'), '-', label='Index = 1.5', c = 'k')
plt.loglog(e2, (e2**2*s2).to('GeV cm-2 s-1'), '--', label='Index = 2', c = 'k')
plt.loglog(e3, (e3**2*s3).to('GeV cm-2 s-1'), ':', label='Index = 2.3', c = 'k')
plt.xlabel('Energy (GeV)')
plt.ylabel('Flux ($GeV/cm^2/s$)')
plt.legend()

# %%
s2

# %%
clust_midM_index20.print_param()

# %%
# Defines the grid
clust_midM_index15.map_reso = 0.01*u.deg
clust_midM_index15.map_fov = 5.0*u.deg

# The center of the map can be offset wrt the cluster
clust_midM_index15.map_coord = SkyCoord("241.14d  17.72d", frame="icrs", unit="deg")

# Get the corresponding header
header = clust_midM_index15.get_map_header()

# %%
template = clust_midM_index15.get_gamma_map(Emin=None, Emax=None, 
                               Energy_density=False, 
                               Normalize=True) # The map is normalized to the total flux, to be in unit of sr-1

# %%
rad500 = clust_midM_index15.theta500.to_value('deg')
radtru = clust_midM_index15.theta_truncation.to_value('deg')

fig = plt.figure(figsize=(10, 8))
ax = plt.subplot(111, projection=WCS(header))
plt.imshow(template, vmin=0, origin='lower', cmap='magma', norm=SymLogNorm(1))

# Show R500
circle500 = matplotlib.patches.Ellipse((clust_midM_index15.coord.ra.value, clust_midM_index15.coord.dec.value),
                                        2*rad500/np.cos(clust_midM_index15.coord.dec.value*np.pi/180), 2*rad500,
                                        linewidth=2, fill=False, zorder=2,
                                        edgecolor='green', linestyle='dashed',facecolor='none',
                                        transform=ax.get_transform('fk5'))
# Show R_truncation
circletru = matplotlib.patches.Ellipse((clust_midM_index15.coord.ra.value, clust_midM_index15.coord.dec.value),
                                        2*radtru/np.cos(clust_midM_index15.coord.dec.value*np.pi/180), 2*radtru,
                                        linewidth=1, fill=False, zorder=2,
                                        edgecolor='green', linestyle='dashed',facecolor='none',
                                        transform=ax.get_transform('fk5'))
ax.add_patch(circle500)
ax.add_patch(circletru)
plt.colorbar()
plt.title(clust_midM_index15.name+', gamma template ($sr^{-1}$)')

# %%
# Save the parameters
clust_midM_index15.save_param()

# Save relevant output products
clust_midM_index15.save_spectra()
clust_midM_index15.save_profile()
clust_midM_index15.save_map()

# Can also produce plots
clust_midM_index15.plot(prod_list=['all'])

# %%
energy = np.logspace(-1,5,100)*u.GeV
e_15_1, s_15_1 = clust_midM_index15.get_gamma_spectrum(energy,Rmax=clust_midM_index15.R500, type_integral='spherical')
e_15_2, s_15_2 = clust_midM_index15_2.get_gamma_spectrum(energy,Rmax=clust_midM_index15_2.R500, type_integral='spherical')

# разом з СТА чутливістю
plt.figure(0,figsize=(10,8))
bins_lo = [0.02, 0.0316, 0.0501, 0.0794, 0.126, 0.2, 0.316, 0.501, 0.794, 1.26, 2, 3.16, 5.01, 7.94, 12.6, 20, 31.6, 50.1, 79.4, 126] # E_min (TeV)
bins_hi = [0.0316, 0.0501, 0.0794, 0.126, 0.2, 0.316, 0.501, 0.794, 1.26, 2, 3.16, 5.01, 7.94, 12.6, 20, 31.6, 50.1, 79.4, 126, 200] # E_max (TeV)
data = [2.37e-11, 8.35e-12, 2.02e-12, 9.41e-13, 5.37e-13, 3.58e-13, 2.43e-13, 1.76e-13, 1.35e-13, 1.24e-13, 1.1e-13,
        1.21e-13, 1.44e-13, 2.06e-13, 3.2e-13, 5.1e-13, 7.97e-13, 1.2e-12, 1.93e-12, 3.92e-12] # S (erg / cm^2 / s)
data_GeV = [i * 624.15064799632 for i in data]
mid_point = [np.exp((np.log(i)+np.log(j))/2) * 1000 for i, j in zip(bins_lo, bins_hi)]
plt.loglog(mid_point, data_GeV, color='k', ls='-.', lw='2', alpha=1, label = 'CTA North sensivity 50h')

#LHAASO sensitivity
bins_lo = [0.3, 0.6, 1, 2, 2.5, 3, 5, 8, 10, 20, 50, 100, 170, 300] # E_min (TeV)
bins_hi = [0.6, 1, 2, 2.5, 3, 5, 8, 10, 20, 50, 100, 170, 300, 600] # E_max (TeV)
data = [3e-9, 8e-10, 4e-10, 1e-10, 8e-11, 7e-11, 8e-11, 9e-11, 6e-11, 4e-11, 1.5e-11, 2e-11, 5e-11, 7e-11 ] # S (GeV/ cm^2 / s)
mid_point = [np.exp((np.log(i)+np.log(j))/2) * 1000 for i, j in zip(bins_lo, bins_hi)]
plt.loglog(mid_point, data, color='gray', ls='-.', lw='2', alpha=1, label = 'LHAASO sensivity')


sum = s1 + s2
plt.gca().set_ylim(bottom= 1e-12)
plt.gca().set_xlim(left= 1e-1)

plt.loglog(e_15_1, (e_15_1**2*s_15_1).to('GeV cm-2 s-1'), '-', label='Index = 1.5, Rmax = R500, Propto1', c = 'k')
plt.loglog(e_15_2, (e_15_2**2*s_15_2).to('GeV cm-2 s-1'), '-', label='Index = 1.5, Rmax = R500, Propto2', c = 'r')
plt.xlabel('Energy (GeV)')
plt.ylabel('Flux ($GeV/cm^2/s$)')
plt.legend()

# %%
clust_midM_index15.print_param()

# %%
clust_midM.print_param()

# %%
energy = np.logspace(-2,7,100)*u.GeV
#e_15_1, s_15_1 = clust_midM_index15.get_gamma_spectrum(energy,Rmax=clust_midM_index15.R500, type_integral='spherical')
#e_15_1, s_15_1 = clust_midM_index15.get_gamma_spectrum(energy,Rmax=clust_midM_index15.R500, type_integral='cylindrical')
#e_15_2, s_15_2 = clust_midM_index15_2.get_gamma_spectrum(energy,Rmax=clust_midM_index15_2.R500, type_integral='spherical')
#e_15_2, s_15_2 = clust_midM_index15_2.get_gamma_spectrum(energy,Rmax=clust_midM_index15_2.R500, type_integral='cylindrical')

e_15_1, s_15_1 = clust_midM_index15.get_gamma_spectrum(energy,Rmax=clust_midM_index15.R500, type_integral='spherical')
e_15_2, s_15_2 = clust_midM_index15_2.get_gamma_spectrum(energy,Rmax=clust_midM_index15_2.R500, type_integral='spherical')

e_15_1_smrc, s_15_1_smrc = clust_midM_index15_test_smallrc.get_gamma_spectrum(energy,Rmax=clust_midM_index15_test_smallrc.R500, type_integral='spherical')
e_15_2_smrc, s_15_2_smrc = clust_midM_index15_2_test_smallrc.get_gamma_spectrum(energy,Rmax=clust_midM_index15_test_smallrc.R500, type_integral='spherical')

e_15_1_bgrc, s_15_1_bgrc = clust_midM_index15_test_bigrc.get_gamma_spectrum(energy,Rmax=clust_midM_index15_test_bigrc.R500, type_integral='spherical')
e_15_2_bgrc, s_15_2_bgrc = clust_midM_index15_2_test_bigrc.get_gamma_spectrum(energy,Rmax=clust_midM_index15_2_test_bigrc.R500, type_integral='spherical')


# разом з СТА чутливістю
plt.figure(0,figsize=(10,8))
bins_lo = [0.02, 0.0316, 0.0501, 0.0794, 0.126, 0.2, 0.316, 0.501, 0.794, 1.26, 2, 3.16, 5.01, 7.94, 12.6, 20, 31.6, 50.1, 79.4, 126] # E_min (TeV)
bins_hi = [0.0316, 0.0501, 0.0794, 0.126, 0.2, 0.316, 0.501, 0.794, 1.26, 2, 3.16, 5.01, 7.94, 12.6, 20, 31.6, 50.1, 79.4, 126, 200] # E_max (TeV)
data = [2.37e-11, 8.35e-12, 2.02e-12, 9.41e-13, 5.37e-13, 3.58e-13, 2.43e-13, 1.76e-13, 1.35e-13, 1.24e-13, 1.1e-13,
        1.21e-13, 1.44e-13, 2.06e-13, 3.2e-13, 5.1e-13, 7.97e-13, 1.2e-12, 1.93e-12, 3.92e-12] # S (erg / cm^2 / s)
data_GeV = [i * 624.15064799632 for i in data]
mid_point = [np.exp((np.log(i)+np.log(j))/2) * 1000 for i, j in zip(bins_lo, bins_hi)]
plt.loglog(mid_point, data_GeV, color='k', ls='-.', lw='2', alpha=1, label = 'CTA North sensivity 50h')

#LHAASO sensitivity
bins_lo = [0.3, 0.6, 1, 2, 2.5, 3, 5, 8, 10, 20, 50, 100, 170, 300] # E_min (TeV)
bins_hi = [0.6, 1, 2, 2.5, 3, 5, 8, 10, 20, 50, 100, 170, 300, 600] # E_max (TeV)
data = [3e-9, 8e-10, 4e-10, 1e-10, 8e-11, 7e-11, 8e-11, 9e-11, 6e-11, 4e-11, 1.5e-11, 2e-11, 5e-11, 7e-11 ] # S (GeV/ cm^2 / s)
mid_point = [np.exp((np.log(i)+np.log(j))/2) * 1000 for i, j in zip(bins_lo, bins_hi)]
plt.loglog(mid_point, data, color='gray', ls='-.', lw='2', alpha=1)#, label = 'LHAASO sensivity')


sum = s1 + s2
plt.gca().set_ylim(bottom= 1e-12)
plt.gca().set_ylim(top= 1e-6)
plt.gca().set_xlim(left= 1e-1)

plt.loglog(e_15_1, (e_15_1**2*s_15_1).to('GeV cm-2 s-1'), '-.', label='CRp prop to 1, r_c0 = 19.35 kpc', c = 'b')
plt.loglog(e_15_2, (e_15_2**2*s_15_2).to('GeV cm-2 s-1'), '-', label='CRp prop to 2, r_c0 = 19.35', c = 'b')

plt.loglog(e_15_1_smrc, (e_15_1_smrc**2*s_15_1_smrc).to('GeV cm-2 s-1'), '-.', label='CRp prop to 1, r_c = 0.1r_c0 = 1.935 kpc', c = 'r')
plt.loglog(e_15_2_smrc, (e_15_2_smrc**2*s_15_2_smrc).to('GeV cm-2 s-1'), '-', label='CRp prop to 2, r_c = 0.1r_c0', c = 'r')

plt.loglog(e_15_1_bgrc, (e_15_1_bgrc**2*s_15_1_bgrc).to('GeV cm-2 s-1'), '-.', label='CRp prop to 1, r_c = 10r_c0 = 193.5 kpc', c = 'g')
plt.loglog(e_15_2_bgrc, (e_15_2_bgrc**2*s_15_2_bgrc).to('GeV cm-2 s-1'), '-', label='CRp prop to 2, r_c = 10r_c0', c = 'g')

#plt.loglog(e_15_1, (e_15_1**2*s_15_1).to('GeV cm-2 s-1'), '-', label='Index = 1.5, Rmax = R500, Propto1', c = 'k')
#plt.loglog(e_15_2, (e_15_2**2*s_15_2).to('GeV cm-2 s-1'), '-', label='Index = 1.5, Rmax = R500, Propto2', c = 'r')

plt.xlabel('Energy (GeV)')
plt.ylabel('Flux ($GeV/cm^2/s$)')
plt.legend()

# %%
s_15_1[-34]

# %%
s_15_2[-34]

# %%
s_arr1 = np.array(s_15_1)
e_arr1 = np.array(e_15_1)
s_arr2 = np.array(s_15_2)
e_arr2 = np.array(e_15_2)

# %%
s_arr2[-34]

# %%
e_arr2[-34]**2*s_arr2[-34]

# %%
eng, spec = clust_midM_index15.get_gamma_spectrum(energy, Rmax=clust_midM_index15.R500, type_integral='spherical')
model_plots.spectra(energy, (energy/const.h).to('GHz'), (energy**2*spec).to('GeV cm-2 s-1'),
        '/Users/vdk/PLOT_SPEC_gamma.pdf',
        label='$F_{\\gamma}$(<R, sph) (GeV cm$^{-2}$ s$^{-1}$)')

# %%
energy=np.logspace(-2,7,100)*u.GeV
eng, spec = clust_midM_index15_2.get_gamma_spectrum(energy, Rmax=clust_midM_index15_2.R_truncation, type_integral='spherical')
clust_midM_index15_2._save_txt_file('/Users/vdk/SPECTRA_gamma_Rtrunc2.txt',
                    eng.to_value('MeV'), spec.to_value('MeV-1 cm-2 s-1'), 'energy (MeV)', 'spectrum (MeV-1 cm-2 s-1)')

# %%
s_15_2[-34]

# %%
energy = np.logspace(-1,5,100)*u.GeV
e_15, s_15 = clust_midM_index15_2.get_gamma_spectrum(energy,Rmax=clust_midM_index15_2.R_truncation, type_integral='spherical')
e_20, s_20 = clust_midM_index20_2.get_gamma_spectrum(energy,Rmax=clust_midM_index20_2.R_truncation, type_integral='spherical')
e_23, s_23 = clust_midM_index23_2.get_gamma_spectrum(energy,Rmax=clust_midM_index23_2.R_truncation, type_integral='spherical')


# разом з СТА чутливістю
plt.figure(0,figsize=(10,8))
bins_lo = [0.02, 0.0316, 0.0501, 0.0794, 0.126, 0.2, 0.316, 0.501, 0.794, 1.26, 2, 3.16, 5.01, 7.94, 12.6, 20, 31.6, 50.1, 79.4, 126] # E_min (TeV)
bins_hi = [0.0316, 0.0501, 0.0794, 0.126, 0.2, 0.316, 0.501, 0.794, 1.26, 2, 3.16, 5.01, 7.94, 12.6, 20, 31.6, 50.1, 79.4, 126, 200] # E_max (TeV)
data = [2.37e-11, 8.35e-12, 2.02e-12, 9.41e-13, 5.37e-13, 3.58e-13, 2.43e-13, 1.76e-13, 1.35e-13, 1.24e-13, 1.1e-13,
        1.21e-13, 1.44e-13, 2.06e-13, 3.2e-13, 5.1e-13, 7.97e-13, 1.2e-12, 1.93e-12, 3.92e-12] # S (erg / cm^2 / s)
data_GeV = [i * 624.15064799632 for i in data]
mid_point = [np.exp((np.log(i)+np.log(j))/2) * 1000 for i, j in zip(bins_lo, bins_hi)]
plt.loglog(mid_point, data_GeV, color='k', ls='-.', lw='2', alpha=1, label = 'CTA North sensivity 50h')

#LHAASO sensitivity
bins_lo = [0.3, 0.6, 1, 2, 2.5, 3, 5, 8, 10, 20, 50, 100, 170, 300] # E_min (TeV)
bins_hi = [0.6, 1, 2, 2.5, 3, 5, 8, 10, 20, 50, 100, 170, 300, 600] # E_max (TeV)
data = [3e-9, 8e-10, 4e-10, 1e-10, 8e-11, 7e-11, 8e-11, 9e-11, 6e-11, 4e-11, 1.5e-11, 2e-11, 5e-11, 7e-11 ] # S (GeV/ cm^2 / s)
mid_point = [np.exp((np.log(i)+np.log(j))/2) * 1000 for i, j in zip(bins_lo, bins_hi)]
plt.loglog(mid_point, data, color='gray', ls='-.', lw='2', alpha=1, label = 'LHAASO sensivity')

# Fermi sensitivity
bins_lo = [5e-5, 7e-5, 2e-4, 4e-4, 6e-4, 1.5e-3, 2e-3, 4e-3, 8e-3,5e-2, 0.1] #in TeV
bins_hi = [7e-5, 2e-4, 4e-4, 6e-4, 1.5e-3, 2e-3, 4e-3, 8e-3, 5e-2,0.1, 0.3] #in TeV
data = [6e-12, 3e-12, 1e-12, 8e-13, 6.5e-13, 3.75e-13, 3e-13, 3.5e-13, 5e-13, 2e-12, 4.25e-12] # S (erg / cm^2 / s)
data_GeV = [i * 624.15064799632 for i in data]
mid_point = [np.exp((np.log(i)+np.log(j))/2) * 1000 for i, j in zip(bins_lo, bins_hi)]
plt.loglog(mid_point, data_GeV, color='grey', ls='-.', lw='2', alpha=0.5, label = 'Fermi sensivity')



sum = s1 + s2
plt.gca().set_ylim(bottom= 1e-12)
plt.gca().set_xlim(left= 1e-1)

plt.loglog(e_15, (e_15**2*s_15).to('GeV cm-2 s-1'), '-', label='Index = 1.5', c = 'k')
plt.loglog(e_20, (e_20**2*s_20).to('GeV cm-2 s-1'), '--', label='Index = 2', c = 'k')
plt.loglog(e_23, (e_23**2*s_23).to('GeV cm-2 s-1'), ':', label='Index = 2.3', c = 'k')
plt.xlabel('Energy (GeV)')
plt.ylabel('Flux ($GeV/cm^2/s$)')
plt.legend()

# %%
# нечайно не зберіг і пропало багато

# %%
energy = np.logspace(-1,6,100)*u.GeV
x = np.logspace(3,6,10)
y = [1e-9 for i in x]

e_15, n_15 = clust_midM_index15.get_neutrino_spectrum(energy,Rmax=clust_midM_index15.R_truncation, type_integral='spherical')
e_20, n_20 = clust_midM_index20.get_neutrino_spectrum(energy,Rmax=clust_midM_index20.R_truncation, type_integral='spherical')
e_23, n_23 = clust_midM_index23.get_neutrino_spectrum(energy,Rmax=clust_midM_index23.R_truncation, type_integral='spherical')

plt.gca().set_ylim(top = 1e-7)
plt.gca().set_ylim(bottom= 1e-15)
plt.gca().set_xlim(left= 1e-1)
plt.gca().set_xlim(right= 1e6)



plt.loglog(e_15, (e_15**2*n_15).to('GeV cm-2 s-1'), '-', label='Index = 1.5', c = 'k')
plt.loglog(e_20, (e_20**2*n_20).to('GeV cm-2 s-1'), '-.', label='Index = 2', c = 'k')
plt.loglog(e_23, (e_23**2*n_23).to('GeV cm-2 s-1'), ':', label='Index = 2.3', c = 'k')
plt.plot(x,y, label = 'Ice Cube discovery potential', c = 'k', ls = '--')

plt.xlabel('Energy (GeV)')
plt.ylabel('Flux ($GeV/cm^2/s$)')
plt.legend()
