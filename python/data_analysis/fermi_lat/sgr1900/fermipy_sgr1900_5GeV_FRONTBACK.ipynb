# %%
from astropy import units as u
from astropy.coordinates import SkyCoord

import matplotlib.pyplot as plt
from IPython.display import display
from gammapy.data import EventList
from gammapy.datasets import Datasets, MapDataset
from gammapy.irf import EDispKernelMap, PSFMap
from gammapy.maps import Map, MapAxis, WcsGeom
from gammapy.modeling import Fit
from matplotlib.patches import Circle
from gammapy.modeling.models import (
    Models,
    PointSpatialModel,
    PowerLawNormSpectralModel,
    PowerLawSpectralModel,
    SkyModel,
    TemplateSpatialModel,
    create_fermi_isotropic_diffuse_model,
)
from astropy.table import vstack
from gammapy.data import EventList
from gammapy.catalog import SourceCatalog4FGL

import yaml
from fermipy.gtanalysis import GTAnalysis
from fermipy.plotting import ROIPlotter, SEDPlotter

catalog_4fgl = SourceCatalog4FGL("/Users/vdk/shared/fermibottle/gll_psc_v35.fit")

# %%
# Create a GTAnalysis object from the configuration file.
gta = GTAnalysis('/Users/vdk/software/my_codebase/python/data_analysis/fermi_lat/sgr1900/fermi_config_sgr1900_5GeV_FRONTBACK.yaml', logging={'verbosity': 3})
gta.setup()
# Out:
# 2025-05-01 13:06:43 INFO    GTAnalysis.__init__():
# --------------------------------------------------------------------------------
# fermipy version 1.3.1
# ScienceTools version 2.2.0
# 2025-05-01 13:06:43 INFO    GTAnalysis.setup(): Running setup.
# 2025-05-01 13:06:43 INFO    GTBinnedAnalysis.setup(): Running setup for component 00
# 2025-05-01 13:06:43 INFO    GTBinnedAnalysis._select_data(): Skipping data selection.
# 2025-05-01 13:06:43 INFO    GTBinnedAnalysis._create_ltcube(): Skipping LT Cube.
# 2025-05-01 13:06:43 INFO    GTBinnedAnalysis._create_expcube(): Skipping gtexpcube.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATEREF to '2001-01-01T00:01:04.184' from MJDREF.
# Set MJD-OBS to 54682.655283 from DATE-OBS.
# Set MJD-END to 60774.984781 from DATE-END'. [astropy.wcs.wcs]
# 2025-05-01 13:06:43 INFO    GTBinnedAnalysis._create_srcmaps(): Skipping gtsrcmaps.
# 2025-05-01 13:06:43 INFO    GTBinnedAnalysis.setup(): Finished setup for component 00
# 2025-05-01 13:06:43 INFO    GTBinnedAnalysis._create_binned_analysis(): Creating BinnedAnalysis for component 00.
# 2025-05-01 13:06:47 INFO    GTAnalysis.setup(): Initializing source properties
# 2025-05-01 13:06:47 INFO    GTAnalysis.setup(): Finished setup.

# %%
gta.print_roi()
# Out:
# 2025-05-01 13:06:47 INFO    GTAnalysis.print_roi():
# name                SpatialModel   SpectrumType     offset        ts       npred
# --------------------------------------------------------------------------------
# 4FGL J1908.6+0915e  RadialDisk     PowerLaw          0.000       nan       243.1
# 4FGL J1910.2+0904c  PointSource    PowerLaw          0.430       nan       221.6
# 4FGL J1911.0+0905   PointSource    LogParabola       0.619       nan      1465.9
# 4FGL J1911.8+0903c  PointSource    PowerLaw          0.808       nan        85.2
# 4FGL J1912.0+0927   PointSource    LogParabola       0.869       nan        52.7
# 4FGL J1908.7+0812   PointSource    LogParabola       1.056       nan        53.6
# 4FGL J1913.3+0905   PointSource    PLSuperExpCuto    1.183       nan       118.8
# 4FGL J1912.7+0957   PointSource    LogParabola       1.226       nan        64.1
# 4FGL J1911.7+1014c  PointSource    LogParabola       1.241       nan        27.7
# 4FGL J1913.3+1019   PointSource    PowerLaw          1.586       nan       167.9
# 4FGL J1914.7+1012c  PointSource    LogParabola       1.777       nan        54.5
# 4FGL J1911.3+1055   PointSource    LogParabola       1.795       nan        11.0
# 4FGL J1906.4+0723   PointSource    PLSuperExpCuto    1.939       nan       371.7
# 4FGL J1906.9+0712   PointSource    LogParabola       2.084       nan       360.2
# 4FGL J1907.6+0703   PointSource    PowerLaw          2.213       nan       100.1
# 4FGL J1914.5+1107c  PointSource    LogParabola       2.362       nan        49.2
# 4FGL J1901.1+0730   PointSource    LogParabola       2.547       nan        98.1
# 4FGL J1916.3+1108   PointSource    LogParabola       2.667       nan        77.9
# 4FGL J1902.5+0654   PointSource    LogParabola       2.788       nan       106.9
# 4FGL J1906.2+0631   PointSource    LogParabola       2.797       nan         6.3
# 4FGL J1857.2+0941   PointSource    PLSuperExpCuto    2.832       nan         9.1
# 4FGL J1857.5+0756   PointSource    LogParabola       3.036       nan        14.3
# 4FGL J1915.3+1149   PointSource    LogParabola       3.042       nan        52.8
# 4FGL J1904.7+0615   PointSource    LogParabola       3.159       nan         9.7
# 4FGL J1907.9+0602   PointSource    PLSuperExpCuto    3.230       nan      1520.8
# 4FGL J1856.2+0749   PointSource    LogParabola       3.373       nan        30.3
# 4FGL J1855.2+0756   PointSource    PowerLaw          3.561       nan        42.6
# 4FGL J1858.5+0640   PointSource    PowerLaw          3.599       nan        97.8
# 4FGL J1918.1+1215c  PointSource    LogParabola       3.808       nan        19.0
# 4FGL J1903.8+0531   PointSource    LogParabola       3.919       nan       137.4
# 4FGL J1919.2+0618   PointSource    LogParabola       3.951       nan         8.4
# 4FGL J1900.9+0538   PointSource    LogParabola       4.100       nan        31.4
# 4FGL J1912.5+1320   PointSource    LogParabola       4.199       nan        18.7
# 4FGL J1913.2+0512   PointSource    LogParabola       4.211       nan        10.5
# 4FGL J1851.5+0718   PointSource    LogParabola       4.655       nan        48.0
# 4FGL J1902.2+0448   PointSource    LogParabola       4.722       nan        56.8
# 4FGL J1919.4+1313   PointSource    LogParabola       4.778       nan        18.4
# 4FGL J1900.7+0426   PointSource    LogParabola       5.199       nan        40.7
# 4FGL J1920.7+1334   PointSource    LogParabola       5.232       nan        22.7
# 4FGL J1925.7+1227   PointSource    LogParabola       5.278       nan        57.4
# 4FGL J1930.3+0911   PointSource    LogParabola       5.356       nan         5.3
# 4FGL J1925.1+0547   PointSource    LogParabola       5.371       nan         4.2
# 4FGL J1848.8+0701   PointSource    LogParabola       5.375       nan         1.3
# 4FGL J1855.2+0456   PointSource    LogParabola       5.445       nan        30.5
# 4FGL J1919.9+1358c  PointSource    LogParabola       5.465       nan        74.7
# 4FGL J1846.3+0919   PointSource    PLSuperExpCuto    5.492       nan       278.0
# 4FGL J1859.8+0411c  PointSource    LogParabola       5.518       nan        56.2
# 4FGL J1931.1+0937   PointSource    LogParabola       5.560       nan       520.0
# 4FGL J1911.8+1447   PointSource    PowerLaw          5.592       nan        42.8
# 4FGL J1920.9+1408   PointSource    LogParabola       5.743       nan        55.4
# 4FGL J1902.8+1451   PointSource    PowerLaw          5.782       nan        26.7
# 4FGL J1920.8+0418   PointSource    LogParabola       5.814       nan        40.5
# 4FGL J1900.4+0339   PointSource    LogParabola       5.950       nan       107.4
# 4FGL J1858.0+0354   PointSource    LogParabola       5.956       nan       103.8
# 4FGL J1923.2+1408e  SpatialMap     LogParabola       6.057       nan      3178.9
# 4FGL J1911.5+0311   PointSource    LogParabola       6.120       nan        57.3
# 4FGL J1918.0+0331   PointSource    LogParabola       6.196       nan        66.8
# 4FGL J1922.7+1428c  PointSource    LogParabola       6.258       nan        71.3
# 4FGL J1933.3+0726   PointSource    PowerLaw          6.380       nan       180.6
# 4FGL J1934.2+1036   PointSource    PowerLaw          6.452       nan        10.4
# 4FGL J1922.4+1453c  PointSource    LogParabola       6.569       nan        30.1
# 4FGL J1857.9+0313c  PointSource    LogParabola       6.603       nan        49.7
# 4FGL J1859.8+1545   PointSource    PowerLaw          6.846       nan        19.9
# 4FGL J1846.0+0507   PointSource    LogParabola       6.965       nan        68.0
# 4FGL J1912.0+1612   PointSource    PowerLaw          6.993       nan        22.2
# 4FGL J1857.7+0246e  RadialDisk     PowerLaw          7.023       nan       851.0
# 4FGL J1840.3+1105   PointSource    LogParabola       7.208       nan        19.5
# 4FGL J1925.3+1522c  PointSource    LogParabola       7.345       nan        22.8
# 4FGL J1858.3+0209   PointSource    PowerLaw          7.557       nan        58.6
# 4FGL J1906.1+1651   PointSource    LogParabola       7.629       nan        50.5
# 4FGL J1907.2+0126   PointSource    PowerLaw          7.822       nan        48.2
# 4FGL J1927.4+0253   PointSource    LogParabola       7.912       nan         9.3
# 4FGL J1851.0+1558   PointSource    PowerLaw          7.961       nan        19.3
# 4FGL J1935.5+1407   PointSource    PowerLaw          8.199       nan        23.7
# 4FGL J1921.4+0136   PointSource    PLSuperExpCuto    8.288       nan        69.7
# 4FGL J1942.4+0927   PointSource    PowerLaw          8.349       nan        11.5
# 4FGL J1942.7+1033   PointSource    LogParabola       8.508       nan       443.2
# 4FGL J1942.1+1142   PointSource    PowerLaw          8.598       nan        11.8
# 4FGL J1856.5+1735   PointSource    LogParabola       8.841       nan        17.9
# 4FGL J1834.3+0613   PointSource    LogParabola       9.030       nan        30.0
# 4FGL J1832.7+0618   PointSource    PowerLaw          9.373       nan        18.7
# 4FGL J1830.1+0617   PointSource    PowerLaw          9.986       nan        42.8
# 4FGL J1948.3+1207   PointSource    LogParabola      10.175       nan         5.6
# isodiff             ConstantValue  FileFunction      -----       nan      4744.7
# galdiff             MapCubeFunctio PowerLaw          -----       nan     99830.9

# %%
plt.figure(figsize=(20, 20))
gta.write_roi('initial',make_plots=True,save_model_map=True)
plt.show()
# Out:
# 2025-05-01 13:06:47 INFO    GTBinnedAnalysis.write_xml(): Writing /Users/vdk/software/my_codebase/python/data_analysis/fermi_lat/sgr1900/output_sgr_5GeV_FRONTBACK/initial_00.xml...
# 2025-05-01 13:06:47 INFO    GTAnalysis.write_fits(): Writing /Users/vdk/software/my_codebase/python/data_analysis/fermi_lat/sgr1900/output_sgr_5GeV_FRONTBACK/initial.fits...
# WARNING: Format %s cannot be mapped to the accepted TDISPn keyword values.  Format will not be moved into TDISPn keyword. [astropy.io.fits.column]
# WARNING: Format %f cannot be mapped to the accepted TDISPn keyword values.  Format will not be moved into TDISPn keyword. [astropy.io.fits.column]
# WARNING: Format %s cannot be mapped to the accepted TDISPn keyword values.  Format will not be moved into TDISPn keyword. [astropy.io.fits.column]
# 2025-05-01 13:06:50 INFO    GTBinnedAnalysis.write_model_map(): Generating model map for component 00.
# 2025-05-01 13:06:51 INFO    GTAnalysis.write_roi(): Writing /Users/vdk/software/my_codebase/python/data_analysis/fermi_lat/sgr1900/output_sgr_5GeV_FRONTBACK/initial.npy...

# %%
gta.free_sources(free=False)
gta.free_sources(skydir=gta.roi[gta.roi.sources[0].name].skydir,distance=[3.0],free=True)
# Out:
# 2025-05-01 13:06:55 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1908.6+0915e    : ['Prefactor', 'Index']
# 2025-05-01 13:06:55 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1910.2+0904c    : ['Prefactor', 'Index']
# 2025-05-01 13:06:55 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1911.0+0905     : ['norm', 'alpha', 'beta']
# 2025-05-01 13:06:55 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1911.8+0903c    : ['Prefactor', 'Index']
# 2025-05-01 13:06:55 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1912.0+0927     : ['norm', 'alpha', 'beta']
# 2025-05-01 13:06:55 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1908.7+0812     : ['norm', 'alpha', 'beta']
# 2025-05-01 13:06:55 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1913.3+0905     : ['Prefactor', 'IndexS', 'ExpfactorS']
# 2025-05-01 13:06:55 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1912.7+0957     : ['norm', 'alpha', 'beta']
# 2025-05-01 13:06:55 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1911.7+1014c    : ['norm', 'alpha', 'beta']
# 2025-05-01 13:06:55 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1913.3+1019     : ['Prefactor', 'Index']
# 2025-05-01 13:06:55 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1914.7+1012c    : ['norm', 'alpha', 'beta']
# 2025-05-01 13:06:55 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1911.3+1055     : ['norm', 'alpha', 'beta']
# 2025-05-01 13:06:55 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1906.4+0723     : ['Prefactor', 'IndexS', 'ExpfactorS']
# 2025-05-01 13:06:55 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1906.9+0712     : ['norm', 'alpha', 'beta']
# 2025-05-01 13:06:55 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1907.6+0703     : ['Prefactor', 'Index']
# 2025-05-01 13:06:55 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1914.5+1107c    : ['norm', 'alpha', 'beta']
# 2025-05-01 13:06:55 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1901.1+0730     : ['norm', 'alpha', 'beta']
# 2025-05-01 13:06:55 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1916.3+1108     : ['norm', 'alpha', 'beta']
# 2025-05-01 13:06:55 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1902.5+0654     : ['norm', 'alpha', 'beta']
# 2025-05-01 13:06:55 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1906.2+0631     : ['norm', 'alpha', 'beta']
# 2025-05-01 13:06:55 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1857.2+0941     : ['Prefactor', 'IndexS', 'ExpfactorS']
# 2025-05-01 13:06:55 INFO    GTAnalysis.free_source(): Freeing parameters for isodiff               : ['Normalization']
# 2025-05-01 13:06:55 INFO    GTAnalysis.free_source(): Freeing parameters for galdiff               : ['Prefactor', 'Index']
# [<fermipy.roi_model.Source at 0x34c4c81c0>,
#  <fermipy.roi_model.Source at 0x34c4c8550>,
#  <fermipy.roi_model.Source at 0x34c4c8610>,
#  <fermipy.roi_model.Source at 0x34c4c8d60>,
#  <fermipy.roi_model.Source at 0x34c4c8ee0>,
#  <fermipy.roi_model.Source at 0x34c4c82b0>,
#  <fermipy.roi_model.Source at 0x34c4c80a0>,
#  <fermipy.roi_model.Source at 0x34c4c87f0>,
#  <fermipy.roi_model.Source at 0x34c4c83a0>,
#  <fermipy.roi_model.Source at 0x34c4c8580>,
#  <fermipy.roi_model.Source at 0x34d525fd0>,
#  <fermipy.roi_model.Source at 0x34c4c8fa0>,
#  <fermipy.roi_model.Source at 0x34c198dc0>,
#  <fermipy.roi_model.Source at 0x34c1986d0>,
#  <fermipy.roi_model.Source at 0x34c4c8730>,
#  <fermipy.roi_model.Source at 0x34c4c86a0>,
#  <fermipy.roi_model.Source at 0x34c3ea5e0>,
#  <fermipy.roi_model.Source at 0x34c3e96a0>,
#  <fermipy.roi_model.Source at 0x34c3ea700>,
#  <fermipy.roi_model.Source at 0x34c3ea250>,
#  <fermipy.roi_model.Source at 0x34c5990a0>,
#  <fermipy.roi_model.IsoSource at 0x34c0fff70>,
#  <fermipy.roi_model.MapCubeSource at 0x34c0ffa00>]

# %%
gta.fit()
# Out:
# 2025-05-01 13:06:59 INFO    GTAnalysis.fit(): Starting fit.
# /Users/vdk/miniforge3/envs/fermipy/lib/python3.9/site-packages/scipy/interpolate/_fitpack2.py:313: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# 2025-05-01 13:07:54 INFO    GTAnalysis.fit(): Fit returned successfully. Quality:   2 Status: 102
# 2025-05-01 13:07:54 INFO    GTAnalysis.fit(): LogLike:  -229462.983 DeltaLogLike:      432.825
# {'fit_quality': 2,
#  'fit_status': 102,
#  'fit_success': True,
#  'dloglike': 432.82515010080533,
#  'edm': 0.008893817800955403,
#  'loglike': -229462.98269681848,
#  'covariance': array([[ 5.88970436e-03,  3.94834250e-03,  2.94467046e-03, ...,
#         7.59913966e-02, 6.68545140e-02, 3.46546233e-01, 1.67638955e-01,
#         9.93856167e-02, 7.09506324e-02, 2.31594137e-02, 1.24360715e-01,
#         6.61101070e-02, 3.13536769e-02, 8.52971255e-02, 1.42904684e-02,
#         2.19153540e-02, 1.10228761e-02, 8.55796627e-03, 1.62724539e-01,
#         3.62512855e-02, 4.72066890e-01, 1.00073223e-01, 2.20719964e-02,
#         6.45137276e-02, 1.37460201e-01, 1.26398409e-01, 1.61724435e-01,
#         7.48801373e-02, 1.06521945e-02, 1.21118443e-01, 6.83802754e-02,
#         9.50914797e-02, 1.32354086e-01, 1.69587982e-01, 2.51112341e-02,
#         6.83863641e-02, 6.44197753e-02, 1.61361858e-01, 7.19288591e-02,
#         3.58632814e-01, 1.03409058e-01, 2.44617006e-02, 1.65412869e-02,
#         8.73633219e-02, 3.99081115e-02, 2.21455785e-03, 9.43858683e-04,
#         2.83420013e-02]),
#  'indices': array([ 49,  50,  52,  94,  95,  96, 102, 103, 104, 121, 122, 123, 125,
#         126, 128, 130, 131, 132, 137, 138, 145, 146, 148, 149, 150, 152,
#         153, 155, 156, 157, 159, 160, 161, 167, 168, 169, 171, 172, 177,
#         178, 179, 188, 189, 190, 196, 197, 199, 201, 202, 204, 205, 206,
#         208, 209, 210, 216, 217, 218, 316, 317, 319]),
#  'is_norm': array([ True, False, False,  True, False, False,  True, False, False,
#          True, False, False,  True, False, False,  True, False, False,
#          True, False,  True, False,  True, False, False,  True, False,
#          True, False, False,  True, False, False,  True, False, False,
#          True, False,  True, False, False,  True, False, False,  True,
#         False, False,  True, False,  True, False, False,  True, False,
#         False,  True, False, False,  True, False,  True]),
#  'src_names': ['4FGL J1857.2+0941',
#   '4FGL J1857.2+0941',
#   '4FGL J1857.2+0941',
#   '4FGL J1901.1+0730',
#   '4FGL J1901.1+0730',
#   '4FGL J1901.1+0730',
#   '4FGL J1902.5+0654',
#   '4FGL J1902.5+0654',
#   '4FGL J1902.5+0654',
#   '4FGL J1906.2+0631',
#   '4FGL J1906.2+0631',
#   '4FGL J1906.2+0631',
#   '4FGL J1906.4+0723',
#   '4FGL J1906.4+0723',
#   '4FGL J1906.4+0723',
#   '4FGL J1906.9+0712',
#   '4FGL J1906.9+0712',
#   '4FGL J1906.9+0712',
#   '4FGL J1907.6+0703',
#   '4FGL J1907.6+0703',
#   '4FGL J1908.6+0915e',
#   '4FGL J1908.6+0915e',
#   '4FGL J1908.7+0812',
#   '4FGL J1908.7+0812',
#   '4FGL J1908.7+0812',
#   '4FGL J1910.2+0904c',
#   '4FGL J1910.2+0904c',
#   '4FGL J1911.0+0905',
#   '4FGL J1911.0+0905',
#   '4FGL J1911.0+0905',
#   '4FGL J1911.3+1055',
#   '4FGL J1911.3+1055',
#   '4FGL J1911.3+1055',
#   '4FGL J1911.7+1014c',
#   '4FGL J1911.7+1014c',
#   '4FGL J1911.7+1014c',
#   '4FGL J1911.8+0903c',
#   '4FGL J1911.8+0903c',
#   '4FGL J1912.0+0927',
#   '4FGL J1912.0+0927',
#   '4FGL J1912.0+0927',
#   '4FGL J1912.7+0957',
#   '4FGL J1912.7+0957',
#   '4FGL J1912.7+0957',
#   '4FGL J1913.3+0905',
#   '4FGL J1913.3+0905',
#   '4FGL J1913.3+0905',
#   '4FGL J1913.3+1019',
#   '4FGL J1913.3+1019',
#   '4FGL J1914.5+1107c',
#   '4FGL J1914.5+1107c',
#   '4FGL J1914.5+1107c',
#   '4FGL J1914.7+1012c',
#   '4FGL J1914.7+1012c',
#   '4FGL J1914.7+1012c',
#   '4FGL J1916.3+1108',
#   '4FGL J1916.3+1108',
#   '4FGL J1916.3+1108',
#   'galdiff',
#   'galdiff',
#   'isodiff'],
#  'par_names': ['Prefactor',
#   'IndexS',
#   'ExpfactorS',
#   'norm',
#   'alpha',
#   'beta',
#   'norm',
#   'alpha',
#   'beta',
#   'norm',
#   'alpha',
#   'beta',
#   'Prefactor',
#   'IndexS',
#   'ExpfactorS',
#   'norm',
#   'alpha',
#   'beta',
#   'Prefactor',
#   'Index',
#   'Prefactor',
#   'Index',
#   'norm',
#   'alpha',
#   'beta',
#   'Prefactor',
#   'Index',
#   'norm',
#   'alpha',
#   'beta',
#   'norm',
#   'alpha',
#   'beta',
#   'norm',
#   'alpha',
#   'beta',
#   'Prefactor',
#   'Index',
#   'norm',
#   'alpha',
#   'beta',
#   'norm',
#   'alpha',
#   'beta',
#   'Prefactor',
#   'IndexS',
#   'ExpfactorS',
#   'Prefactor',
#   'Index',
#   'norm',
#   'alpha',
#   'beta',
#   'norm',
#   'alpha',
#   'beta',
#   'norm',
#   'alpha',
#   'beta',
#   'Prefactor',
#   'Index',
#   'Normalization'],
#  'config': {'optimizer': 'MINUIT',
#   'tol': 0.001,
#   'max_iter': 100,
#   'init_lambda': 0.0001,
#   'retries': 3,
#   'min_fit_quality': 2,
#   'verbosity': 0,
#   'covar': True,
#   'reoptimize': False},
#  'niter': 1}

# %%
gta.print_roi()
# Out:
# 2025-05-01 13:07:54 INFO    GTAnalysis.print_roi():
# name                SpatialModel   SpectrumType     offset        ts       npred
# --------------------------------------------------------------------------------
# 4FGL J1908.6+0915e  RadialDisk     PowerLaw          0.000     19.41       170.0
# 4FGL J1910.2+0904c  PointSource    PowerLaw          0.430    102.73       210.6
# 4FGL J1911.0+0905   PointSource    LogParabola       0.619   2611.27      1388.8
# 4FGL J1911.8+0903c  PointSource    PowerLaw          0.808     34.82       124.6
# 4FGL J1912.0+0927   PointSource    LogParabola       0.869     13.04        61.0
# 4FGL J1908.7+0812   PointSource    LogParabola       1.056     13.29        61.5
# 4FGL J1913.3+0905   PointSource    PLSuperExpCuto    1.183     33.45        88.1
# 4FGL J1912.7+0957   PointSource    LogParabola       1.226     19.37        68.2
# 4FGL J1911.7+1014c  PointSource    LogParabola       1.241     11.91        42.5
# 4FGL J1913.3+1019   PointSource    PowerLaw          1.586    101.47       156.5
# 4FGL J1914.7+1012c  PointSource    LogParabola       1.777     12.41        41.1
# 4FGL J1911.3+1055   PointSource    LogParabola       1.795      9.05        36.0
# 4FGL J1906.4+0723   PointSource    PLSuperExpCuto    1.939    306.53       386.8
# 4FGL J1906.9+0712   PointSource    LogParabola       2.084    215.21       314.6
# 4FGL J1907.6+0703   PointSource    PowerLaw          2.213     29.72        97.6
# 4FGL J1914.5+1107c  PointSource    LogParabola       2.362      7.70        42.9
# 4FGL J1901.1+0730   PointSource    LogParabola       2.547     81.49       124.0
# 4FGL J1916.3+1108   PointSource    LogParabola       2.667     30.45        86.5
# 4FGL J1902.5+0654   PointSource    LogParabola       2.788     46.45        91.7
# 4FGL J1906.2+0631   PointSource    LogParabola       2.797      2.43        22.5
# 4FGL J1857.2+0941   PointSource    PLSuperExpCuto    2.832      6.69        17.5
# 4FGL J1857.5+0756   PointSource    LogParabola       3.036       nan        14.3
# 4FGL J1915.3+1149   PointSource    LogParabola       3.042       nan        52.8
# 4FGL J1904.7+0615   PointSource    LogParabola       3.159       nan         9.7
# 4FGL J1907.9+0602   PointSource    PLSuperExpCuto    3.230       nan      1520.8
# 4FGL J1856.2+0749   PointSource    LogParabola       3.373       nan        30.3
# 4FGL J1855.2+0756   PointSource    PowerLaw          3.561       nan        42.6
# 4FGL J1858.5+0640   PointSource    PowerLaw          3.599       nan        97.8
# 4FGL J1918.1+1215c  PointSource    LogParabola       3.808       nan        19.0
# 4FGL J1903.8+0531   PointSource    LogParabola       3.919       nan       137.4
# 4FGL J1919.2+0618   PointSource    LogParabola       3.951       nan         8.4
# 4FGL J1900.9+0538   PointSource    LogParabola       4.100       nan        31.4
# 4FGL J1912.5+1320   PointSource    LogParabola       4.199       nan        18.7
# 4FGL J1913.2+0512   PointSource    LogParabola       4.211       nan        10.5
# 4FGL J1851.5+0718   PointSource    LogParabola       4.655       nan        48.0
# 4FGL J1902.2+0448   PointSource    LogParabola       4.722       nan        56.8
# 4FGL J1919.4+1313   PointSource    LogParabola       4.778       nan        18.4
# 4FGL J1900.7+0426   PointSource    LogParabola       5.199       nan        40.7
# 4FGL J1920.7+1334   PointSource    LogParabola       5.232       nan        22.7
# 4FGL J1925.7+1227   PointSource    LogParabola       5.278       nan        57.4
# 4FGL J1930.3+0911   PointSource    LogParabola       5.356       nan         5.3
# 4FGL J1925.1+0547   PointSource    LogParabola       5.371       nan         4.2
# 4FGL J1848.8+0701   PointSource    LogParabola       5.375       nan         1.3
# 4FGL J1855.2+0456   PointSource    LogParabola       5.445       nan        30.5
# 4FGL J1919.9+1358c  PointSource    LogParabola       5.465       nan        74.7
# 4FGL J1846.3+0919   PointSource    PLSuperExpCuto    5.492       nan       278.0
# 4FGL J1859.8+0411c  PointSource    LogParabola       5.518       nan        56.2
# 4FGL J1931.1+0937   PointSource    LogParabola       5.560       nan       520.0
# 4FGL J1911.8+1447   PointSource    PowerLaw          5.592       nan        42.8
# 4FGL J1920.9+1408   PointSource    LogParabola       5.743       nan        55.4
# 4FGL J1902.8+1451   PointSource    PowerLaw          5.782       nan        26.7
# 4FGL J1920.8+0418   PointSource    LogParabola       5.814       nan        40.5
# 4FGL J1900.4+0339   PointSource    LogParabola       5.950       nan       107.4
# 4FGL J1858.0+0354   PointSource    LogParabola       5.956       nan       103.8
# 4FGL J1923.2+1408e  SpatialMap     LogParabola       6.057       nan      3178.9
# 4FGL J1911.5+0311   PointSource    LogParabola       6.120       nan        57.3
# 4FGL J1918.0+0331   PointSource    LogParabola       6.196       nan        66.8
# 4FGL J1922.7+1428c  PointSource    LogParabola       6.258       nan        71.3
# 4FGL J1933.3+0726   PointSource    PowerLaw          6.380       nan       180.6
# 4FGL J1934.2+1036   PointSource    PowerLaw          6.452       nan        10.4
# 4FGL J1922.4+1453c  PointSource    LogParabola       6.569       nan        30.1
# 4FGL J1857.9+0313c  PointSource    LogParabola       6.603       nan        49.7
# 4FGL J1859.8+1545   PointSource    PowerLaw          6.846       nan        19.9
# 4FGL J1846.0+0507   PointSource    LogParabola       6.965       nan        68.0
# 4FGL J1912.0+1612   PointSource    PowerLaw          6.993       nan        22.2
# 4FGL J1857.7+0246e  RadialDisk     PowerLaw          7.023       nan       851.0
# 4FGL J1840.3+1105   PointSource    LogParabola       7.208       nan        19.5
# 4FGL J1925.3+1522c  PointSource    LogParabola       7.345       nan        22.8
# 4FGL J1858.3+0209   PointSource    PowerLaw          7.557       nan        58.6
# 4FGL J1906.1+1651   PointSource    LogParabola       7.629       nan        50.5
# 4FGL J1907.2+0126   PointSource    PowerLaw          7.822       nan        48.2
# 4FGL J1927.4+0253   PointSource    LogParabola       7.912       nan         9.3
# 4FGL J1851.0+1558   PointSource    PowerLaw          7.961       nan        19.3
# 4FGL J1935.5+1407   PointSource    PowerLaw          8.199       nan        23.7
# 4FGL J1857.9+0313c     6.603   1.206  5.67e-07   3.23       nan        49.7
# 4FGL J1859.8+1545      6.846   0.573   5.7e-07   2.11       nan        19.9
# 4FGL J1846.0+0507      6.965   0.847  9.71e-07   1.91       nan        68.0
# 4FGL J1912.0+1612      6.993   1.955  3.95e-07   2.60       nan        22.2
# 4FGL J1857.7+0246e     7.023   0.801  3.17e-05   2.03       nan       851.0
# 4FGL J1840.3+1105      7.208   0.829  2.65e-07   2.37       nan        19.5
# 4FGL J1925.3+1522c     7.345   1.042  2.58e-07   3.38       nan        22.8
# 4FGL J1858.3+0209      7.557   2.507  2.53e-06   2.37       nan        58.6
# 4FGL J1906.1+1651      7.629   0.676  5.87e-07   1.82       nan        50.5
# 4FGL J1907.2+0126      7.822   0.465   1.3e-06   2.27       nan        48.2
# 4FGL J1927.4+0253      7.912   2.167  1.18e-07   2.94       nan         9.3
# 4FGL J1851.0+1558      7.961   0.401  4.55e-07   2.29       nan        19.3
# 4FGL J1935.5+1407      8.199   2.615  1.02e-06   1.95       nan        23.7
# 4FGL J1921.4+0136      8.288   0.805  8.49e-07   2.72       nan        69.7
# 4FGL J1942.4+0927      8.349   0.417  2.61e-07   2.45       nan        11.5
# 4FGL J1942.7+1033      8.508   0.387  1.55e-05   1.79       nan       443.2
# 4FGL J1942.1+1142      8.598   1.291  2.29e-07   2.54       nan        11.8
# 4FGL J1856.5+1735      8.841   0.725  1.95e-07   2.93       nan        17.9
# 4FGL J1834.3+0613      9.030   1.480  3.84e-07   2.43       nan        30.0
# 4FGL J1832.7+0618      9.373   1.615  4.44e-07   2.35       nan        18.7
# 4FGL J1830.1+0617      9.986   2.064  1.01e-06   2.40       nan        42.8
# 4FGL J1948.3+1207     10.175   0.424  6.45e-08   3.32       nan         5.6
# isodiff                  ---   0.106   0.00236   2.12      3.44       501.4    *
# galdiff                  ---   1.019    0.0486   0.02 282627.28     96326.5    *

# %% [markdown]
# # Build TS map with 4FGL sources

# %%
plt.clf()
tsmap_postfit = gta.tsmap(prefix='TSmap_all_sources',make_plots=True,write_fits=True,write_npy=True)

# %%
plt.clf()
fig = plt.figure(figsize=(14,6))
ROIPlotter(tsmap_postfit['sqrt_ts'],roi=gta.roi, graticule_radii=[0.6]).plot(interpolation='bicubic',levels=[0,3,5],vmin=0,vmax=5,subplot=121,cmap='magma', zoom = 6)
plt.gca().set_title('Sqrt(TS)')
ROIPlotter(tsmap_postfit['npred'],roi=gta.roi, graticule_radii=[0.6]).plot(interpolation='bicubic',vmin=0,vmax=20,subplot=122,cmap='magma', zoom = 6)
plt.gca().set_title('NPred')
plt.show()
# Out:
# 2025-05-01 13:07:54 INFO    GTAnalysis.tsmap(): Generating TS map
# 2025-05-01 13:07:56 INFO    GTAnalysis._make_tsmap_fast(): Fitting test source.
# 2025-05-01 13:08:05 INFO    GTAnalysis.tsmap(): Finished TS map
# 2025-05-01 13:08:08 WARNING GTAnalysis.tsmap(): Saving TS maps in .npy files is disabled b/c of incompatibilities in python3, remove the maps from the /Users/vdk/software/my_codebase/python/data_analysis/fermi_lat/sgr1900/output_sgr_5GeV_FRONTBACK/TSmap_all_sources_pointsource_powerlaw_2.00_tsmap.npy
# 2025-05-01 13:08:08 INFO    GTAnalysis.tsmap(): Execution time: 13.85 s

# %% [markdown]
# # Remove the main source

# %%
gta.delete_source('4FGL J1908.6+0915e')
gta.print_roi()
# Out:
# 2025-05-01 13:09:21 ERROR   GTAnalysis.delete_source(): No source with name: 4FGL J1908.6+0915e
# 2025-05-01 13:09:21 INFO    GTAnalysis.print_roi():
# name                SpatialModel   SpectrumType     offset        ts       npred
# --------------------------------------------------------------------------------
# 4FGL J1910.2+0904c  PointSource    PowerLaw          0.430    102.73       210.6
# 4FGL J1911.0+0905   PointSource    LogParabola       0.619   2611.27      1388.8
# 4FGL J1911.8+0903c  PointSource    PowerLaw          0.808     34.82       124.6
# 4FGL J1912.0+0927   PointSource    LogParabola       0.869     13.04        61.0
# 4FGL J1908.7+0812   PointSource    LogParabola       1.056     13.29        61.5
# 4FGL J1913.3+0905   PointSource    PLSuperExpCuto    1.183     33.45        88.1
# 4FGL J1912.7+0957   PointSource    LogParabola       1.226     19.37        68.2
# 4FGL J1911.7+1014c  PointSource    LogParabola       1.241     11.91        42.5
# 4FGL J1913.3+1019   PointSource    PowerLaw          1.586    101.47       156.5
# 4FGL J1914.7+1012c  PointSource    LogParabola       1.777     12.41        41.1
# 4FGL J1911.3+1055   PointSource    LogParabola       1.795      9.05        36.0
# 4FGL J1906.4+0723   PointSource    PLSuperExpCuto    1.939    306.53       386.8
# 4FGL J1906.9+0712   PointSource    LogParabola       2.084    215.21       314.6
# 4FGL J1907.6+0703   PointSource    PowerLaw          2.213     29.72        97.6
# 4FGL J1914.5+1107c  PointSource    LogParabola       2.362      7.70        42.9
# 4FGL J1901.1+0730   PointSource    LogParabola       2.547     81.49       124.0
# 4FGL J1916.3+1108   PointSource    LogParabola       2.667     30.45        86.5
# 4FGL J1902.5+0654   PointSource    LogParabola       2.788     46.45        91.7
# 4FGL J1906.2+0631   PointSource    LogParabola       2.797      2.43        22.5
# 4FGL J1857.2+0941   PointSource    PLSuperExpCuto    2.832      6.69        17.5
# 4FGL J1857.5+0756   PointSource    LogParabola       3.036       nan        14.3
# 4FGL J1915.3+1149   PointSource    LogParabola       3.042       nan        52.8
# 4FGL J1904.7+0615   PointSource    LogParabola       3.159       nan         9.7
# 4FGL J1907.9+0602   PointSource    PLSuperExpCuto    3.230       nan      1520.8
# 4FGL J1856.2+0749   PointSource    LogParabola       3.373       nan        30.3
# 4FGL J1855.2+0756   PointSource    PowerLaw          3.561       nan        42.6
# 4FGL J1858.5+0640   PointSource    PowerLaw          3.599       nan        97.8
# 4FGL J1918.1+1215c  PointSource    LogParabola       3.808       nan        19.0
# 4FGL J1903.8+0531   PointSource    LogParabola       3.919       nan       137.4
# 4FGL J1919.2+0618   PointSource    LogParabola       3.951       nan         8.4
# 4FGL J1900.9+0538   PointSource    LogParabola       4.100       nan        31.4
# 4FGL J1912.5+1320   PointSource    LogParabola       4.199       nan        18.7
# 4FGL J1913.2+0512   PointSource    LogParabola       4.211       nan        10.5
# 4FGL J1851.5+0718   PointSource    LogParabola       4.655       nan        48.0
# 4FGL J1902.2+0448   PointSource    LogParabola       4.722       nan        56.8
# 4FGL J1919.4+1313   PointSource    LogParabola       4.778       nan        18.4
# 4FGL J1900.7+0426   PointSource    LogParabola       5.199       nan        40.7
# 4FGL J1920.7+1334   PointSource    LogParabola       5.232       nan        22.7
# 4FGL J1925.7+1227   PointSource    LogParabola       5.278       nan        57.4
# 4FGL J1930.3+0911   PointSource    LogParabola       5.356       nan         5.3
# 4FGL J1925.1+0547   PointSource    LogParabola       5.371       nan         4.2
# 4FGL J1848.8+0701   PointSource    LogParabola       5.375       nan         1.3
# 4FGL J1855.2+0456   PointSource    LogParabola       5.445       nan        30.5
# 4FGL J1919.9+1358c  PointSource    LogParabola       5.465       nan        74.7
# 4FGL J1846.3+0919   PointSource    PLSuperExpCuto    5.492       nan       278.0
# 4FGL J1859.8+0411c  PointSource    LogParabola       5.518       nan        56.2
# 4FGL J1931.1+0937   PointSource    LogParabola       5.560       nan       520.0
# 4FGL J1911.8+1447   PointSource    PowerLaw          5.592       nan        42.8
# 4FGL J1920.9+1408   PointSource    LogParabola       5.743       nan        55.4
# 4FGL J1902.8+1451   PointSource    PowerLaw          5.782       nan        26.7
# 4FGL J1920.8+0418   PointSource    LogParabola       5.814       nan        40.5
# 4FGL J1900.4+0339   PointSource    LogParabola       5.950       nan       107.4
# 4FGL J1858.0+0354   PointSource    LogParabola       5.956       nan       103.8
# 4FGL J1923.2+1408e  SpatialMap     LogParabola       6.057       nan      3178.9
# 4FGL J1911.5+0311   PointSource    LogParabola       6.120       nan        57.3
# 4FGL J1918.0+0331   PointSource    LogParabola       6.196       nan        66.8
# 4FGL J1922.7+1428c  PointSource    LogParabola       6.258       nan        71.3
# 4FGL J1933.3+0726   PointSource    PowerLaw          6.380       nan       180.6
# 4FGL J1934.2+1036   PointSource    PowerLaw          6.452       nan        10.4
# 4FGL J1922.4+1453c  PointSource    LogParabola       6.569       nan        30.1
# 4FGL J1857.9+0313c  PointSource    LogParabola       6.603       nan        49.7
# 4FGL J1859.8+1545   PointSource    PowerLaw          6.846       nan        19.9
# 4FGL J1846.0+0507   PointSource    LogParabola       6.965       nan        68.0
# 4FGL J1912.0+1612   PointSource    PowerLaw          6.993       nan        22.2
# 4FGL J1857.7+0246e  RadialDisk     PowerLaw          7.023       nan       851.0
# 4FGL J1840.3+1105   PointSource    LogParabola       7.208       nan        19.5
# 4FGL J1925.3+1522c  PointSource    LogParabola       7.345       nan        22.8
# 4FGL J1858.3+0209   PointSource    PowerLaw          7.557       nan        58.6
# 4FGL J1906.1+1651   PointSource    LogParabola       7.629       nan        50.5
# 4FGL J1907.2+0126   PointSource    PowerLaw          7.822       nan        48.2
# 4FGL J1927.4+0253   PointSource    LogParabola       7.912       nan         9.3
# 4FGL J1851.0+1558   PointSource    PowerLaw          7.961       nan        19.3
# 4FGL J1935.5+1407   PointSource    PowerLaw          8.199       nan        23.7
# 4FGL J1921.4+0136   PointSource    PLSuperExpCuto    8.288       nan        69.7
# 4FGL J1942.4+0927   PointSource    PowerLaw          8.349       nan        11.5
# 4FGL J1942.7+1033   PointSource    LogParabola       8.508       nan       443.2
# 4FGL J1942.1+1142   PointSource    PowerLaw          8.598       nan        11.8
# 4FGL J1856.5+1735   PointSource    LogParabola       8.841       nan        17.9
# 4FGL J1834.3+0613   PointSource    LogParabola       9.030       nan        30.0
# 4FGL J1832.7+0618   PointSource    PowerLaw          9.373       nan        18.7
# 4FGL J1830.1+0617   PointSource    PowerLaw          9.986       nan        42.8
# 4FGL J1948.3+1207   PointSource    LogParabola      10.175       nan         5.6
# isodiff             ConstantValue  FileFunction      -----      3.44       501.4
# galdiff             MapCubeFunctio PowerLaw          ----- 282627.28     96326.5

# %%
gta.fit()
# Out:
# 2025-05-01 13:09:26 INFO    GTAnalysis.fit(): Starting fit.
# /Users/vdk/miniforge3/envs/fermipy/lib/python3.9/site-packages/scipy/interpolate/_fitpack2.py:313: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
#   '4FGL J1906.4+0723',
#   '4FGL J1906.4+0723',
#   '4FGL J1906.4+0723',
#   '4FGL J1906.9+0712',
#   '4FGL J1906.9+0712',
#   '4FGL J1906.9+0712',
#   '4FGL J1907.6+0703',
#   '4FGL J1907.6+0703',
#   '4FGL J1908.7+0812',
#   '4FGL J1908.7+0812',
#   '4FGL J1908.7+0812',
#   '4FGL J1910.2+0904c',
#   '4FGL J1910.2+0904c',
#   '4FGL J1911.0+0905',
#   '4FGL J1911.0+0905',
#   '4FGL J1911.0+0905',
#   '4FGL J1911.3+1055',
#   '4FGL J1911.3+1055',
#   '4FGL J1911.3+1055',
#   '4FGL J1911.7+1014c',
#   '4FGL J1911.7+1014c',
#   '4FGL J1911.7+1014c',
#   '4FGL J1911.8+0903c',
#   '4FGL J1911.8+0903c',
#   '4FGL J1912.0+0927',
#   '4FGL J1912.0+0927',
#   '4FGL J1912.0+0927',
#   '4FGL J1912.7+0957',
#   '4FGL J1912.7+0957',
#   '4FGL J1912.7+0957',
#   '4FGL J1913.3+0905',
#   '4FGL J1913.3+0905',
#   '4FGL J1913.3+0905',
#   '4FGL J1913.3+1019',
#   '4FGL J1913.3+1019',
#   '4FGL J1914.5+1107c',
#   '4FGL J1914.5+1107c',
#   '4FGL J1914.5+1107c',
#   '4FGL J1914.7+1012c',
#   '4FGL J1914.7+1012c',
#   '4FGL J1914.7+1012c',
#   '4FGL J1916.3+1108',
#   '4FGL J1916.3+1108',
#   '4FGL J1916.3+1108',
#   'galdiff',
#   'galdiff',
#   'isodiff'],
#  'par_names': ['Prefactor',
#   'IndexS',
#   'ExpfactorS',
#   'norm',
#   'alpha',
#   'beta',
#   'norm',
#   'alpha',
#   'beta',
#   'norm',
#   'alpha',
#   'beta',
#   'Prefactor',
#   'IndexS',
#   'ExpfactorS',
#   'norm',
#   'alpha',
#   'beta',
#   'Prefactor',
#   'Index',
#   'norm',
#   'alpha',
#   'beta',
#   'Prefactor',
#   'Index',
#   'norm',
#   'alpha',
#   'beta',
#   'norm',
#   'alpha',
#   'beta',
#   'norm',
#   'alpha',
#   'beta',
#   'Prefactor',
#   'Index',
#   'norm',
#   'alpha',
#   'beta',
#   'norm',
#   'alpha',
#   'beta',
#   'Prefactor',
#   'IndexS',
#   'ExpfactorS',
#   'Prefactor',
#   'Index',
#   'norm',
#   'alpha',
#   'beta',
#   'norm',
#   'alpha',
#   'beta',
#   'norm',
#   'alpha',
#   'beta',
#   'Prefactor',
#   'Index',
#   'Normalization'],
#  'config': {'optimizer': 'MINUIT',
#   'tol': 0.001,
#   'max_iter': 100,
#   'init_lambda': 0.0001,
#   'retries': 3,
#   'min_fit_quality': 2,
#   'verbosity': 0,
#   'covar': True,
#   'reoptimize': False},
#  'niter': 1}

# %%
plt.clf()
tsmap_no_sources = gta.tsmap(prefix='TSmap_no_sources',make_plots=True,write_fits=True,write_npy=True)

# %%
plt.clf()
fig = plt.figure(figsize=(14,6))
ROIPlotter(tsmap_no_sources['sqrt_ts'],roi=gta.roi, graticule_radii=[0.6]).plot(interpolation='bicubic',levels=[0,3,5],vmin=0,vmax=5,subplot=121,cmap='magma', zoom = 7)
plt.gca().set_title('Sqrt(TS)')
ROIPlotter(tsmap_no_sources['npred'],roi=gta.roi, graticule_radii=[0.6]).plot(interpolation='bicubic',vmin=0,vmax=50,subplot=122,cmap='magma', zoom = 7)
plt.gca().set_title('NPred')
plt.show()

# %%
import numpy as np

# 1) Get your ROI center in Galactic coordinates
glon0, glat0 = gta.config['selection']['glon'], gta.config['selection']['glat']

# 2) Compute the two offsets (0.2° at 45°: upper‐right and lower‐left)
d = 0.2/np.sqrt(2)
pos = [
    (glon0 - d, glat0 + d),   # upper‐right
    (glon0 + d, glat0 - d)    # lower‐left
]

# 3) (Optional) free all sources beyond 2° so only the center region floats
gta.free_sources(free=False)
gta.free_sources(skydir=gta.roi[gta.roi.sources[0].name].skydir,distance=[2.0],free=True)


gta.delete_source('4FGL J1908.6+0915e')
gta.delete_source('disk1')
gta.delete_source('disk2')
gta.delete_source('ps1')
gta.delete_source('ps2')

# 5) Add your two point sources
for i, (gl, gb) in enumerate(pos, 1):
    gta.add_source(
        f'ps{i}',
        {
          'glon':         gl,
          'glat':         gb,
          'SpatialModel': 'PointSource',
          'SpectrumType': 'PowerLaw',
          # Optional: give starting values & bounds for a PL
          'Index':     dict(value=-2.3,    scale=1.0, min=-5.0, max=-1.0),
          'Prefactor': dict(value=1e-13,   scale=1e-13, min=1e-16, max=1e-11),
          'Scale':     dict(value=1000.0,  scale=1.0,   min=30.0,  max=1e5)
        },
        free=True,             # float all parameters in the next fit
        init_source=True,      # do an initial TS‐map+fit around each point
        save_source_maps=True  # write out their srcmap cubes
    )

# 6) Run your fit
gta.optimize()
gta.fit()

# 7) Check the results
gta.print_model()
# Out:
# 2025-05-01 13:06:28 INFO    GTAnalysis.free_source(): Fixing parameters for 4FGL J1921.4+0136     : ['Prefactor', 'IndexS', 'ExpfactorS']
# 2025-05-01 13:06:29 INFO    GTAnalysis.free_source(): Freeing parameters for ps1                   : ['Prefactor', 'Index']
# 2025-05-01 13:06:29 INFO    GTAnalysis.free_source(): Freeing parameters for ps2                   : ['Prefactor', 'Index']
# 2025-05-01 13:06:29 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1910.2+0904c    : ['Prefactor', 'Index']
# 2025-05-01 13:06:29 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1911.0+0905     : ['norm', 'alpha', 'beta']
# 2025-05-01 13:06:29 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1911.8+0903c    : ['Prefactor', 'Index']
# 2025-05-01 13:06:29 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1908.7+0812     : ['norm', 'alpha', 'beta']
# 2025-05-01 13:06:29 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1912.0+0927     : ['norm', 'alpha', 'beta']
# 2025-05-01 13:06:29 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1913.3+0905     : ['Prefactor', 'IndexS', 'ExpfactorS']
# 2025-05-01 13:06:29 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1911.7+1014c    : ['norm', 'alpha', 'beta']
# 2025-05-01 13:06:29 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1912.7+0957     : ['norm', 'alpha', 'beta']
# 2025-05-01 13:06:29 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1913.3+1019     : ['Prefactor', 'Index']
# 2025-05-01 13:06:29 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1906.4+0723     : ['Prefactor', 'IndexS', 'ExpfactorS']
# 2025-05-01 13:06:29 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1911.3+1055     : ['norm', 'alpha', 'beta']
# 2025-05-01 13:06:29 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1914.7+1012c    : ['norm', 'alpha', 'beta']
# 2025-05-01 13:06:29 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J1906.9+0712     : ['norm', 'alpha', 'beta']
# 2025-05-01 13:06:29 INFO    GTAnalysis.free_source(): Freeing parameters for isodiff               : ['Normalization']
# 2025-05-01 13:06:29 INFO    GTAnalysis.free_source(): Freeing parameters for galdiff               : ['Prefactor', 'Index']
# 2025-05-01 13:06:29 ERROR   GTAnalysis.delete_source(): No source with name: 4FGL J1908.6+0915e
# 2025-05-01 13:06:29 ERROR   GTAnalysis.delete_source(): No source with name: disk1
# 2025-05-01 13:06:29 ERROR   GTAnalysis.delete_source(): No source with name: disk2
# 2025-05-01 13:06:29 INFO    GTAnalysis.delete_source(): Deleting source ps1
# 2025-05-01 13:06:29 INFO    GTAnalysis.delete_source(): Deleting source ps2
# 2025-05-01 13:06:29 INFO    GTAnalysis.add_source(): Adding source ps1
# 2025-05-01 13:06:31 INFO    GTAnalysis.add_source(): Adding source ps2
# 2025-05-01 13:06:31 INFO    GTAnalysis.optimize(): Starting
# Joint fit  ['galdiff', '4FGL J1923.2+1408e', '4FGL J1907.9+0602', '4FGL J1911.0+0905', '4FGL J1857.7+0246e']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 44
#      26     gta.add_source(
#      27         f'ps{i}',
#      28         {
#    (...)
#      40         save_source_maps=True  # write out their srcmap cubes
#      41     )
#      43 # 6) Run your fit
# ---> 44 gta.optimize()
#      45 gta.fit()
#      47 # 7) Check the results
#
# File ~/miniforge3/envs/fermipy/lib/python3.9/site-packages/fermipy/gtanalysis.py:2343, in GTAnalysis.optimize(self, **kwargs)
#    2340         break
#    2342 print ("Joint fit ", joint_norm_fit)
# -> 2343 self.fit(loglevel=logging.DEBUG, **config['optimizer'])
#    2344 self.free_sources(free=False, loglevel=logging.DEBUG)
#    2346 # Step through remaining sources and re-fit normalizations
#    2347 # FIXME, EAC, use npred_wt here
#
# File ~/miniforge3/envs/fermipy/lib/python3.9/site-packages/fermipy/gtanalysis.py:3065, in GTAnalysis.fit(self, update, **kwargs)
#    3061     return o
#    3063 saved_state = LikelihoodState(self.like)
# -> 3065 fit_output = self._fit(**config)
#    3066 o.update(fit_output)
#    3068 self.logger.debug("Fit complete.")
#
# File ~/miniforge3/envs/fermipy/lib/python3.9/site-packages/fermipy/gtanalysis.py:2977, in GTAnalysis._fit(self, **kwargs)
#    2975     return self._fit_newton(**kwargs)
#    2976 else:
# -> 2977     return self._fit_optimizer_iter(**kwargs)
#
# File ~/miniforge3/envs/fermipy/lib/python3.9/site-packages/fermipy/gtanalysis.py:2887, in GTAnalysis._fit_optimizer_iter(self, **kwargs)
#    2883     errinv = 1. / o['errors']
#    2884     o['correlation'] = \
#    2885         o['covariance'] * errinv[:, np.newaxis] * errinv[np.newaxis, :]
# -> 2887 free_params = self.get_params(True)
#    2888 for i, p in enumerate(free_params):
#    2889     o['values'][i] = p['value']
#
# File ~/miniforge3/envs/fermipy/lib/python3.9/site-packages/fermipy/gtanalysis.py:2150, in GTAnalysis.get_params(self, freeonly)
#    2148 #            for parName in self.get_free_source_params(srcName):
#    2149             for parName in par_names:
# -> 2150                 idx = self.like.par_index(srcName, parName)
#    2151                 par = self.like.model[idx]
#    2153                 if freeonly and not par.isFree():
#
# File ~/miniforge3/envs/fermipy/lib/python3.9/site-packages/fermitools/SummedLikelihood.py:229, in SummedLikelihood.par_index(self, srcname, parname)
#     228 def par_index(self, srcname, parname):
# --> 229     return self.components[0].par_index(srcname, parname)
#
# File ~/miniforge3/envs/fermipy/lib/python3.9/site-packages/fermitools/AnalysisBase.py:174, in AnalysisBase.par_index(self, srcName, parName)
#     172 pars = pyLike.ParameterVector()
#     173 self[src].src.spectrum().getParams(pars)
# --> 174 for par in pars:
#     175     par_index += 1
#     176     if src == srcName and par.getName() == parName:
#
# KeyboardInterrupt:

# %%
gta.print_roi()
# Out:
# 2025-05-01 12:48:17 INFO    GTAnalysis.fit(): Starting fit.
# /Users/vdk/miniforge3/envs/fermipy/lib/python3.9/site-packages/scipy/interpolate/_fitpack2.py:313: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# 2025-05-01 12:48:55 INFO    GTAnalysis.fit(): Fit returned successfully. Quality:   2 Status: 102
# 2025-05-01 12:48:55 INFO    GTAnalysis.fit(): LogLike:  -229464.254 DeltaLogLike:       16.110
# 2025-05-01 12:48:55 INFO    GTAnalysis.print_roi():
# name                SpatialModel   SpectrumType     offset        ts       npred
# --------------------------------------------------------------------------------
# disk1               RadialDisk     PowerLaw          0.200      6.92        47.9
# disk2               RadialDisk     PowerLaw          0.200      6.95        51.5
# 4FGL J1910.2+0904c  PointSource    PowerLaw          0.430    113.02       215.0
# 4FGL J1911.0+0905   PointSource    LogParabola       0.619   2658.03      1398.3
# 4FGL J1911.8+0903c  PointSource    PowerLaw          0.808     34.52       124.1
# 4FGL J1912.0+0927   PointSource    LogParabola       0.869     13.18        61.3
# 4FGL J1908.7+0812   PointSource    LogParabola       1.056     13.38        61.8
# 4FGL J1913.3+0905   PointSource    PLSuperExpCuto    1.183     33.40        88.1
# 4FGL J1912.7+0957   PointSource    LogParabola       1.226     19.34        68.0
# 4FGL J1911.7+1014c  PointSource    LogParabola       1.241     11.91        42.5
# 4FGL J1913.3+1019   PointSource    PowerLaw          1.586    101.21       156.4
# 4FGL J1914.7+1012c  PointSource    LogParabola       1.777     12.34        40.9
# 4FGL J1911.3+1055   PointSource    LogParabola       1.795      9.03        36.0
# 4FGL J1906.4+0723   PointSource    PLSuperExpCuto    1.939    306.11       386.5
# 4FGL J1906.9+0712   PointSource    LogParabola       2.084    214.94       314.5
# 4FGL J1907.6+0703   PointSource    PowerLaw          2.213     29.57        97.4
# 4FGL J1914.5+1107c  PointSource    LogParabola       2.362      7.63        42.7
# 4FGL J1901.1+0730   PointSource    LogParabola       2.547     81.35       123.9
# 4FGL J1916.3+1108   PointSource    LogParabola       2.667     30.29        86.2
# 4FGL J1902.5+0654   PointSource    LogParabola       2.788     46.32        91.6
# 4FGL J1906.2+0631   PointSource    LogParabola       2.797      2.41        22.4
# 4FGL J1857.2+0941   PointSource    PLSuperExpCuto    2.832      6.68        17.5
# 4FGL J1857.5+0756   PointSource    LogParabola       3.036       nan        14.3
# 4FGL J1915.3+1149   PointSource    LogParabola       3.042       nan        52.8
# 4FGL J1904.7+0615   PointSource    LogParabola       3.159       nan         9.7
# 4FGL J1907.9+0602   PointSource    PLSuperExpCuto    3.230       nan      1520.8
# 4FGL J1856.2+0749   PointSource    LogParabola       3.373       nan        30.3
# 4FGL J1855.2+0756   PointSource    PowerLaw          3.561       nan        42.6
# 4FGL J1858.5+0640   PointSource    PowerLaw          3.599       nan        97.8
# 4FGL J1918.1+1215c  PointSource    LogParabola       3.808       nan        19.0
# 4FGL J1903.8+0531   PointSource    LogParabola       3.919       nan       137.4
# 4FGL J1919.2+0618   PointSource    LogParabola       3.951       nan         8.4
# 4FGL J1900.9+0538   PointSource    LogParabola       4.100       nan        31.4
# 4FGL J1912.5+1320   PointSource    LogParabola       4.199       nan        18.7
# 4FGL J1913.2+0512   PointSource    LogParabola       4.211       nan        10.5
# 4FGL J1851.5+0718   PointSource    LogParabola       4.655       nan        48.0
# 4FGL J1902.2+0448   PointSource    LogParabola       4.722       nan        56.8
# 4FGL J1919.4+1313   PointSource    LogParabola       4.778       nan        18.4
# 4FGL J1900.7+0426   PointSource    LogParabola       5.199       nan        40.7
# 4FGL J1920.7+1334   PointSource    LogParabola       5.232       nan        22.7
# 4FGL J1925.7+1227   PointSource    LogParabola       5.278       nan        57.4
# 4FGL J1930.3+0911   PointSource    LogParabola       5.356       nan         5.3
# 4FGL J1925.1+0547   PointSource    LogParabola       5.371       nan         4.2
# 4FGL J1848.8+0701   PointSource    LogParabola       5.375       nan         1.3
# 4FGL J1855.2+0456   PointSource    LogParabola       5.445       nan        30.5
# 4FGL J1919.9+1358c  PointSource    LogParabola       5.465       nan        74.7
# 4FGL J1846.3+0919   PointSource    PLSuperExpCuto    5.492       nan       278.0
# 4FGL J1859.8+0411c  PointSource    LogParabola       5.518       nan        56.2
# 4FGL J1931.1+0937   PointSource    LogParabola       5.560       nan       520.0
# 4FGL J1911.8+1447   PointSource    PowerLaw          5.592       nan        42.8
# 4FGL J1920.9+1408   PointSource    LogParabola       5.743       nan        55.4
# 4FGL J1902.8+1451   PointSource    PowerLaw          5.782       nan        26.7
# 4FGL J1920.8+0418   PointSource    LogParabola       5.814       nan        40.5
# 4FGL J1900.4+0339   PointSource    LogParabola       5.950       nan       107.4
# 4FGL J1858.0+0354   PointSource    LogParabola       5.956       nan       103.8
# 4FGL J1923.2+1408e  SpatialMap     LogParabola       6.057       nan      3178.9
# 4FGL J1911.5+0311   PointSource    LogParabola       6.120       nan        57.3
# 4FGL J1918.0+0331   PointSource    LogParabola       6.196       nan        66.8
# 4FGL J1922.7+1428c  PointSource    LogParabola       6.258       nan        71.3
# 4FGL J1933.3+0726   PointSource    PowerLaw          6.380       nan       180.6
# 4FGL J1934.2+1036   PointSource    PowerLaw          6.452       nan        10.4
# 4FGL J1922.4+1453c  PointSource    LogParabola       6.569       nan        30.1
# 4FGL J1857.9+0313c  PointSource    LogParabola       6.603       nan        49.7
# 4FGL J1859.8+1545   PointSource    PowerLaw          6.846       nan        19.9
# 4FGL J1846.0+0507   PointSource    LogParabola       6.965       nan        68.0
# 4FGL J1912.0+1612   PointSource    PowerLaw          6.993       nan        22.2
# 4FGL J1857.7+0246e  RadialDisk     PowerLaw          7.023       nan       851.0
# 4FGL J1840.3+1105   PointSource    LogParabola       7.208       nan        19.5
# 4FGL J1925.3+1522c  PointSource    LogParabola       7.345       nan        22.8
# 4FGL J1858.3+0209   PointSource    PowerLaw          7.557       nan        58.6
# 4FGL J1906.1+1651   PointSource    LogParabola       7.629       nan        50.5
# 4FGL J1907.2+0126   PointSource    PowerLaw          7.822       nan        48.2
# 4FGL J1927.4+0253   PointSource    LogParabola       7.912       nan         9.3
# 4FGL J1851.0+1558   PointSource    PowerLaw          7.961       nan        19.3
# 4FGL J1935.5+1407   PointSource    PowerLaw          8.199       nan        23.7
# 4FGL J1921.4+0136   PointSource    PLSuperExpCuto    8.288       nan        69.7
# 4FGL J1942.4+0927   PointSource    PowerLaw          8.349       nan        11.5
# 4FGL J1942.7+1033   PointSource    LogParabola       8.508       nan       443.2
# 4FGL J1942.1+1142   PointSource    PowerLaw          8.598       nan        11.8
# 4FGL J1856.5+1735   PointSource    LogParabola       8.841       nan        17.9
# 4FGL J1834.3+0613   PointSource    LogParabola       9.030       nan        30.0
# 4FGL J1832.7+0618   PointSource    PowerLaw          9.373       nan        18.7
# 4FGL J1830.1+0617   PointSource    PowerLaw          9.986       nan        42.8
# 4FGL J1948.3+1207   PointSource    LogParabola      10.175       nan         5.6
# isodiff             ConstantValue  FileFunction      -----      2.90       457.5
# galdiff             MapCubeFunctio PowerLaw          ----- 290982.65     96431.5

# %%
plt.clf()
tsmap_postfit = gta.tsmap(prefix='TSmap_2disk',make_plots=True,write_fits=True,write_npy=True)
# Out:
# 2025-05-01 12:49:29 INFO    GTAnalysis.tsmap(): Generating TS map
# 2025-05-01 12:49:30 INFO    GTAnalysis._make_tsmap_fast(): Fitting test source.
# 2025-05-01 12:49:39 INFO    GTAnalysis.tsmap(): Finished TS map
# 2025-05-01 12:49:41 WARNING GTAnalysis.tsmap(): Saving TS maps in .npy files is disabled b/c of incompatibilities in python3, remove the maps from the /Users/vdk/software/my_codebase/python/data_analysis/fermi_lat/sgr1900/output_sgr_5GeV_FRONTBACK/TSmap_2disk_pointsource_powerlaw_2.00_tsmap.npy
# 2025-05-01 12:49:41 INFO    GTAnalysis.tsmap(): Execution time: 12.11 s

# %%
plt.clf()
fig = plt.figure(figsize=(14,6))
ROIPlotter(tsmap_postfit['sqrt_ts'],roi=gta.roi, graticule_radii=[0.6]).plot(interpolation='bicubic',levels=[0,3,5],vmin=0,vmax=5,subplot=121,cmap='magma', zoom = 6)
plt.gca().set_title('Sqrt(TS)')
ROIPlotter(tsmap_postfit['npred'],roi=gta.roi, graticule_radii=[0.6]).plot(interpolation='bicubic',vmin=0,vmax=20,subplot=122,cmap='magma', zoom = 6)
plt.gca().set_title('NPred')
plt.show()

# %%
model = {
    'SpatialModel': 'RadialDisk',
    'Radius':       0.6,            # 0.6° disk
    'SpectrumType': 'PowerLaw',
    'Index':        -2.238266135060183,            # your best‐guess photon index
    'Prefactor':    1.1975660845479393e-13,          # normalization (ph/cm2/s/MeV at the pivot)
    'Scale':        4195.53759765625          # pivot energy in MeV
}
resid = gta.residmap('sgr1900_roi_fit',model=model)
# Out:
# 2025-04-30 15:56:14 INFO    GTAnalysis.residmap(): Generating residual maps
# 2025-04-30 15:56:14 INFO    GTAnalysis.add_source(): Adding source residmap_testsource
# 2025-04-30 15:56:24 INFO    GTAnalysis.delete_source(): Deleting source residmap_testsource
# 2025-04-30 15:56:25 INFO    GTAnalysis.residmap(): Finished residual maps
# 2025-04-30 15:56:27 WARNING GTAnalysis.residmap(): Saving maps in .npy files is disabled b/c of incompatibilities in python3, remove the maps from the /Users/vdk/software/my_codebase/python/data_analysis/fermi_lat/sgr1900/output_sgr_1GeV_15deg_region/sgr1900_roi_fit_radialdisk_powerlaw_-2.24_residmap.npy
# 2025-04-30 15:56:27 INFO    GTAnalysis.residmap(): Execution time: 13.58 s

# %%
plt.clf()
fig = plt.figure(figsize=(14,6))
ROIPlotter(resid['sigma'],roi=gta.roi).plot(vmin=-5,vmax=5,levels=[-5,-3,3,5,7,9],subplot=121,cmap='RdBu_r', zoom = 7)
plt.gca().set_title('Significance')
ROIPlotter(resid['excess'],roi=gta.roi).plot(vmin=-200,vmax=200,subplot=122,cmap='RdBu_r', zoom = 7)
plt.gca().set_title('Excess Counts')
# Out:
# Text(0.5, 1.0, 'Excess Counts')

# %%
resid_noj0621 = gta.residmap('sgr1900_roi_fit_no4FGL',
                model=model,
                exclude=['4FGL J1908.6+0915e'])
# Out:
# 2025-04-30 15:58:48 INFO    GTAnalysis.residmap(): Generating residual maps
# 2025-04-30 15:58:48 INFO    GTAnalysis.add_source(): Adding source residmap_testsource
# 2025-04-30 15:58:59 INFO    GTAnalysis.delete_source(): Deleting source residmap_testsource
# 2025-04-30 15:59:00 INFO    GTAnalysis.residmap(): Finished residual maps
# 2025-04-30 15:59:02 WARNING GTAnalysis.residmap(): Saving maps in .npy files is disabled b/c of incompatibilities in python3, remove the maps from the /Users/vdk/software/my_codebase/python/data_analysis/fermi_lat/sgr1900/output_sgr_1GeV_15deg_region/sgr1900_roi_fit_no4FGL_radialdisk_powerlaw_-2.24_residmap.npy
# 2025-04-30 15:59:02 INFO    GTAnalysis.residmap(): Execution time: 13.43 s

# %%
plt.clf()
fig = plt.figure(figsize=(14,6))
ROIPlotter(resid_noj0621['sigma'],roi=gta.roi).plot(vmin=-5,vmax=5,levels=[-5,-3,3,5,7,9],subplot=121,cmap='RdBu_r', zoom = 7)
plt.gca().set_title('Significance')
ROIPlotter(resid_noj0621['excess'],roi=gta.roi).plot(vmin=-200,vmax=200,subplot=122,cmap='RdBu_r', zoom = 7)
plt.gca().set_title('Excess Counts')
# Out:
# Text(0.5, 1.0, 'Excess Counts')

# %%
tsmap_noj0621 = gta.tsmap('sgr1900_noj0621',
                model=model,
                exclude=['4FGL J1908.6+0915e'])
# Out:
# 2025-04-30 16:00:02 INFO    GTAnalysis.tsmap(): Generating TS map
# 2025-04-30 16:00:14 INFO    GTAnalysis._make_tsmap_fast(): Fitting test source.
# 2025-04-30 16:01:30 INFO    GTAnalysis.tsmap(): Finished TS map
# 2025-04-30 16:01:32 WARNING GTAnalysis.tsmap(): Saving TS maps in .npy files is disabled b/c of incompatibilities in python3, remove the maps from the /Users/vdk/software/my_codebase/python/data_analysis/fermi_lat/sgr1900/output_sgr_1GeV_15deg_region/sgr1900_noj0621_radialdisk_powerlaw_-2.24_tsmap.npy
# 2025-04-30 16:01:32 INFO    GTAnalysis.tsmap(): Execution time: 89.41 s

# %%
plt.clf()
fig = plt.figure(figsize=(6,6))
ROIPlotter(tsmap_noj0621['sqrt_ts'],roi=gta.roi).plot(vmin=0,vmax=5,levels=[3,5,7,9],subplot=111,cmap='magma', zoom = 7)
plt.gca().set_title('sqrt(TS)')
plt.show()

# %%
plt.clf()
tsmap_ = gta.tsmap(prefix='TSmap_sgr1900_all',make_plots=True,write_fits=True,write_npy=True)
# Out:
# 2025-04-30 16:04:01 INFO    GTAnalysis.tsmap(): Generating TS map
# 2025-04-30 16:04:05 INFO    GTAnalysis._make_tsmap_fast(): Fitting test source.
# 2025-04-30 16:05:03 INFO    GTAnalysis.tsmap(): Finished TS map
# 2025-04-30 16:05:05 WARNING GTAnalysis.tsmap(): Saving TS maps in .npy files is disabled b/c of incompatibilities in python3, remove the maps from the /Users/vdk/software/my_codebase/python/data_analysis/fermi_lat/sgr1900/output_sgr_1GeV_15deg_region/TSmap_sgr1900_all_pointsource_powerlaw_2.00_tsmap.npy
# 2025-04-30 16:05:05 INFO    GTAnalysis.tsmap(): Execution time: 64.76 s

# %%
plt.clf()
fig = plt.figure(figsize=(14,6))
ROIPlotter(tsmap_['sqrt_ts'],roi=gta.roi).plot(levels=[0,3,5,7],vmin=0,vmax=5,subplot=121,cmap='magma', zoom = 7)
plt.gca().set_title('Sqrt(TS)')
ROIPlotter(tsmap_['npred'],roi=gta.roi).plot(vmin=0,vmax=100,subplot=122,cmap='magma', zoom = 7)
plt.gca().set_title('NPred')
plt.show()

# %%
import numpy as np

# 1) Get your ROI center in Galactic coordinates
glon0, glat0 = gta.config['selection']['glon'], gta.config['selection']['glat']

# 2) Compute the two offsets (0.2° at 45°: upper‐right and lower‐left)
d = 0.2/np.sqrt(2)
pos = [
    (glon0 - d, glat0 + d),   # upper right
    (glon0 + d, glat0 - d)    # lower left
]

pos
# Out:
# [(42.98347864376269, 0.5715213562373095),
#  (43.266321356237306, 0.2886786437626905)]

# %%
# Free only central objects
gta.free_sources(skydir=gta.roi[gta.roi.sources[0].name].skydir,distance=[2.0],free=True)

# 3) (Optional) remove the original big disk
gta.delete_source('4FGL J1908.6+0915e')
gta.delete_source('disk1')
gta.delete_source('disk2')
# 4) Add your two small disks
for i, (gl, gb) in enumerate(pos, 1):
    gta.add_source(
        f'disk{i}',
        {
          'glon':         gl,
          'glat':         gb,
          'SpatialModel': 'RadialDisk',
          'Radius':       dict(value=0.2, scale=1.0, min=0.05, max=1.0),
          'SpectrumType': 'PowerLaw',
        },
        free=True,             # free all parameters of disk{i}
        init_source=True,      # do a quick local fit for each disk
        save_source_maps=True  # store their srcmaps for later
    )

# 5) Re‐optimize and fit the whole ROI
# Out:
# 2025-04-30 16:15:09 ERROR   GTAnalysis.delete_source(): No source with name: 4FGL J1908.6+0915e
# 2025-04-30 16:15:09 INFO    GTAnalysis.delete_source(): Deleting source disk1
# 2025-04-30 16:15:10 INFO    GTAnalysis.delete_source(): Deleting source disk2
# 2025-04-30 16:15:10 INFO    GTAnalysis.add_source(): Adding source disk1
# 2025-04-30 16:15:20 INFO    GTAnalysis.add_source(): Adding source disk2

# %%
gta.print_model()
# Out:
# 2025-04-30 16:15:28 INFO    GTAnalysis.print_model():
# sourcename            offset    norm  eflux     index        ts       npred free
# --------------------------------------------------------------------------------
# disk1                  0.200   1.000  6.55e-06   2.00       nan       687.2    *
# disk2                  0.200   1.000  6.55e-06   2.00       nan       684.3    *
# 4FGL J1910.2+0904c     0.430   0.452  1.11e-05   2.43    294.15      2321.2    *
# 4FGL J1911.0+0905      0.619   0.696  5.46e-05   2.19   6406.82     10452.2    *
# 4FGL J1911.8+0903c     0.808   0.529  5.62e-06   2.33     68.35      1031.5    *
# 4FGL J1912.0+0927      0.869   0.337  4.05e-06   2.76     89.59      1230.6    *
# 4FGL J1908.7+0812      1.056   1.750  6.74e-06   3.21    239.75      2368.4    *
# 4FGL J1913.3+0905      1.183   0.780   6.3e-06   3.28    320.68      1807.4    *
# 4FGL J1912.7+0957      1.226   0.488  4.86e-06   2.85    148.00      1512.6    *
# 4FGL J1911.7+1014c     1.241   0.340  3.33e-06   2.99     48.77       874.8    *
# 4FGL J1830.1+0617      9.986   2.037  1.83e-06   2.51    115.96       319.7
# 4FGL J1948.3+1207     10.175   0.737  1.06e-06   3.39     93.87       269.0
# isodiff                  ---   0.133   0.00428   2.12     11.05      3034.6    *
# galdiff                  ---   0.985     0.128   0.012848986.64   1108002.2    *

# %%
gta.fit()
# Out:
# 2025-04-30 16:15:36 INFO    GTAnalysis.fit(): Starting fit.
# 2025-04-30 16:16:44 INFO    GTAnalysis.fit(): Fit returned successfully. Quality:   3 Status:   0
# 2025-04-30 16:16:44 INFO    GTAnalysis.fit(): LogLike:   222709.562 DeltaLogLike:       17.312
# {'fit_quality': 3,
#  'fit_status': 0,
#  'fit_success': True,
#  'dloglike': 17.312421568436548,
#  'edm': 0.0005992537107884161,
#  'loglike': 222709.56158103538,
#  'covariance': array([[ 1.13230042e-03, -8.32661972e-04,  2.03285650e-03, ...,
#          -1.24379057e-06,  2.70882489e-06,  6.91941611e-05],
#         [-8.32661972e-04,  2.26704536e-03, -1.07946297e-03, ...,
#          -6.52662333e-06, -6.10783206e-06,  4.27033028e-06],
#         [ 2.03285650e-03, -1.07946297e-03,  8.70471352e-03, ...,
#           4.50723361e-06,  4.34223210e-06,  1.17462414e-05],
#         ...,
#         [-1.24379057e-06, -6.52662333e-06,  4.50723361e-06, ...,
#           2.56550551e-06,  1.31722314e-06, -2.73531524e-05],
#         [ 2.70882489e-06, -6.10783206e-06,  4.34223210e-06, ...,
#           1.31722314e-06,  2.83913044e-06,  2.71781084e-05],
#         [ 6.91941611e-05,  4.27033028e-06,  1.17462414e-05, ...,
#          -2.73531524e-05,  2.71781084e-05,  2.02235848e-03]]),
#  'correlation': array([[ 1.        , -0.51970607,  0.64751323, ..., -0.02307703,
#           0.04777574,  0.04572561],
#         [-0.51970607,  1.        , -0.24299672, ..., -0.08557994,
#          -0.07613149,  0.00199435],
#         [ 0.64751323, -0.24299672,  1.        , ...,  0.03016104,
#           0.02762124,  0.00279958],
#         ...,
#         [-0.02307703, -0.08557994,  0.03016104, ...,  1.        ,
#           0.48806785, -0.3797448 ],
#         [ 0.04777574, -0.07613149,  0.02762124, ...,  0.48806785,
#           1.        ,  0.35867201],
#         [ 0.04572561,  0.00199435,  0.00279958, ..., -0.3797448 ,
#           0.35867201,  1.        ]]),
#  'values': array([ 0.77507822,  2.69111316,  0.27916319,  1.75413889,  3.23462157,
#         -0.01885926,  0.44102704,  2.43256859,  0.69403991,  2.26128522,
#          0.09019955,  0.47695877,  3.58743304, -0.23915761,  0.3393329 ,
#          3.1463481 , -0.16377983,  0.53039771,  2.33928177,  0.3329299 ,
#          2.5857955 ,  0.33381768,  0.48763243,  2.56992681,  0.46152052,
#          0.7805728 ,  1.93789627,  1.34288766,  0.32524441,  2.17467631,
#          1.36877183,  2.86421408, -0.12939562,  0.42252139,  0.58156959,
#          0.98465529,  0.01248731,  0.13498403]),
#  'errors': array([0.03364967, 0.0476135 , 0.09329905, 0.13296716, 0.17108428,
#         0.1180454 , 0.04089155, 0.08526293, 0.02043564, 0.03020779,
#         0.01782413, 0.125856  , 0.2199579 , 0.04905637, 0.06198355,
#         0.17587873, 0.04849893, 0.10433538, 0.15321367, 0.05218624,
#         0.22065509, 0.25578763, 0.06842362, 0.19740956, 0.32149111,
#         0.06375732, 0.17407271, 0.30167105, 0.03318954, 0.09481227,
#         0.22185884, 0.15580276, 0.05554921, 0.12862587, 0.15412198,
#         0.00160172, 0.00168497, 0.04497064]),
#  'indices': array([125, 126, 128, 145, 146, 147, 149, 150, 152, 153, 154, 156, 157,
#         158, 164, 165, 166, 168, 169, 174, 175, 176, 185, 186, 187, 193,
#         194, 196, 198, 199, 205, 206, 207, 313, 316, 319, 320, 322]),
#  'is_norm': array([ True, False, False,  True, False, False,  True, False,  True,
#         False, False,  True, False, False,  True, False, False,  True,
#         False,  True, False, False,  True, False, False,  True, False,
#         False,  True, False,  True, False, False,  True,  True,  True,
#         False,  True]),
#  'src_names': ['4FGL J1906.4+0723',
#   '4FGL J1906.4+0723',
#   '4FGL J1906.4+0723',
#   '4FGL J1908.7+0812',
#   '4FGL J1908.7+0812',
#   '4FGL J1908.7+0812',
#   '4FGL J1910.2+0904c',
#   '4FGL J1910.2+0904c',
#   '4FGL J1911.0+0905',
#   '4FGL J1911.0+0905',
#   '4FGL J1911.0+0905',
#   '4FGL J1911.3+1055',
#   '4FGL J1911.3+1055',
#   '4FGL J1911.3+1055',
#   '4FGL J1911.7+1014c',
#   '4FGL J1911.7+1014c',
#   '4FGL J1911.7+1014c',
#   '4FGL J1911.8+0903c',
#   '4FGL J1911.8+0903c',
#   '4FGL J1912.0+0927',
#   '4FGL J1912.0+0927',
#   '4FGL J1912.0+0927',
#   '4FGL J1912.7+0957',
#   '4FGL J1912.7+0957',
#   '4FGL J1912.7+0957',
#   '4FGL J1913.3+0905',
#   '4FGL J1913.3+0905',
#   '4FGL J1913.3+0905',
#   '4FGL J1913.3+1019',
#   '4FGL J1913.3+1019',
#   '4FGL J1914.7+1012c',
#   '4FGL J1914.7+1012c',
#   '4FGL J1914.7+1012c',
#   'disk1',
#   'disk2',
#   'galdiff',
#   'galdiff',
#   'isodiff'],
#  'par_names': ['Prefactor',
#   'IndexS',
#   'ExpfactorS',
#   'norm',
#   'alpha',
#   'beta',
#   'Prefactor',
#   'Index',
#   'norm',
#   'alpha',
#   'beta',
#   'norm',
#   'alpha',
#   'beta',
#   'norm',
#   'alpha',
#   'beta',
#   'Prefactor',
#   'Index',
#   'norm',
#   'alpha',
#   'beta',
#   'norm',
#   'alpha',
#   'beta',
#   'Prefactor',
#   'IndexS',
#   'ExpfactorS',
#   'Prefactor',
#   'Index',
#   'norm',
#   'alpha',
#   'beta',
#   'Prefactor',
#   'Prefactor',
#   'Prefactor',
#   'Index',
#   'Normalization'],
#  'config': {'optimizer': 'MINUIT',
#   'tol': 0.001,
#   'max_iter': 100,
#   'init_lambda': 0.0001,
#   'retries': 3,
#   'min_fit_quality': 2,
#   'verbosity': 0,
#   'covar': True,
#   'reoptimize': False},
#  'niter': 1}

# %%
gta.print_model()
# Out:
# 2025-04-30 16:21:37 INFO    GTAnalysis.print_model():
# sourcename            offset    norm  eflux     index        ts       npred free
# --------------------------------------------------------------------------------
# disk1                  0.200   0.423  2.77e-06   2.00     13.12       290.4    *
# disk2                  0.200   0.582  3.81e-06   2.00     19.80       398.0    *
# 4FGL J1910.2+0904c     0.430   0.441  1.09e-05   2.43    281.62      2266.6    *
# 4FGL J1911.0+0905      0.619   0.694  5.44e-05   2.19   6386.05     10424.0    *
# 4FGL J1911.8+0903c     0.808   0.530  5.65e-06   2.34     69.45      1045.5    *
# 4FGL J1912.0+0927      0.869   0.333     4e-06   2.76     87.46      1211.1    *
# 4FGL J1908.7+0812      1.056   1.754  6.75e-06   3.21    240.91      2374.0    *
# 4FGL J1913.3+0905      1.183   0.781   6.3e-06   3.28    321.02      1810.1    *
# 4FGL J1912.7+0957      1.226   0.488  4.86e-06   2.85    148.02      1513.3    *
# 4FGL J1832.7+0618      9.373   1.050  5.66e-07   2.35     12.71        94.9
# 4FGL J1830.1+0617      9.986   2.037  1.83e-06   2.51    115.96       319.7
# 4FGL J1948.3+1207     10.175   0.737  1.06e-06   3.39     93.87       269.0
# isodiff                  ---   0.135   0.00435   2.12     11.42      3084.3    *
# galdiff                  ---   0.985     0.128   0.012837966.09   1107870.0    *

# %%
plt.clf()
tsmap_2disk = gta.tsmap(prefix='TSmap_sgr1900_2disks',make_plots=True,write_fits=True,write_npy=True)
# Out:
# 2025-04-30 16:16:44 INFO    GTAnalysis.tsmap(): Generating TS map
# 2025-04-30 16:16:48 INFO    GTAnalysis._make_tsmap_fast(): Fitting test source.
# 2025-04-30 16:17:45 INFO    GTAnalysis.tsmap(): Finished TS map
# 2025-04-30 16:17:47 WARNING GTAnalysis.tsmap(): Saving TS maps in .npy files is disabled b/c of incompatibilities in python3, remove the maps from the /Users/vdk/software/my_codebase/python/data_analysis/fermi_lat/sgr1900/output_sgr_1GeV_15deg_region/TSmap_sgr1900_2disks_pointsource_powerlaw_2.00_tsmap.npy
# 2025-04-30 16:17:47 INFO    GTAnalysis.tsmap(): Execution time: 62.68 s

# %%
plt.clf()
fig = plt.figure(figsize=(14,6))
ROIPlotter(tsmap_2disk['sqrt_ts'],roi=gta.roi).plot(levels=[0,3,5,7],vmin=0,vmax=5,subplot=121,cmap='magma', zoom = 7)
plt.gca().set_title('Sqrt(TS)')
ROIPlotter(tsmap_2disk['npred'],roi=gta.roi).plot(vmin=0,vmax=100,subplot=122,cmap='magma', zoom = 7)
plt.gca().set_title('NPred')
plt.show()

# %%
from fermipy.gtanalysis import GTAnalysis
import numpy as np

# --- 0) assume gta already built and has your two 'disk1','disk2' sources ---
# --- 1) initial global fit to get things in the ballpark ---
gta.optimize()
gta.fit()

# --- 2) iterative loop: localize → refit → extension → refit ---
for iteration in range(2):
    print(f"\nIteration {iteration+1}: localize sources")
    for src in ['disk1','disk2']:
        loc = gta.localize(src, free_radius=0.3)  
        print(f"  {src}: RA={loc['ra']:.3f}  Dec={loc['dec']:.3f}")
    gta.optimize()
    gta.fit()

    print("   scan for extension")
    for src in ['disk1','disk2']:
        ext = gta.extension(src,
                            spatial_model='RadialDisk',
                            ext_radius=[0.05, 1.0],  # scan 0.05°–1.0°
                            free_radius=0.5)
        print(f"  {src}: best R = {ext['r68']:.3f}°  TS_ext = {ext['ts_ext']:.1f}")
    gta.optimize()
    gta.fit()

# --- 3) test alternative spectral models ---
for src in ['disk1','disk2']:
    print(f"\nTesting spectra for {src}")
    test = gta.spectral_analysis(src,
                                 models=['PowerLaw','LogParabola','PLSuperExpCutoff4'])
    print(test['summary'])
    # Suppose LogParabola wins for disk1, keep PL for disk2:
    best = test['best_model']
    gta.set_source_spectrum(src, best)

gta.optimize()
gta.fit()

# --- 4) final diagnostics ---
gta.print_model()
# residual TS‐map to check for leftovers
resid = gta.residmap('two_disk_resid',
                    model=[  # subtract both disks
                      {'SpatialModel':'RadialDisk','Radius': gta.roi['disk1'].spatial['r68'], 
                       'SpectrumType':gta.roi['disk1'].spectral['type'],
                       'Index':gta.roi['disk1'].spectral['pars']['Index']['value']},
                      {'SpatialModel':'RadialDisk','Radius': gta.roi['disk2'].spatial['r68'], 
                       'SpectrumType':gta.roi['disk2'].spectral['type'],
                       'Index':gta.roi['disk2'].spectral['pars']['Index']['value']}
                    ],
                    roiwidth=4.0, binsz=0.05)
gta.plot_residmap(resid)
# Out:
# 2025-04-30 16:26:52 INFO    GTAnalysis.optimize(): Starting
# Joint fit  ['galdiff', '4FGL J1907.9+0602', '4FGL J1923.2+1408e', '4FGL J1911.0+0905', '4FGL J1857.7+0246e']
# /Users/vdk/miniforge3/envs/fermipy/lib/python3.9/site-packages/scipy/interpolate/_fitpack2.py:313: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# Fitting shape galdiff TS: 3656011.612
# Fitting shape 4FGL J1907.9+0602 TS:  26641.229
# Fitting shape 4FGL J1923.2+1408e TS:  21701.787
# Fitting shape 4FGL J1911.0+0905 TS:   6426.981
# Fitting shape 4FGL J1846.3+0919 TS:   5516.681
# Fitting shape 4FGL J1931.1+0937 TS:   3210.684
# Fitting shape 4FGL J1942.7+1033 TS:   2867.341
# Fitting shape 4FGL J1906.4+0723 TS:   1759.305
# Fitting shape 4FGL J1857.7+0246e TS:   1085.464
# Fitting shape 4FGL J1933.3+0726 TS:    951.515
# Fitting shape 4FGL J1906.9+0712 TS:    758.991
# Fitting shape 4FGL J1921.4+0136 TS:    484.215
# Fitting shape 4FGL J1858.3+0209 TS:    452.688
# Fitting shape 4FGL J1858.0+0354 TS:    399.480
# Fitting shape 4FGL J1913.3+0905 TS:    324.275
# Fitting shape 4FGL J1910.2+0904c TS:    286.485
# Fitting shape 4FGL J1900.4+0339 TS:    269.762
# Fitting shape 4FGL J1908.7+0812 TS:    247.382
# Fitting shape 4FGL J1922.7+1428c TS:    208.799
# Fitting shape 4FGL J1902.2+0448 TS:    196.419
# Fitting shape 4FGL J1903.8+0531 TS:    181.724
# Fitting shape 4FGL J1901.1+0730 TS:    179.894
# Fitting shape 4FGL J1902.5+0654 TS:    173.466
# Fitting shape 4FGL J1916.3+1108 TS:    172.213
# Fitting shape 4FGL J1913.3+1019 TS:    169.563
# Fitting shape 4FGL J1915.3+1149 TS:    164.455
# Fitting shape 4FGL J1918.0+0331 TS:    153.359
# Fitting shape 4FGL J1912.7+0957 TS:    150.364
# Fitting shape 4FGL J1906.1+1651 TS:    142.952
# Fitting shape 4FGL J1856.5+1735 TS:    128.221
# Fitting shape 4FGL J1846.0+0507 TS:    121.245
# Fitting shape 4FGL J1900.7+0426 TS:    117.996
# Fitting shape 4FGL J1830.1+0617 TS:    114.295
# Fitting shape 4FGL J1920.9+1408 TS:    108.978
# Fitting shape 4FGL J1851.5+0718 TS:    107.436
# Fitting shape 4FGL J1920.8+0418 TS:    103.359
# Fitting shape 4FGL J1914.5+1107c TS:     99.787
# Fitting shape 4FGL J1911.5+0311 TS:     98.811
# Fitting shape 4FGL J1907.2+0126 TS:     97.266
# Fitting shape 4FGL J1858.5+0640 TS:     96.372
# Fitting shape 4FGL J1948.3+1207 TS:     90.869
# Fitting shape 4FGL J1912.0+0927 TS:     88.857
# Fitting shape 4FGL J1925.7+1227 TS:     87.025
# Fitting shape 4FGL J1834.3+0613 TS:     78.128
# Fitting shape 4FGL J1900.9+0538 TS:     75.522
# Fitting shape 4FGL J1907.6+0703 TS:     75.013
# Fitting shape 4FGL J1925.3+1522c TS:     71.505
# Fitting shape 4FGL J1911.8+0903c TS:     70.402
# Fitting shape 4FGL J1855.2+0456 TS:     69.641
# Fitting shape 4FGL J1918.1+1215c TS:     67.848
# Fitting shape 4FGL J1859.8+0411c TS:     66.756
# Fitting shape 4FGL J1914.7+1012c TS:     64.665
# Fitting shape 4FGL J1840.3+1105 TS:     64.457
# Fitting shape 4FGL J1927.4+0253 TS:     62.900
# Fitting shape 4FGL J1856.2+0749 TS:     60.125
# Fitting shape 4FGL J1919.9+1358c TS:     54.852
# Fitting shape 4FGL J1919.4+1313 TS:     51.138
# Fitting shape 4FGL J1911.7+1014c TS:     49.167
# Fitting shape 4FGL J1902.8+1451 TS:     48.879
# Fitting shape 4FGL J1922.4+1453c TS:     45.320
# Fitting shape 4FGL J1855.2+0756 TS:     44.918
# Fitting shape 4FGL J1912.5+1320 TS:     43.620
# Fitting shape 4FGL J1911.8+1447 TS:     41.936
# Fitting shape 4FGL J1913.2+0512 TS:     41.525
# Fitting shape 4FGL J1857.9+0313c TS:     37.403
# Fitting shape 4FGL J1935.5+1407 TS:     37.290
# Fitting shape 4FGL J1851.0+1558 TS:     36.152
# Fitting shape 4FGL J1930.3+0911 TS:     34.648
# Fitting shape 4FGL J1934.2+1036 TS:     34.144
# Fitting shape 4FGL J1857.2+0941 TS:     33.527
# Fitting shape 4FGL J1919.2+0618 TS:     27.096
# Fitting shape 4FGL J1920.7+1334 TS:     25.722
# Fitting shape 4FGL J1904.7+0615 TS:     25.098
# 2025-04-30 16:36:22 INFO    GTAnalysis.optimize(): Finished
# 2025-04-30 16:36:22 INFO    GTAnalysis.optimize(): LogLike: 222713.727628 Delta-LogLike: 4.166047
# 2025-04-30 16:36:22 INFO    GTAnalysis.optimize(): Execution time: 569.93 s
# 2025-04-30 16:36:22 INFO    GTAnalysis.fit(): Starting fit.
# 2025-04-30 16:37:30 INFO    GTAnalysis.fit(): Fit returned successfully. Quality:   3 Status:   0
# 2025-04-30 16:37:30 INFO    GTAnalysis.fit(): LogLike:   222713.920 DeltaLogLike:        0.192
# 2025-04-30 16:37:30 INFO    GTAnalysis.localize(): Running localization for disk1
# Iteration 1: localize sources
# 2025-04-30 16:38:19 INFO    GTAnalysis._localize(): Localization succeeded.
# 2025-04-30 16:38:19 INFO    GTAnalysis._localize(): Updating source disk1 to localized position.
# 2025-04-30 16:38:19 INFO    GTAnalysis.delete_source(): Deleting source disk1
# 2025-04-30 16:38:19 INFO    GTAnalysis.add_source(): Adding source disk1
# 2025-04-30 16:38:33 INFO    GTAnalysis._localize(): Localization completed with new position:
# (  ra, dec) = (  286.9684 +/-   0.1080,    9.1276 +/-   0.1512)
# (glon,glat) = (   42.9204 +/-   0.1259,    0.5370 +/-   0.1368)
# offset =   0.0719 r68 =   0.1877 r95 =   0.3028 r99 =   0.3755
# 2025-04-30 16:38:33 INFO    GTAnalysis._localize(): LogLike:   222715.958 DeltaLogLike:        2.038
# 2025-04-30 16:38:33 INFO    GTAnalysis.localize(): Finished localization.
# 2025-04-30 16:38:34 WARNING GTAnalysis.localize(): Saving TS maps in .npy files is disabled b/c of incompatibilities in python3, remove the maps from the /Users/vdk/software/my_codebase/python/data_analysis/fermi_lat/sgr1900/output_sgr_1GeV_15deg_region/disk1_loc.npy
# 2025-04-30 16:38:34 INFO    GTAnalysis.localize(): Execution time: 63.84 s
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[49], line 14
#      12 for src in ['disk1','disk2']:
#      13     loc = gta.localize(src, free_radius=0.3)
# ---> 14     print(f"  {src}: RA={loc['ra']:.3f}  Dec={loc['dec']:.3f}  ΔTS={loc['dts']:.1f}")
#      15 gta.optimize()
#      16 gta.fit()
#
# KeyError: 'dts'

# %%
plt.clf()
tsmap_2disk = gta.tsmap(prefix='TSmap_sgr1900_2disks',make_plots=True,write_fits=True,write_npy=True)
# Out:
# 2025-04-30 16:41:47 INFO    GTAnalysis.tsmap(): Generating TS map
# 2025-04-30 16:41:51 INFO    GTAnalysis._make_tsmap_fast(): Fitting test source.
# 2025-04-30 16:42:49 INFO    GTAnalysis.tsmap(): Finished TS map
# 2025-04-30 16:42:52 WARNING GTAnalysis.tsmap(): Saving TS maps in .npy files is disabled b/c of incompatibilities in python3, remove the maps from the /Users/vdk/software/my_codebase/python/data_analysis/fermi_lat/sgr1900/output_sgr_1GeV_15deg_region/TSmap_sgr1900_2disks_pointsource_powerlaw_2.00_tsmap.npy
# 2025-04-30 16:42:52 INFO    GTAnalysis.tsmap(): Execution time: 64.63 s

# %%
plt.clf()
fig = plt.figure(figsize=(14,6))
ROIPlotter(tsmap_2disk['sqrt_ts'],roi=gta.roi).plot(levels=[0,3,5,7],vmin=0,vmax=5,subplot=121,cmap='magma', zoom = 7)
plt.gca().set_title('Sqrt(TS)')
ROIPlotter(tsmap_2disk['npred'],roi=gta.roi).plot(vmin=0,vmax=100,subplot=122,cmap='magma', zoom = 7)
plt.gca().set_title('NPred')
plt.show()

# %%
# subtract only the diffuse components
resid_bg = gta.residmap('data_minus_diffuse',
                       model=['galdiff','isodiff'],
                       roiwidth=4.0, binsz=0.05)
gta.plot_residmap(resid_bg, cb_label='Counts excess')
# Out:
# 2025-04-30 16:40:46 INFO    GTAnalysis.residmap(): Generating residual maps
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[50], line 2
#       1 # subtract only the diffuse components
# ----> 2 resid_bg = gta.residmap('data_minus_diffuse',
#       3                        model=['galdiff','isodiff'],
#       4                        roiwidth=4.0, binsz=0.05)
#       5 gta.plot_residmap(resid_bg, cb_label='Counts excess')
#
# File ~/miniforge3/envs/fermipy/lib/python3.9/site-packages/fermipy/residmap.py:258, in ResidMapGenerator.residmap(self, prefix, **kwargs)
#     254 self.logger.info('Generating residual maps')
#     256 schema = ConfigSchema(self.defaults['residmap'])
# --> 258 config = schema.create_config(self.config['residmap'], **kwargs)
#     260 # Defining default properties of test source model
#     261 config['model'].setdefault('Index', 2.0)
#
# File ~/miniforge3/envs/fermipy/lib/python3.9/site-packages/fermipy/config.py:180, in ConfigSchema.create_config(self, config, validate, **kwargs)
#     177 config = {} if config is None else config
#     179 o = create_default_config(self)
# --> 180 config = utils.merge_dict(config, kwargs, add_new_keys=True)
#     181 cast_config(config, self)
#     182 if validate:
#
# File ~/miniforge3/envs/fermipy/lib/python3.9/site-packages/fermipy/utils.py:1354, in merge_dict(d0, d1, add_new_keys, append_arrays)
#    1351 elif (d0[k] is not None and d1[k] is not None) and t0 != t1:
#    1353     if t0 == dict or t0 == list:
# -> 1354         raise Exception('Conflicting types in dictionary merge for '
#    1355                         'key %s %s %s' % (k, t0, t1))
#    1356     od[k] = t0(d1[k])
#    1357 else:
#
# Exception: Conflicting types in dictionary merge for key model <class 'dict'> <class 'list'>
